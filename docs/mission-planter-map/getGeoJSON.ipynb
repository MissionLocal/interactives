# %%
import pandas as pd
import geopandas as gpd

# %%
df = pd.read_csv('planterInfo.csv')

# %%
df
# Out:
#                                                address        lat         lng  \
# 0                                     100 San Jose Ave  37.753469 -122.421614
# 1                                         1000 Capp St  37.750635 -122.417421
# 2                                  1001 South Van Ness  37.757041 -122.416613
# 3                                         1011 York St  37.755774 -122.408423
# 4                                      1014 Alabama St  37.755370 -122.411323
# ..                                                 ...        ...         ...
# 409                            Dearborn St and Bird St  37.762284 -122.422918
# 410                         Market and Octavia streets  37.771614 -122.423395
# 411  Market St. and McCoppin St. and Elgin Park Oct...  37.771575 -122.423570
# 412         Southside between Capp and Mission streets  37.757010 -122.418393
# 413                                              TOTAL        NaN         NaN
#
# ...

# %%
geometry = gpd.points_from_xy(df['lng'], df['lat'])
geo_df = gpd.GeoDataFrame(df, geometry=geometry)

# %%
geojson_file_path = 'coordinates.geojson'
geo_df.to_file(geojson_file_path, driver='GeoJSON')
