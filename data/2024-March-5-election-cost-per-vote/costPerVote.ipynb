# %%
import pandas as pd

# %% [markdown]
# # Vote counts

# %%
# read votes data, date is March 14th 4pm
propA_votes = pd.read_csv('votesByPrecinctsMarch14th4pm/propositions/008_propA.csv')
propB_votes = pd.read_csv('votesByPrecinctsMarch14th4pm/propositions/009_propB.csv')
propC_votes = pd.read_csv('votesByPrecinctsMarch14th4pm/propositions/010_propC.csv')
propD_votes = pd.read_csv('votesByPrecinctsMarch14th4pm/propositions/011_propD.csv')
propE_votes = pd.read_csv('votesByPrecinctsMarch14th4pm/propositions/012_propE.csv')
propF_votes = pd.read_csv('votesByPrecinctsMarch14th4pm/propositions/013_propF.csv')
propG_votes = pd.read_csv('votesByPrecinctsMarch14th4pm/propositions/014_propG.csv')
judge1_votes = pd.read_csv('votesByPrecinctsMarch14th4pm/judges/005_court1.csv')
judge13_votes = pd.read_csv('votesByPrecinctsMarch14th4pm/judges/006_court13.csv')
dccc17_votes = pd.read_csv('votesByPrecinctsMarch14th4pm/dccc/001_dccc17.csv')
dccc19_votes = pd.read_csv('votesByPrecinctsMarch14th4pm/dccc/002_dccc19.csv')

# %%
#prop A yes and no total votes
propA_yesTotalVote = int(sum(propA_votes['yes']))
propA_noTotalVote = int(sum(propA_votes['no']))

#prop B yes and no total votes
propB_yesTotalVote = int(sum(propB_votes['yes']))
propB_noTotalVote = int(sum(propB_votes['no']))

#prop C yes and no total votes
propC_yesTotalVote = int(sum(propC_votes['yes']))
propC_noTotalVote = int(sum(propC_votes['no']))

#prop D yes and no total votes
propD_yesTotalVote = int(sum(propD_votes['yes']))
propD_noTotalVote = int(sum(propD_votes['no']))

#prop E yes and no total votes
propE_yesTotalVote = int(sum(propE_votes['yes']))
propE_noTotalVote = int(sum(propE_votes['no']))

#prop F yes and no total votes
propF_yesTotalVote = int(sum(propF_votes['yes']))
propF_noTotalVote = int(sum(propF_votes['no']))

#prop G yes and no total votes
propG_yesTotalVote = int(sum(propG_votes['yes']))
propG_noTotalVote = int(sum(propG_votes['no']))

#judge 1 votes
judge1MichaelBegert = int(sum(judge1_votes['Michael Isaku Begert']))
judge1ChipZecher = int(sum(judge1_votes['Chip Zecher']))

#judge 13 votes
judge13PatrickThompson = int(sum(judge13_votes['Patrick Thompson']))
judge13JeanRoland = int(sum(judge13_votes['Jean Myungjin Roland']))

#dccc 17 votes
dccc17PeterGallotta = int(sum(dccc17_votes['Peter Gallotta']))
dccc17KristinHardy = int(sum(dccc17_votes['Kristin Hardy']))
dccc17EmmaHeiken = int(sum(dccc17_votes['Emma Heiken']))
dccc17LilyHo = int(sum(dccc17_votes['Lily Ho']))
dccc17JohnAvalos = int(sum(dccc17_votes['John Avalos']))
dccc17CedricAkbar = int(sum(dccc17_votes['Cedric Akbar']))
dccc17NancyTung = int(sum(dccc17_votes['Nancy Tung']))
dccc17FrankTizedes = int(sum(dccc17_votes['Frank Tizedes']))
dccc17MichaelLai = int(sum(dccc17_votes['Michael Lai']))
dccc17JeremyLee = int(sum(dccc17_votes['Jeremy Lee']))
dccc17LauranceLemLee = int(sum(dccc17_votes['Laurance Lem Lee']))
dccc17PeterHoLikLee = int(sum(dccc17_votes['Peter Ho Lik Lee']))
dccc17TrevorChandler = int(sum(dccc17_votes['Trevor Chandler']))
dccc17VickChung = int(sum(dccc17_votes['Vick Chung']))
dccc17ChristopherChristensen = int(sum(dccc17_votes['Christopher Christensen']))
dccc17CarrieBarnes = int(sum(dccc17_votes['Carrie Barnes']))
dccc17PatrickBell = int(sum(dccc17_votes['Patrick Bell']))
dccc17GloriaBerry = int(sum(dccc17_votes['Gloria Berry']))
dccc17AdolfoVelasquez = int(sum(dccc17_votes['Adolfo Velasquez']))
dccc17MichaelNguyen = int(sum(dccc17_votes['Michael Nguyen']))
dccc17LynWerbach = int(sum(dccc17_votes['Lyn Werbach']))
dccc17JoeSangirardi = int(sum(dccc17_votes['Joe Sangirardi']))
dccc17SydneySimpson = int(sum(dccc17_votes['Sydney Simpson']))
dccc17JoshuaRudyOchoa = int(sum(dccc17_votes['Joshua Rudy Ochoa']))
dccc17LuisZamora = int(sum(dccc17_votes['Luis Zamora']))
dccc17MattDorsey = int(sum(dccc17_votes['Matt Dorsey']))
dccc17SalRosselli = int(sum(dccc17_votes['Sal Rosselli']))
dccc17JaneKim = int(sum(dccc17_votes['Jane Kim']))
dccc17BilalMahmood = int(sum(dccc17_votes['Bilal Mahmood']))
dccc17AnitaMartinez = int(sum(dccc17_votes['Anita Martinez']))

#dccc 19 votes
dccc19ParagGupta = int(sum(dccc19_votes['Parag Gupta']))
dccc19NatalieGee = int(sum(dccc19_votes['Natalie Gee']))
dccc19GregHardeman = int(sum(dccc19_votes['Greg Hardeman']))
dccc19FrancesHsieh = int(sum(dccc19_votes['Frances Hsieh']))
dccc19MichelaAliotoPier = int(sum(dccc19_votes['Michela Alioto-Pier']))
dccc19JadeTu = int(sum(dccc19_votes['Jade Tu']))
dccc19LeahLacroix = int(sum(dccc19_votes['Leah Lacroix']))
dccc19SandraLeeFewer = int(sum(dccc19_votes['Sandra Lee Fewer']))
dccc19ConnieChan = int(sum(dccc19_votes['Connie Chan']))
dccc19MikeChen = int(sum(dccc19_votes['Mike Chen']))
dccc19QueenaChen = int(sum(dccc19_votes['Queena Chen']))
dccc19DanCalamuci = int(sum(dccc19_votes['Dan Calamuci']))
dccc19LanierColes = int(sum(dccc19_votes['Lanier Coles']))
dccc19SaraBarz = int(sum(dccc19_votes['Sara Barz']))
dccc19JenNossokoff = int(sum(dccc19_votes['Jen Nossokoff']))
dccc19CatherineStefani = int(sum(dccc19_votes['Catherine Stefani']))
dccc19MarjanPhilhour = int(sum(dccc19_votes['Marjan Philhour']))
dccc19ManoRaju = int(sum(dccc19_votes['Mano Raju']))
dccc19HeneKelly = int(sum(dccc19_votes['Hene Kelly']))
dccc19GordonMar = int(sum(dccc19_votes['Gordon Mar']))
dccc19BrianQuan = int(sum(dccc19_votes['Brian Quan']))

# %%
#make a dataframe of how many votes each candidates or prop gets
data = [
    ['propAyes', propA_yesTotalVote], 
    ['propAno', propA_noTotalVote], 
    ['propByes', propB_yesTotalVote],
    ['propBno', propB_noTotalVote],
    ['propCyes', propC_yesTotalVote],
    ['propCno', propC_noTotalVote],
    ['propDyes', propD_yesTotalVote],
    ['propDno', propD_noTotalVote],
    ['propEyes', propE_yesTotalVote],
    ['propEno', propE_noTotalVote],
    ['propFyes', propF_yesTotalVote],
    ['propFno', propF_noTotalVote],
    ['propGyes', propG_yesTotalVote],
    ['propGno', propG_noTotalVote],
    ['judge1MichaelBegert', judge1MichaelBegert],
    ['judge1ChipZecher', judge1ChipZecher],
    ['judge13PatrickThompson', judge13PatrickThompson],
    ['judge13JeanRoland', judge13JeanRoland],
    ['dccc17PeterGallotta', dccc17PeterGallotta],
    ['dccc17KristinHardy', dccc17KristinHardy],
    ['dccc17EmmaHeiken', dccc17EmmaHeiken],
    ['dccc17LilyHo', dccc17LilyHo],
    ['dccc17JohnAvalos', dccc17JohnAvalos],
    ['dccc17CedricAkbar', dccc17CedricAkbar],
    ['dccc17NancyTung', dccc17NancyTung],
    ['dccc17FrankTizedes', dccc17FrankTizedes],
    ['dccc17MichaelLai', dccc17MichaelLai],
    ['dccc17JeremyLee', dccc17JeremyLee],
    ['dccc17LauranceLemLee', dccc17LauranceLemLee],
    ['dccc17PeterHoLikLee', dccc17PeterHoLikLee],
    ['dccc17TrevorChandler', dccc17TrevorChandler],
    ['dccc17VickChung', dccc17VickChung],
    ['dccc17ChristopherChristensen', dccc17ChristopherChristensen],
    ['dccc17CarrieBarnes', dccc17CarrieBarnes],
    ['dccc17PatrickBell', dccc17PatrickBell],
    ['dccc17GloriaBerry', dccc17GloriaBerry],
    ['dccc17AdolfoVelasquez', dccc17AdolfoVelasquez],
    ['dccc17MichaelNguyen', dccc17MichaelNguyen],
    ['dccc17LynWerbach', dccc17LynWerbach],
    ['dccc17JoeSangirardi', dccc17JoeSangirardi],
    ['dccc17SydneySimpson', dccc17SydneySimpson],
    ['dccc17JoshuaRudyOchoa', dccc17JoshuaRudyOchoa],
    ['dccc17LuisZamora', dccc17LuisZamora],
    ['dccc17MattDorsey', dccc17MattDorsey],
    ['dccc17SalRosselli', dccc17SalRosselli],
    ['dccc17JaneKim', dccc17JaneKim],
    ['dccc17BilalMahmood', dccc17BilalMahmood],
    ['dccc17AnitaMartinez', dccc17AnitaMartinez],
    ['dccc19ParagGupta', dccc19ParagGupta],
    ['dccc19NatalieGee', dccc19NatalieGee],
    ['dccc19GregHardeman', dccc19GregHardeman],
    ['dccc19FrancesHsieh', dccc19FrancesHsieh],
    ['dccc19MichelaAliotoPier', dccc19MichelaAliotoPier],
    ['dccc19JadeTu', dccc19JadeTu],
    ['dccc19LeahLacroix', dccc19LeahLacroix],
    ['dccc19SandraLeeFewer', dccc19SandraLeeFewer],
    ['dccc19ConnieChan', dccc19ConnieChan],
    ['dccc19MikeChen', dccc19MikeChen],
    ['dccc19QueenaChen', dccc19QueenaChen],
    ['dccc19DanCalamuci', dccc19DanCalamuci],
    ['dccc19LanierColes', dccc19LanierColes],
    ['dccc19SaraBarz', dccc19SaraBarz],
    ['dccc19JenNossokoff', dccc19JenNossokoff],
    ['dccc19CatherineStefani', dccc19CatherineStefani],
    ['dccc19MarjanPhilhour', dccc19MarjanPhilhour],
    ['dccc19ManoRaju', dccc19ManoRaju],
    ['dccc19HeneKelly', dccc19HeneKelly],
    ['dccc19GordonMar', dccc19GordonMar],
    ['dccc19BrianQuan', dccc19BrianQuan]
]
 
# Create the pandas DataFrame
df_votes = pd.DataFrame(data, columns=['item', 'votes'])
df_votes
# Out:
#                     item   votes
# 0               propAyes  158391
# 1                propAno   66630
# 2               propByes   61527
# 3                propBno  161262
# 4               propCyes  116229
# ..                   ...     ...
# 64  dccc19MarjanPhilhour   24605
# 65        dccc19ManoRaju   18552
# 66       dccc19HeneKelly   16520
# 67       dccc19GordonMar   21576
# 68       dccc19BrianQuan   21240
#
# [69 rows x 2 columns]

# %%
df_votes.to_csv('votes_clean.csv', index=False)

# %% [markdown]
# # DCCC money

# %%
#import campaign money data
totalMoney = pd.read_csv('campaignMoney.csv')
totalMoney
# Out:
#                                name        contest   amount  \
# 0        1266 Ninth LLC(Dan Safier)  Proposition A    375.0
# 1       3333 California(Dan Safier)  Proposition A  13900.0
# 2       3700 California(Dan Safier)  Proposition A  11900.0
# 3                  94123Hala Hijazi    John Avalos    250.0
# 4     A San Francisco For All of Us  Proposition F   7500.0
# ...                             ...            ...      ...
# 4148                        Yen Hui        Seat 13    100.0
# 4149                        Yj Choi        Seat 13    100.0
# 4150                Zachary Alinder         Seat 1    250.0
# 4151                  Zachary Stobo         Seat 1    500.0
# 4152                  Zachary Stobo        Seat 13    500.0
#
#                                          committee_name position        slate  \
# 0                             Affordable Housing For SF  Support          NaN
# 1                             Affordable Housing For SF  Support          NaN
# ...

# %%
#filter out the DCCC money
dcccMoney = totalMoney[totalMoney['race'] == 'DCCC']
dcccMoney
# Out:
#                   name            contest  amount  \
# 3     94123Hala Hijazi        John Avalos   250.0
# 5            A. Sparks     Michael Nguyen   100.0
# 9        Aamer Mahmood      Bilal Mahmood  5000.0
# 10        Aaron Barton     Joe Sangirardi   250.0
# 11        Aaron Parisi        Emma Heiken   200.0
# ...                ...                ...     ...
# 2872    Zahra Sobolski        Matt Dorsey   100.0
# 2873    Zalaikha Lodin     Sydney Simpson   150.0
# 2875        Zhihan Zou        Natalie Gee   100.0
# 2876        Zoe Kelman  Joshua Rudy Ochoa   250.0
# 2877     Zoe Scheinman        Lyn Werbach   100.0
#
#                                          committee_name position        slate  \
# 3     John Avalos For Democratic County Central Comm...  Support  progressive
# 5     Michael Nguyen For Democratic County Central C...  Support  progressive
# 9                    Bilal Mahmood For DCCC Member 2024  Support     moderate
# ...

# %%
# check if all the rows are support of the DCCC candidates, making sure the amount is going into supporting the candidates
dcccAllSupport = all(dcccMoney['position'] == 'Support')
dcccAllSupport
# Out:
# True

# %%
# Get total money for each DCCC AD 17 candidate
PeterGallottaMoney = sum(dcccMoney[dcccMoney['contest'] == 'Peter Gallotta']['amount'])
KristinHardyMoney = sum(dcccMoney[dcccMoney['contest'] == 'Kristin Hardy']['amount'])
EmmaHeikenMoney = sum(dcccMoney[dcccMoney['contest'] == 'Emma Heiken']['amount'])
LilyHoMoney = sum(dcccMoney[dcccMoney['contest'] == 'Lily Ho']['amount'])
JohnAvalosMoney = sum(dcccMoney[dcccMoney['contest'] == 'John Avalos']['amount'])
CedricAkbarMoney = sum(dcccMoney[dcccMoney['contest'] == 'Cedric Akbar']['amount'])
NancyTungMoney = sum(dcccMoney[dcccMoney['contest'] == 'Nancy Tung']['amount'])
FrankTizedesMoney = sum(dcccMoney[dcccMoney['contest'] == 'Frank Tizedes']['amount'])
MichaelLaiMoney = sum(dcccMoney[dcccMoney['contest'] == 'Michael Lai']['amount'])
JeremyLeeMoney = sum(dcccMoney[dcccMoney['contest'] == 'Jeremy Lee']['amount'])
LauranceLemLeeMoney = sum(dcccMoney[dcccMoney['contest'] == 'Laurance Lem Lee']['amount'])
PeterHoLikLeeMoney = sum(dcccMoney[dcccMoney['contest'] == 'Peter Ho Lik Lee']['amount'])
TrevorChandlerMoney = sum(dcccMoney[dcccMoney['contest'] == 'Trevor Chandler']['amount'])
VickChungMoney = sum(dcccMoney[dcccMoney['contest'] == 'Vick Chung']['amount'])
ChristopherChristensenMoney = sum(dcccMoney[dcccMoney['contest'] == 'Christopher Christensen']['amount'])
CarrieBarnesMoney = sum(dcccMoney[dcccMoney['contest'] == 'Carrie Barnes']['amount'])
PatrickBellMoney = sum(dcccMoney[dcccMoney['contest'] == 'Patrick Bell']['amount'])
GloriaBerryMoney = sum(dcccMoney[dcccMoney['contest'] == 'Gloria Berry']['amount'])
AdolfoVelasquezMoney = sum(dcccMoney[dcccMoney['contest'] == 'Adolfo Velasquez']['amount'])
MichaelNguyenMoney = sum(dcccMoney[dcccMoney['contest'] == 'Michael Nguyen']['amount'])
LynWerbachMoney = sum(dcccMoney[dcccMoney['contest'] == 'Lyn Werbach']['amount'])
JoeSangirardiMoney = sum(dcccMoney[dcccMoney['contest'] == 'Joe Sangirardi']['amount'])
SydneySimpsonMoney = sum(dcccMoney[dcccMoney['contest'] == 'Sydney Simpson']['amount'])
JoshuaRudyOchoaMoney = sum(dcccMoney[dcccMoney['contest'] == 'Joshua Rudy Ochoa']['amount'])
LuisZamoraMoney = sum(dcccMoney[dcccMoney['contest'] == 'Luis Zamora']['amount'])
MattDorseyMoney = sum(dcccMoney[dcccMoney['contest'] == 'Matt Dorsey']['amount'])
SalRosselliMoney = sum(dcccMoney[dcccMoney['contest'] == 'Sal Rosselli']['amount'])
JaneKimMoney = sum(dcccMoney[dcccMoney['contest'] == 'Jane Kim']['amount'])
BilalMahmoodMoney = sum(dcccMoney[dcccMoney['contest'] == 'Bilal Mahmood']['amount'])
AnitaMartinezMoney = sum(dcccMoney[dcccMoney['contest'] == 'Anita Martinez']['amount'])

# %%
# Get total money for each DCCC AD 19 candidate
ParagGuptaMoney = sum(dcccMoney[dcccMoney['contest'] == 'Parag Gupta']['amount'])
NatalieGeeMoney = sum(dcccMoney[dcccMoney['contest'] == 'Natalie Gee']['amount'])
GregHardemanMoney = sum(dcccMoney[dcccMoney['contest'] == 'Greg Hardeman']['amount'])
FrancesHsiehMoney = sum(dcccMoney[dcccMoney['contest'] == 'Frances Hsieh']['amount'])
MichelaAliotoPierMoney = sum(dcccMoney[dcccMoney['contest'] == 'Michela Alioto-Pier']['amount'])
JadeTuMoney = sum(dcccMoney[dcccMoney['contest'] == 'Jade Tu']['amount'])
LeahLacroixMoney = sum(dcccMoney[dcccMoney['contest'] == 'Leah Lacroix']['amount'])
SandraLeeFewerMoney = sum(dcccMoney[dcccMoney['contest'] == 'Sandra Lee Fewer']['amount'])
ConnieChanMoney = sum(dcccMoney[dcccMoney['contest'] == 'Connie Chan']['amount'])
MikeChenMoney = sum(dcccMoney[dcccMoney['contest'] == 'Mike Chen']['amount'])
QueenaChenMoney = sum(dcccMoney[dcccMoney['contest'] == 'Queena Chen']['amount'])
DanCalamuciMoney = sum(dcccMoney[dcccMoney['contest'] == 'Dan Calamuci']['amount'])
LanierColesMoney = sum(dcccMoney[dcccMoney['contest'] == 'Lanier Coles']['amount'])
SaraBarzMoney = sum(dcccMoney[dcccMoney['contest'] == 'Sara Barz']['amount'])
JenNossokoffMoney = sum(dcccMoney[dcccMoney['contest'] == 'Jen Nossokoff']['amount'])
CatherineStefaniMoney = sum(dcccMoney[dcccMoney['contest'] == 'Catherine Stefani']['amount'])
MarjanPhilhourMoney = sum(dcccMoney[dcccMoney['contest'] == 'Marjan Philhour']['amount'])
ManoRajuMoney = sum(dcccMoney[dcccMoney['contest'] == 'Mano Raju']['amount'])
HeneKellyMoney = sum(dcccMoney[dcccMoney['contest'] == 'Hene Kelly']['amount'])
GordonMarMoney = sum(dcccMoney[dcccMoney['contest'] == 'Gordon Mar']['amount'])
BrianQuanMoney = sum(dcccMoney[dcccMoney['contest'] == 'Brian Quan']['amount'])

# %%
#make a dataframe of how many votes each candidates or prop gets
data_cost = [
    ['dccc17PeterGallotta', PeterGallottaMoney],
    ['dccc17KristinHardy', KristinHardyMoney],
    ['dccc17EmmaHeiken', EmmaHeikenMoney],
    ['dccc17LilyHo', LilyHoMoney],
    ['dccc17JohnAvalos', JohnAvalosMoney],
    ['dccc17CedricAkbar', CedricAkbarMoney],
    ['dccc17NancyTung', NancyTungMoney],
    ['dccc17FrankTizedes', FrankTizedesMoney],
    ['dccc17MichaelLai', MichaelLaiMoney],
    ['dccc17JeremyLee', JeremyLeeMoney],
    ['dccc17LauranceLemLee', LauranceLemLeeMoney],
    ['dccc17PeterHoLikLee', PeterHoLikLeeMoney],
    ['dccc17TrevorChandler', TrevorChandlerMoney],
    ['dccc17VickChung', VickChungMoney],
    ['dccc17ChristopherChristensen', ChristopherChristensenMoney],
    ['dccc17CarrieBarnes', CarrieBarnesMoney],
    ['dccc17PatrickBell', PatrickBellMoney],
    ['dccc17GloriaBerry', GloriaBerryMoney],
    ['dccc17AdolfoVelasquez', AdolfoVelasquezMoney],
    ['dccc17MichaelNguyen', MichaelNguyenMoney],
    ['dccc17LynWerbach', LynWerbachMoney],
    ['dccc17JoeSangirardi', JoeSangirardiMoney],
    ['dccc17SydneySimpson', SydneySimpsonMoney],
    ['dccc17JoshuaRudyOchoa', JoshuaRudyOchoaMoney],
    ['dccc17LuisZamora', LuisZamoraMoney],
    ['dccc17MattDorsey', MattDorseyMoney],
    ['dccc17SalRosselli', SalRosselliMoney],
    ['dccc17JaneKim', JaneKimMoney],
    ['dccc17BilalMahmood', BilalMahmoodMoney],
    ['dccc17AnitaMartinez', AnitaMartinezMoney],
    ['dccc19ParagGupta', ParagGuptaMoney],
    ['dccc19NatalieGee', NatalieGeeMoney],
    ['dccc19GregHardeman', GregHardemanMoney],
    ['dccc19FrancesHsieh', FrancesHsiehMoney],
    ['dccc19MichelaAliotoPier', MichelaAliotoPierMoney],
    ['dccc19JadeTu', JadeTuMoney],
    ['dccc19LeahLacroix', LeahLacroixMoney],
    ['dccc19SandraLeeFewer', SandraLeeFewerMoney],
    ['dccc19ConnieChan', ConnieChanMoney],
    ['dccc19MikeChen', MikeChenMoney],
    ['dccc19QueenaChen', QueenaChenMoney],
    ['dccc19DanCalamuci', DanCalamuciMoney],
    ['dccc19LanierColes', LanierColesMoney],
    ['dccc19SaraBarz', SaraBarzMoney],
    ['dccc19JenNossokoff', JenNossokoffMoney],
    ['dccc19CatherineStefani', CatherineStefaniMoney],
    ['dccc19MarjanPhilhour', MarjanPhilhourMoney],
    ['dccc19ManoRaju', ManoRajuMoney],
    ['dccc19HeneKelly', HeneKellyMoney],
    ['dccc19GordonMar', GordonMarMoney],
    ['dccc19BrianQuan', BrianQuanMoney]
]
 
# Create the pandas DataFrame
df_dccc_cost = pd.DataFrame(data_cost, columns=['item', 'total_cost'])
df_dccc_cost
# Out:
#                             item  total_cost
# 0            dccc17PeterGallotta     23133.0
# 1             dccc17KristinHardy     53544.0
# 2               dccc17EmmaHeiken     53969.0
# 3                   dccc17LilyHo     70974.0
# 4               dccc17JohnAvalos     16361.0
# 5              dccc17CedricAkbar     37666.0
# 6                dccc17NancyTung     87248.0
# 7             dccc17FrankTizedes       273.0
# 8               dccc17MichaelLai    225960.0
# 9                dccc17JeremyLee     15934.0
# 10          dccc17LauranceLemLee         0.0
# 11           dccc17PeterHoLikLee         0.0
# 12          dccc17TrevorChandler     58608.0
# 13               dccc17VickChung     14459.0
# 14  dccc17ChristopherChristensen         0.0
# 15            dccc17CarrieBarnes    141043.0
# 16             dccc17PatrickBell     57231.0
# 17             dccc17GloriaBerry     13644.0
# 18         dccc17AdolfoVelasquez     17453.0
# 19           dccc17MichaelNguyen     20287.0
# ...

# %%
df_dccc_cost.to_csv('dccc_cost.csv', index=False)

# %% [markdown]
# # Judge money

# %%
#filter out the DCCC money
judgeMoney = totalMoney[totalMoney['race'] == 'judge']
judgeMoney
# Out:
#                  name  contest  amount  \
# 2878           A Chun   Seat 1   500.0
# 2879   A. Marisa Chun   Seat 1   125.0
# 2880   A. Marisa Chun  Seat 13   125.0
# 2881     Aaron Peskin   Seat 1   100.0
# 2882     Aaron Peskin   Seat 1   500.0
# ...               ...      ...     ...
# 4148          Yen Hui  Seat 13   100.0
# 4149          Yj Choi  Seat 13   100.0
# 4150  Zachary Alinder   Seat 1   250.0
# 4151    Zachary Stobo   Seat 1   500.0
# 4152    Zachary Stobo  Seat 13   500.0
#
#                                          committee_name position slate   race
# 2878                  Begert 2024; Retain Judge Michael    right  None  judge
# 2879  Begert And Patrick Thompson; Safe And Accounta...    right  None  judge
# 2880  Begert And Patrick Thompson; Safe And Accounta...    right  None  judge
# 2881                  Begert 2024; Retain Judge Michael    right  None  judge
# 2882  Begert And Patrick Thompson; Safe And Accounta...    right  None  judge
# ...

# %%
#filter out seat 1
judgeMoney_seat1 = judgeMoney[judgeMoney['contest'] == 'Seat 1']
judgeMoney_seat1['committee_name'].value_counts()
# Out:
# Begert 2024; Retain Judge Michael                                                                                   365
# Zecher For Superior Court Judge 2024; Chip                                                                          239
# Begert And Patrick Thompson; Safe And Accountable San Francisco Supporting The Retention Of Judges Michael Isaku    123
# Independent Expenditure                                                                                               1
# Name: committee_name, dtype: int64

# %%
judge1MichaelBegertMoney1 = sum(judgeMoney_seat1[judgeMoney_seat1['committee_name'] == 'Begert 2024; Retain Judge Michael']['amount'])
judge1MichaelBegertMoney2 = sum(judgeMoney_seat1[judgeMoney_seat1['committee_name'] == 'Begert And Patrick Thompson; Safe And Accountable San Francisco Supporting The Retention Of Judges Michael Isaku']['amount'])
judge1MichaelBergertMoney = judge1MichaelBegertMoney1 + judge1MichaelBegertMoney2
judge1MichaelBergertMoney
# Out:
# 417480.67000000004

# %%
judge1AlbertZecherMoney = sum(judgeMoney_seat1[judgeMoney_seat1['committee_name'] == 'Zecher For Superior Court Judge 2024; Chip']['amount'])
judge1AlbertZecherMoney
# Out:
# 680490.3300000001

# %%
#filter out seat 13
judgeMoney_seat13 = judgeMoney[judgeMoney['contest'] == 'Seat 13']
judgeMoney_seat13['committee_name'].value_counts()
# Out:
# Thompson 2024; Retain Judge Patrick                                                                                 213
# Roland For Superior Court Judge 2024; Jean Myungjin                                                                 209
# Begert And Patrick Thompson; Safe And Accountable San Francisco Supporting The Retention Of Judges Michael Isaku    124
# Independent Expenditure                                                                                               1
# Name: committee_name, dtype: int64

# %%
judge13PatrickThompsonMoney1 = sum(judgeMoney_seat13[judgeMoney_seat13['committee_name'] == 'Thompson 2024; Retain Judge Patrick']['amount'])
judge13PatrickThompsonMoney2 = sum(judgeMoney_seat13[judgeMoney_seat13['committee_name'] == 'Begert And Patrick Thompson; Safe And Accountable San Francisco Supporting The Retention Of Judges Michael Isaku']['amount'])
judge13PatrickThompsonMoney = judge13PatrickThompsonMoney1 + judge13PatrickThompsonMoney2
judge13PatrickThompsonMoney
# Out:
# 274764.12

# %%
judge13JeanRolandMoney = sum(judgeMoney_seat13[judgeMoney_seat13['committee_name'] == 'Roland For Superior Court Judge 2024; Jean Myungjin']['amount'])
judge13JeanRolandMoney
# Out:
# 384889.6

# %%
#make a dataframe of how many votes each candidates or prop gets
judge_cost = [
    ['judge1MichaelBegert', judge1MichaelBergertMoney],
    ['judge1AlbertZecher', judge1AlbertZecherMoney],
    ['judge13PatrickThompson', judge13PatrickThompsonMoney],
    ['judge13JeanRoland', judge13JeanRolandMoney]
]
# Create the pandas DataFrame
df_judge_cost = pd.DataFrame(judge_cost, columns=['item', 'total_cost'])
df_judge_cost
# Out:
#                      item  total_cost
# 0     judge1MichaelBegert   417480.67
# 1      judge1AlbertZecher   680490.33
# 2  judge13PatrickThompson   274764.12
# 3       judge13JeanRoland   384889.60

# %%
df_judge_cost.to_csv('judge_cost.csv', index=False)

# %% [markdown]
# # Props money

# %%
#filter out prop A
PropAMoney = totalMoney[totalMoney['contest'] == 'Proposition A']

#filter out prop B
PropBMoney = totalMoney[totalMoney['contest'] == 'Proposition B']

#filter out prop C
PropCMoney = totalMoney[totalMoney['contest'] == 'Proposition C']

#filter out prop D
PropDMoney = totalMoney[totalMoney['contest'] == 'Proposition D']

#filter out prop E
PropEMoney = totalMoney[totalMoney['contest'] == 'Proposition E']

#filter out prop F
PropFMoney = totalMoney[totalMoney['contest'] == 'Proposition F']

#filter out prop G
PropGMoney = totalMoney[totalMoney['contest'] == 'Proposition G']

# %%
#prop A
PropAMoney['committee_name'].value_counts()
# Out:
# Affordable Housing For SF    79
# Name: committee_name, dtype: int64

# %%
PropAyesMoney = sum(PropAMoney[PropAMoney['committee_name'] == 'Affordable Housing For SF']['amount'])

# %%
#prop B
PropBMoney['committee_name'].value_counts()
# Out:
# Stop The Cop Tax, No On B                                                                                     30
# Yes On B, Committee To Restore Police Minimum Staffing And Public Safety, Sponsored By Labor Organizations     5
# Name: committee_name, dtype: int64

# %%
PropByesMoney = sum(PropBMoney[PropBMoney['committee_name'] == 'Yes On B, Committee To Restore Police Minimum Staffing And Public Safety, Sponsored By Labor Organizations']['amount'])
PropBnoMoney = sum(PropBMoney[PropBMoney['committee_name'] == 'Stop The Cop Tax, No On B']['amount'])

# %%
#prop C
PropCMoney['committee_name'].value_counts()
# Out:
# For More Housing & Revitalized Downtown, Yes On C    26
# Stop The Giveaway, No On C                            9
# Name: committee_name, dtype: int64

# %%
PropCyesMoney = sum(PropCMoney[PropCMoney['committee_name'] == 'For More Housing & Revitalized Downtown, Yes On C']['amount']) 
PropCnoMoney = sum(PropCMoney[PropCMoney['committee_name'] == 'Stop The Giveaway, No On C']['amount'])

# %%
#prop D
PropDMoney['committee_name'].value_counts()
# Out:
# Series([], Name: committee_name, dtype: int64)

# %%
#prop E
PropEMoney['committee_name'].value_counts()
# Out:
# Yes On Prop E For A Safer SF - Mayor Breed'S Ballot Measure Committee                                                                       89
# Daniel Lurie For Prop E                                                                                                                     13
# Supporting Measures E And F, The Fight For San Francisco's Future                                                                           11
# Sponsored By The American Civil Liberties Union of Northern California, No On Measure E                                                      4
# Supporting Measures E And F, The Fight For San Francisco's Future, Yes On Prop E For A Safer SF - Mayor Breed'S Ballot Measure Committee     2
# Thriving Communities For All San Francisco Supporting Prop E, Sponsored By Center For Empowered Politics                                     1
# Name: committee_name, dtype: int64

# %%
PropEyesMoney1 = sum(PropEMoney[PropEMoney['committee_name'] == 'Yes On Prop E For A Safer SF - Mayor Breed\'S Ballot Measure Committee']['amount'])
PropEyesMoney2 = sum(PropEMoney[PropEMoney['committee_name'] == 'Daniel Lurie For Prop E']['amount'])
PropEyesMoney3 = sum(PropEMoney[PropEMoney['committee_name'] == 'Supporting Measures E And F, The Fight For San Francisco\'s Future']['amount'])
PropEyesMoney4 = sum(PropEMoney[PropEMoney['committee_name'] == 'Supporting Measures E And F, The Fight For San Francisco\'s Future, Yes On Prop E For A Safer SF - Mayor Breed\'S Ballot Measure Committee']['amount'])
PropEyesMoney5 = sum(PropEMoney[PropEMoney['committee_name'] == 'Thriving Communities For All San Francisco Supporting Prop E, Sponsored By Center For Empowered Politics']['amount'])
propEyesMoney = PropEyesMoney1 + PropEyesMoney2 + PropEyesMoney3 + PropEyesMoney4 + PropEyesMoney5
propEyesMoney
# Out:
# 2255905.0

# %%
propEnoMoney = sum(PropEMoney[PropEMoney['committee_name'] == 'Sponsored By The American Civil Liberties Union of Northern California, No On Measure E']['amount'])
propEnoMoney
# Out:
# 212166.0

# %%
#prop F
PropFMoney['committee_name'].value_counts()
# Out:
# Compassion And Accountability, For Treatment, Yes On F                                                                       23
# Reduce SF'S Homelessness; A Committee Against Proposition F 2024                                                             22
# Supporting Measures E And F, The Fight For San Francisco's Future                                                            12
# The Fight For San Francisco's Future, Yes On F, Supporting Measures E And F, For Treatment, Compassion And Accountability     1
# Name: committee_name, dtype: int64

# %%
propFyesMoney1 = sum(PropFMoney[PropFMoney['committee_name'] == 'Compassion And Accountability, For Treatment, Yes On F']['amount'])
propFyesMoney2 = sum(PropFMoney[PropFMoney['committee_name'] == 'Supporting Measures E And F, The Fight For San Francisco\'s Future']['amount'])
propFyesMoney3 = sum(PropFMoney[PropFMoney['committee_name'] == 'The Fight For San Francisco\'s Future, Yes On F, Supporting Measures E And F, For Treatment, Compassion And Accountability']['amount'])
propFyesMoney = propFyesMoney1 + propFyesMoney2 + propFyesMoney3
propFyesMoney
# Out:
# 1076000.0

# %%
propFnoMoney = sum(PropFMoney[PropFMoney['committee_name'] == 'Reduce SF\'S Homelessness; A Committee Against Proposition F 2024']['amount'])
propFnoMoney
# Out:
# 38531.0

# %%
#prop G
PropGMoney['committee_name'].value_counts()
# Out:
# Bring Algebra Back 2024    42
# Name: committee_name, dtype: int64

# %%
propGyesMoney = sum(PropGMoney[PropGMoney['committee_name'] == 'Bring Algebra Back 2024']['amount'])
propGyesMoney
# Out:
# 174221.0

# %%
#make a dataframe of how many votes each candidates or prop gets
props_cost = [
    ['propAyes', PropAyesMoney], 
    ['propAno', 0], 
    ['propByes', PropByesMoney],
    ['propBno', PropBnoMoney],
    ['propCyes', PropCyesMoney],
    ['propCno', PropCnoMoney],
    ['propDyes', 0],
    ['propDno', 0],
    ['propEyes', propEyesMoney],
    ['propEno', propEnoMoney],
    ['propFyes', propFyesMoney],
    ['propFno', propFnoMoney],
    ['propGyes', propGyesMoney],
    ['propGno', 0]
]
# Create the pandas DataFrame
df_props_cost = pd.DataFrame(props_cost, columns=['item', 'total_cost'])
df_props_cost
# Out:
#         item  total_cost
# 0   propAyes    926350.0
# 1    propAno         0.0
# 2   propByes    617500.0
# 3    propBno   1375760.0
# 4   propCyes    379348.0
# 5    propCno     74640.0
# 6   propDyes         0.0
# 7    propDno         0.0
# 8   propEyes   2255905.0
# 9    propEno    212166.0
# 10  propFyes   1076000.0
# 11   propFno     38531.0
# 12  propGyes    174221.0
# 13   propGno         0.0

# %%
df_props_cost.to_csv('props_cost.csv', index=False)
