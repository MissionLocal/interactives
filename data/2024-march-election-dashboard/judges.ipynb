# %%
import pandas as pd

# %% [markdown]
# # Albert "Chip" Zecker
#
# Downloaded the excel files from his committee contributions [here](https://cal-access.sos.ca.gov/Campaign/Candidates/Detail.aspx?id=1463374) (late and all contributions). Adding them together, cleaning and removing duplicates below:

# %%
# import csv 

zecher_late_df = pd.read_csv('./raw_files/zecher_late.csv')

# %%
zecher_late_df.columns = zecher_late_df.columns.str.lower().str.replace(' ', '_')

# %%
print(zecher_late_df.shape)
# Out:
# (57, 12)

# %%
zecher_all_df = pd.read_csv('./raw_files/zecher_all.csv')

# %%
zecher_all_df.shape
# Out:
# (244, 12)

# %%
zecher_all_df.columns = zecher_all_df.columns.str.lower().str.replace(' ', '_')

# %%
zecher_late_df.head()
# Out:
#     name_of_contributor           city   state/zip  id_number employer  \
# 0    JEANNIE SANGIACOMO           ROSS  CA / 94957        NaN     NONE
# 1    JEANNIE SANGIACOMO           ROSS  CA / 94957        NaN     NONE
# 2           WALTER WOOD      LOS ALTOS  CA / 94022        NaN     NONE
# 3      PG&E CORPORATION        OAKLAND  CA / 94612        NaN      NaN
# 4  TUCKER AND MARKS INC  SAN FRANCISCO  CA / 94108        NaN      NaN
#
#   occupation      amount            transaction_type     type  \
# 0    RETIRED    $500.00   LATE CONTRIBUTION RECEIVED  INITIAL
# 1    RETIRED    $500.00   LATE CONTRIBUTION RECEIVED  INITIAL
# 2    RETIRED  $5,000.00   LATE CONTRIBUTION RECEIVED  INITIAL
# 3        NaN  $5,000.00   LATE CONTRIBUTION RECEIVED  INITIAL
# 4        NaN  $1,000.00   LATE CONTRIBUTION RECEIVED  INITIAL
#
#   transaction_date  filed_date transaction_number
# 0       02/23/2024  02/26/2024     2897128-INC515
# 1       02/21/2024  02/26/2024     2897128-INC504
# 2       02/21/2024  02/22/2024     2895281-INC507
# 3       02/21/2024  02/22/2024     2895281-INC506
# 4       02/20/2024  02/21/2024     2893914-INC499

# %%
zecher_all_df.head()
# Out:
#   name_of_contributor payment_type           city state    zip  id_number  \
# 0   BOSTON PROPERTIES     MONETARY  SAN FRANCISCO    CA  94111        NaN
# 1          KEVIN BASS     MONETARY       DANVILLE    CA  94526        NaN
# 2        ST JOHN BAIN     MONETARY         SONOMA    CA  95476        NaN
# 3        CLAIRE SOLOT     MONETARY         SONOMA    CA  95476        NaN
# 4       LAURIE THOMAS     MONETARY  SAN FRANCISCO    CA  94114        NaN
#
#                          employer                               occupation  \
# 0                             NaN                                      NaN
# 1             ENTERPRISE MOBILITY         VICE PRESIDENT & GENERAL MANAGER
# 2                            TIMI  SENIOR DIRECTOR, STRATEGIC PARTNERSHIPS
# 3  BIGGLESWORTH FAMILY FOUNDATION                        MANAGING DIRECTOR
# 4               NICE VENTURES INC                                PRESIDENT
#
#         amount transaction_date filed_date transaction_number
# 0  $10,000.00          1/4/2024  1/25/2024   2873178 - INC208
# 1     $500.00          1/5/2024  1/25/2024   2873178 - INC209
# 2   $3,500.00          1/5/2024  1/25/2024   2873178 - INC210
# 3   $3,500.00          1/5/2024  1/25/2024   2873178 - INC211
# 4     $500.00          1/6/2024  1/25/2024   2873178 - INC212

# %%
zecher_df = pd.concat([zecher_late_df, zecher_all_df])

# %%
zecher_df["committee_name"] = "ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP"

# %%
zecher_df.head(5)
# Out:
#     name_of_contributor           city   state/zip  id_number employer  \
# 0    JEANNIE SANGIACOMO           ROSS  CA / 94957        NaN     NONE
# 1    JEANNIE SANGIACOMO           ROSS  CA / 94957        NaN     NONE
# 2           WALTER WOOD      LOS ALTOS  CA / 94022        NaN     NONE
# 3      PG&E CORPORATION        OAKLAND  CA / 94612        NaN      NaN
# 4  TUCKER AND MARKS INC  SAN FRANCISCO  CA / 94108        NaN      NaN
#
#   occupation      amount            transaction_type     type  \
# 0    RETIRED    $500.00   LATE CONTRIBUTION RECEIVED  INITIAL
# 1    RETIRED    $500.00   LATE CONTRIBUTION RECEIVED  INITIAL
# 2    RETIRED  $5,000.00   LATE CONTRIBUTION RECEIVED  INITIAL
# 3        NaN  $5,000.00   LATE CONTRIBUTION RECEIVED  INITIAL
# 4        NaN  $1,000.00   LATE CONTRIBUTION RECEIVED  INITIAL
#
#   transaction_date  filed_date transaction_number payment_type state  zip  \
# 0       02/23/2024  02/26/2024     2897128-INC515          NaN   NaN  NaN
# 1       02/21/2024  02/26/2024     2897128-INC504          NaN   NaN  NaN
# 2       02/21/2024  02/22/2024     2895281-INC507          NaN   NaN  NaN
# 3       02/21/2024  02/22/2024     2895281-INC506          NaN   NaN  NaN
# 4       02/20/2024  02/21/2024     2893914-INC499          NaN   NaN  NaN
#
#                                committee_name
# 0  ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP
# 1  ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP
# 2  ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP
# 3  ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP
# 4  ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP

# %%
zecher_df['date'] = pd.to_datetime(zecher_df['transaction_date'], format='%m/%d/%Y')

# %%
zecher_df['amount'] = zecher_df['amount'].str.replace('$', '')
# Out:
# /var/folders/_0/x7xh_2c16jq4chdcqrg28fr40000gn/T/ipykernel_1433/380300085.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   zecher_df['amount'] = zecher_df['amount'].str.replace('$', '')

# %%
zecher_df['amount'] = zecher_df['amount'].str.replace(',', '')

# %%
zecher_df['amount'] = zecher_df['amount'].astype(float)

# %%
zecher_df['transaction_number'] = zecher_df['transaction_number'].str.replace(' - ', '-')

# %%
zecher_doubles = zecher_df[zecher_df.duplicated(subset=['name_of_contributor', 'amount', 'date', 'transaction_type'], keep=False)]

# %%
zecher_doubles
# Out:
#     name_of_contributor           city state/zip  id_number  \
# 40        ALBERT ZECHER  SAN FRANCISCO       NaN        NaN
# 88      DAVID ZILBERMAN  SAN FRANCISCO       NaN        NaN
# 96      DAVID ZILBERMAN  SAN FRANCISCO       NaN        NaN
# 243       ALBERT ZECHER  SAN FRANCISCO       NaN        NaN
#
#                      employer       occupation  amount transaction_type type  \
# 40                        NaN              NaN     0.0              NaN  NaN
# 88   NORWEST VENTURE PARTNERS  GENERAL PARTNER   250.0              NaN  NaN
# 96   NORWEST VENTURE PARTNERS  GENERAL PARTNER   250.0              NaN  NaN
# 243                       NaN              NaN     0.0              NaN  NaN
#
#     transaction_date filed_date transaction_number payment_type state  \
# 40        10/16/2023  1/25/2024       2873178-PAY9         LOAN    CA
# 88         11/3/2023  1/25/2024      2873175-INC19     MONETARY    CA
# 96         11/3/2023  1/25/2024      2873175-INC21     MONETARY    CA
# 243       10/16/2023  2/22/2024       2895288-PAY9         LOAN    CA
#
#          zip                              committee_name       date
# 40   94122.0  ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP 2023-10-16
# 88   94115.0  ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP 2023-11-03
# 96   94115.0  ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP 2023-11-03
# 243  94122.0  ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP 2023-10-16

# %% [markdown]
# I have addressed entries that seem like duplicates but are in fact transactions of the same type from the same person on the same day. Now I am looking for duplicates overall based on the name, amount and date.

# %%
zecher_df[zecher_df.duplicated(subset=['name_of_contributor', 'amount', 'date'], keep=False)]
# Out:
#                           name_of_contributor           city   state/zip  \
# 5                               REGINA CALLAN  SAN FRANCISCO  CA / 94123
# 6                               KEITH WETMORE  NEWPORT BEACH  CA / 92657
# 7                                  NEIL MEHTA  SAN FRANCISCO  CA / 94115
# 8                             SUSAN LOWENBERG  SAN FRANCISCO  CA / 94108
# 9                               JOYCE NEWSTAT  SAN FRANCISCO  CA / 94108
# ..                                        ...            ...         ...
# 234                                NEIL MEHTA  SAN FRANCISCO         NaN
# 235                             KEITH WETMORE  NEWPORT BEACH         NaN
# 241  NEW TRADITION MEDIA LLC(EVAN RICHHEIMER)       NEW YORK         NaN
# 242                               FRED FAVERO         SONOMA         NaN
# 243                             ALBERT ZECHER  SAN FRANCISCO         NaN
#
#      id_number                   employer               occupation    amount  \
# 5          NaN       REGINA CALLAN DESIGN                    OWNER   1000.00
# 6          NaN   MAJOR LINDSEY AND AFRICA                RECRUITER   2500.00
# 7          NaN          GREENOAKS CAPITAL                  FOUNDER  49999.00
# 8          NaN      LOWENBERG CORPORATION     REAL ESTATE INVESTOR   1250.00
# 9          NaN  ROCKET SCIENCE ASSOCIATES  CHIEF EXECUTIVE OFFICER   1250.00
# ..         ...                        ...                      ...       ...
# 234        NaN          GREENOAKS CAPITAL                  FOUNDER  49999.00
# 235        NaN   MAJOR LINDSEY AND AFRICA                RECRUITER   2500.00
# 241        NaN                        NaN                      NaN   2708.75
# 242        NaN           FAVERO VINEYARDS                    OWNER   2708.75
# 243        NaN                        NaN                      NaN      0.00
#
#                transaction_type     type transaction_date  filed_date  \
# 5    LATE CONTRIBUTION RECEIVED  INITIAL       02/13/2024  02/19/2024
# 6    LATE CONTRIBUTION RECEIVED  INITIAL       02/14/2024  02/15/2024
# 7    LATE CONTRIBUTION RECEIVED  INITIAL       02/14/2024  02/15/2024
# 8    LATE CONTRIBUTION RECEIVED  INITIAL       02/12/2024  02/13/2024
# 9    LATE CONTRIBUTION RECEIVED  INITIAL       02/12/2024  02/13/2024
# ..                          ...      ...              ...         ...
# 234                         NaN      NaN        2/14/2024   2/22/2024
# 235                         NaN      NaN        2/14/2024   2/22/2024
# 241                         NaN      NaN         2/5/2024   2/22/2024
# 242                         NaN      NaN         2/5/2024   2/22/2024
# 243                         NaN      NaN       10/16/2023   2/22/2024
#
#     transaction_number  payment_type state      zip  \
# 5       2892610-INC441           NaN   NaN      NaN
# 6       2891799-INC455           NaN   NaN      NaN
# 7       2891799-INC454           NaN   NaN      NaN
# 8       2890866-INC435           NaN   NaN      NaN
# 9       2890866-INC434           NaN   NaN      NaN
# ..                 ...           ...   ...      ...
# 234     2895288-INC454      MONETARY    CA  94115.0
# 235     2895288-INC455      MONETARY    CA  92657.0
# 241     2895288-NON400  NON-MONETARY    NY  10012.0
# 242     2895288-NON401  NON-MONETARY    CA  95476.0
# 243       2895288-PAY9          LOAN    CA  94122.0
#
#                                  committee_name       date
# 5    ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP 2024-02-13
# 6    ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP 2024-02-14
# 7    ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP 2024-02-14
# 8    ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP 2024-02-12
# 9    ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP 2024-02-12
# ..                                          ...        ...
# 234  ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP 2024-02-14
# 235  ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP 2024-02-14
# 241  ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP 2024-02-05
# 242  ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP 2024-02-05
# 243  ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP 2023-10-16
#
# [108 rows x 17 columns]

# %% [markdown]
# Also, there are no duplicates just based on the transaction number.

# %%
zecher_df[zecher_df.duplicated(subset=['transaction_number'], keep=False)]
# Out:
# Empty DataFrame
# Columns: [name_of_contributor, city, state/zip, id_number, employer, occupation, amount, transaction_type, type, transaction_date, filed_date, transaction_number, payment_type, state, zip, committee_name, date]
# Index: []

# %% [markdown]
# Here I am actually removing the duplicates:

# %%
zecher_df = zecher_df.drop_duplicates(subset=['name_of_contributor', 'amount', 'date'])

# %%
zecher_df
# Out:
#       name_of_contributor           city   state/zip  id_number  \
# 0      JEANNIE SANGIACOMO           ROSS  CA / 94957        NaN
# 1      JEANNIE SANGIACOMO           ROSS  CA / 94957        NaN
# 2             WALTER WOOD      LOS ALTOS  CA / 94022        NaN
# 3        PG&E CORPORATION        OAKLAND  CA / 94612        NaN
# 4    TUCKER AND MARKS INC  SAN FRANCISCO  CA / 94108        NaN
# ..                    ...            ...         ...        ...
# 236             ED CONLON  SAN FRANCISCO         NaN        NaN
# 237          PAUL DENNING  SAN FRANCISCO         NaN        NaN
# 238           ROBERT CHAN  SAN FRANCISCO         NaN        NaN
# 239  SALLY FAY COTTINGHAM  SAN FRANCISCO         NaN        NaN
# 240   MARYANNE SANGIACOMO  SAN FRANCISCO         NaN        NaN
#
#                                 employer         occupation  amount  \
# 0                                   NONE            RETIRED   500.0
# 1                                   NONE            RETIRED   500.0
# 2                                   NONE            RETIRED  5000.0
# 3                                    NaN                NaN  5000.0
# 4                                    NaN                NaN  1000.0
# ..                                   ...                ...     ...
# 236  HATHAWAY DINWIDDIE CONSTRUCTION CO.     VICE PRESIDENT   500.0
# 237               DENNING & COMPANY, LLC  INVESTMENT BANKER   500.0
# 238                                 NONE            RETIRED   300.0
# 239                     NOB HILL GAZETTE   FREELANCE WRITER   250.0
# 240                              TRINITY          PRINCIPAL   500.0
#
#                transaction_type     type transaction_date  filed_date  \
# 0    LATE CONTRIBUTION RECEIVED  INITIAL       02/23/2024  02/26/2024
# 1    LATE CONTRIBUTION RECEIVED  INITIAL       02/21/2024  02/26/2024
# 2    LATE CONTRIBUTION RECEIVED  INITIAL       02/21/2024  02/22/2024
# 3    LATE CONTRIBUTION RECEIVED  INITIAL       02/21/2024  02/22/2024
# 4    LATE CONTRIBUTION RECEIVED  INITIAL       02/20/2024  02/21/2024
# ..                          ...      ...              ...         ...
# 236                         NaN      NaN        2/14/2024   2/22/2024
# 237                         NaN      NaN        2/14/2024   2/22/2024
# 238                         NaN      NaN        2/16/2024   2/22/2024
# 239                         NaN      NaN        2/16/2024   2/22/2024
# 240                         NaN      NaN        2/16/2024   2/22/2024
#
#     transaction_number payment_type state      zip  \
# 0       2897128-INC515          NaN   NaN      NaN
# 1       2897128-INC504          NaN   NaN      NaN
# 2       2895281-INC507          NaN   NaN      NaN
# 3       2895281-INC506          NaN   NaN      NaN
# 4       2893914-INC499          NaN   NaN      NaN
# ..                 ...          ...   ...      ...
# 236     2895288-INC456     MONETARY    CA  94133.0
# 237     2895288-INC457     MONETARY    CA  94135.0
# 238     2895288-INC472     MONETARY    CA  94123.0
# 239     2895288-INC473     MONETARY    CA  94115.0
# 240     2895288-INC474     MONETARY    CA  94127.0
#
#                                  committee_name       date
# 0    ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP 2024-02-23
# 1    ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP 2024-02-21
# 2    ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP 2024-02-21
# 3    ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP 2024-02-21
# 4    ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP 2024-02-20
# ..                                          ...        ...
# 236  ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP 2024-02-14
# 237  ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP 2024-02-14
# 238  ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP 2024-02-16
# 239  ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP 2024-02-16
# 240  ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP 2024-02-16
#
# [247 rows x 17 columns]

# %%
zecher_df = pd.concat([zecher_df, zecher_doubles])

# %%
zecher_df
# Out:
#       name_of_contributor           city   state/zip  id_number  \
# 0      JEANNIE SANGIACOMO           ROSS  CA / 94957        NaN
# 1      JEANNIE SANGIACOMO           ROSS  CA / 94957        NaN
# 2             WALTER WOOD      LOS ALTOS  CA / 94022        NaN
# 3        PG&E CORPORATION        OAKLAND  CA / 94612        NaN
# 4    TUCKER AND MARKS INC  SAN FRANCISCO  CA / 94108        NaN
# ..                    ...            ...         ...        ...
# 240   MARYANNE SANGIACOMO  SAN FRANCISCO         NaN        NaN
# 40          ALBERT ZECHER  SAN FRANCISCO         NaN        NaN
# 88        DAVID ZILBERMAN  SAN FRANCISCO         NaN        NaN
# 96        DAVID ZILBERMAN  SAN FRANCISCO         NaN        NaN
# 243         ALBERT ZECHER  SAN FRANCISCO         NaN        NaN
#
#                      employer       occupation  amount  \
# 0                        NONE          RETIRED   500.0
# 1                        NONE          RETIRED   500.0
# 2                        NONE          RETIRED  5000.0
# 3                         NaN              NaN  5000.0
# 4                         NaN              NaN  1000.0
# ..                        ...              ...     ...
# 240                   TRINITY        PRINCIPAL   500.0
# 40                        NaN              NaN     0.0
# 88   NORWEST VENTURE PARTNERS  GENERAL PARTNER   250.0
# 96   NORWEST VENTURE PARTNERS  GENERAL PARTNER   250.0
# 243                       NaN              NaN     0.0
#
#                transaction_type     type transaction_date  filed_date  \
# 0    LATE CONTRIBUTION RECEIVED  INITIAL       02/23/2024  02/26/2024
# 1    LATE CONTRIBUTION RECEIVED  INITIAL       02/21/2024  02/26/2024
# 2    LATE CONTRIBUTION RECEIVED  INITIAL       02/21/2024  02/22/2024
# 3    LATE CONTRIBUTION RECEIVED  INITIAL       02/21/2024  02/22/2024
# 4    LATE CONTRIBUTION RECEIVED  INITIAL       02/20/2024  02/21/2024
# ..                          ...      ...              ...         ...
# 240                         NaN      NaN        2/16/2024   2/22/2024
# 40                          NaN      NaN       10/16/2023   1/25/2024
# 88                          NaN      NaN        11/3/2023   1/25/2024
# 96                          NaN      NaN        11/3/2023   1/25/2024
# 243                         NaN      NaN       10/16/2023   2/22/2024
#
#     transaction_number payment_type state      zip  \
# 0       2897128-INC515          NaN   NaN      NaN
# 1       2897128-INC504          NaN   NaN      NaN
# 2       2895281-INC507          NaN   NaN      NaN
# 3       2895281-INC506          NaN   NaN      NaN
# 4       2893914-INC499          NaN   NaN      NaN
# ..                 ...          ...   ...      ...
# 240     2895288-INC474     MONETARY    CA  94127.0
# 40        2873178-PAY9         LOAN    CA  94122.0
# 88       2873175-INC19     MONETARY    CA  94115.0
# 96       2873175-INC21     MONETARY    CA  94115.0
# 243       2895288-PAY9         LOAN    CA  94122.0
#
#                                  committee_name       date
# 0    ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP 2024-02-23
# 1    ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP 2024-02-21
# 2    ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP 2024-02-21
# 3    ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP 2024-02-21
# 4    ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP 2024-02-20
# ..                                          ...        ...
# 240  ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP 2024-02-16
# 40   ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP 2023-10-16
# 88   ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP 2023-11-03
# 96   ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP 2023-11-03
# 243  ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP 2023-10-16
#
# [251 rows x 17 columns]

# %%
zecher_df[zecher_df.duplicated(subset=['name_of_contributor', 'amount', 'date'], keep=False)]
# Out:
#     name_of_contributor           city state/zip  id_number  \
# 40        ALBERT ZECHER  SAN FRANCISCO       NaN        NaN
# 88      DAVID ZILBERMAN  SAN FRANCISCO       NaN        NaN
# 40        ALBERT ZECHER  SAN FRANCISCO       NaN        NaN
# 88      DAVID ZILBERMAN  SAN FRANCISCO       NaN        NaN
# 96      DAVID ZILBERMAN  SAN FRANCISCO       NaN        NaN
# 243       ALBERT ZECHER  SAN FRANCISCO       NaN        NaN
#
#                      employer       occupation  amount transaction_type type  \
# 40                        NaN              NaN     0.0              NaN  NaN
# 88   NORWEST VENTURE PARTNERS  GENERAL PARTNER   250.0              NaN  NaN
# 40                        NaN              NaN     0.0              NaN  NaN
# 88   NORWEST VENTURE PARTNERS  GENERAL PARTNER   250.0              NaN  NaN
# 96   NORWEST VENTURE PARTNERS  GENERAL PARTNER   250.0              NaN  NaN
# 243                       NaN              NaN     0.0              NaN  NaN
#
#     transaction_date filed_date transaction_number payment_type state  \
# 40        10/16/2023  1/25/2024       2873178-PAY9         LOAN    CA
# 88         11/3/2023  1/25/2024      2873175-INC19     MONETARY    CA
# 40        10/16/2023  1/25/2024       2873178-PAY9         LOAN    CA
# 88         11/3/2023  1/25/2024      2873175-INC19     MONETARY    CA
# 96         11/3/2023  1/25/2024      2873175-INC21     MONETARY    CA
# 243       10/16/2023  2/22/2024       2895288-PAY9         LOAN    CA
#
#          zip                              committee_name       date
# 40   94122.0  ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP 2023-10-16
# 88   94115.0  ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP 2023-11-03
# 40   94122.0  ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP 2023-10-16
# 88   94115.0  ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP 2023-11-03
# 96   94115.0  ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP 2023-11-03
# 243  94122.0  ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP 2023-10-16

# %%
zecher_df = zecher_df.drop_duplicates(subset=['transaction_number'])

# %%
zecher_df[zecher_df.duplicated(subset=['name_of_contributor', 'amount', 'date'], keep=False)]
# Out:
#     name_of_contributor           city state/zip  id_number  \
# 40        ALBERT ZECHER  SAN FRANCISCO       NaN        NaN
# 88      DAVID ZILBERMAN  SAN FRANCISCO       NaN        NaN
# 96      DAVID ZILBERMAN  SAN FRANCISCO       NaN        NaN
# 243       ALBERT ZECHER  SAN FRANCISCO       NaN        NaN
#
#                      employer       occupation  amount transaction_type type  \
# 40                        NaN              NaN     0.0              NaN  NaN
# 88   NORWEST VENTURE PARTNERS  GENERAL PARTNER   250.0              NaN  NaN
# 96   NORWEST VENTURE PARTNERS  GENERAL PARTNER   250.0              NaN  NaN
# 243                       NaN              NaN     0.0              NaN  NaN
#
#     transaction_date filed_date transaction_number payment_type state  \
# 40        10/16/2023  1/25/2024       2873178-PAY9         LOAN    CA
# 88         11/3/2023  1/25/2024      2873175-INC19     MONETARY    CA
# 96         11/3/2023  1/25/2024      2873175-INC21     MONETARY    CA
# 243       10/16/2023  2/22/2024       2895288-PAY9         LOAN    CA
#
#          zip                              committee_name       date
# 40   94122.0  ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP 2023-10-16
# 88   94115.0  ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP 2023-11-03
# 96   94115.0  ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP 2023-11-03
# 243  94122.0  ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP 2023-10-16

# %%
zecher_df.shape
# Out:
# (249, 17)

# %% [markdown]
# Reading in independent expeditures

# %%
zecher_ind = pd.read_csv('./raw_files/zecher_ind.csv')

# %%
zecher_ind
# Out:
#          date                            name_of_contributor position  \
# 0  01/30/2024  COALITION TO GROW SAN FRANCISCO - GROW SF PAC  SUPPORT
# 1  01/30/2024  COALITION TO GROW SAN FRANCISCO - GROW SF PAC  SUPPORT
# 2  01/26/2024  COALITION TO GROW SAN FRANCISCO - GROW SF PAC  SUPPORT
# 3  01/31/2024  COALITION TO GROW SAN FRANCISCO - GROW SF PAC  SUPPORT
# 4  01/21/2024  COALITION TO GROW SAN FRANCISCO - GROW SF PAC  SUPPORT
# 5  01/24/2024  COALITION TO GROW SAN FRANCISCO - GROW SF PAC  SUPPORT
#
#       amount      description
# 0  $17792.50       ONLINE ADS
# 1   $3985.77       ONLINE ADS
# 2   $1594.31       ONLINE ADS
# 3    $478.29  DESIGN SERVICES
# 4    $199.28       ONLINE ADS
# 5    $143.48       ONLINE ADS

# %%
zecher_ind['date'] = pd.to_datetime(zecher_ind['date'], format='%m/%d/%Y')

# %%
zecher_ind['amount'] = zecher_ind['amount'].str.replace('$', '')

zecher_ind['amount'] = zecher_ind['amount'].astype(float)
# Out:
# /var/folders/_0/x7xh_2c16jq4chdcqrg28fr40000gn/T/ipykernel_1433/1371513256.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   zecher_ind['amount'] = zecher_ind['amount'].str.replace('$', '')

# %%
zecher_ind['committee_name'] = 'Independent Expenditure'

# %%
zecher_ind
# Out:
#         date                            name_of_contributor position  \
# 0 2024-01-30  COALITION TO GROW SAN FRANCISCO - GROW SF PAC  SUPPORT
# 1 2024-01-30  COALITION TO GROW SAN FRANCISCO - GROW SF PAC  SUPPORT
# 2 2024-01-26  COALITION TO GROW SAN FRANCISCO - GROW SF PAC  SUPPORT
# 3 2024-01-31  COALITION TO GROW SAN FRANCISCO - GROW SF PAC  SUPPORT
# 4 2024-01-21  COALITION TO GROW SAN FRANCISCO - GROW SF PAC  SUPPORT
# 5 2024-01-24  COALITION TO GROW SAN FRANCISCO - GROW SF PAC  SUPPORT
#
#      amount      description           committee_name
# 0  17792.50       ONLINE ADS  Independent Expenditure
# 1   3985.77       ONLINE ADS  Independent Expenditure
# 2   1594.31       ONLINE ADS  Independent Expenditure
# 3    478.29  DESIGN SERVICES  Independent Expenditure
# 4    199.28       ONLINE ADS  Independent Expenditure
# 5    143.48       ONLINE ADS  Independent Expenditure

# %%
zecher_df = pd.concat([zecher_df, zecher_ind])

# %%
zecher_df
# Out:
#                               name_of_contributor           city   state/zip  \
# 0                              JEANNIE SANGIACOMO           ROSS  CA / 94957
# 1                              JEANNIE SANGIACOMO           ROSS  CA / 94957
# 2                                     WALTER WOOD      LOS ALTOS  CA / 94022
# 3                                PG&E CORPORATION        OAKLAND  CA / 94612
# 4                            TUCKER AND MARKS INC  SAN FRANCISCO  CA / 94108
# ..                                            ...            ...         ...
# 1   COALITION TO GROW SAN FRANCISCO - GROW SF PAC            NaN         NaN
# 2   COALITION TO GROW SAN FRANCISCO - GROW SF PAC            NaN         NaN
# 3   COALITION TO GROW SAN FRANCISCO - GROW SF PAC            NaN         NaN
# 4   COALITION TO GROW SAN FRANCISCO - GROW SF PAC            NaN         NaN
# 5   COALITION TO GROW SAN FRANCISCO - GROW SF PAC            NaN         NaN
#
#     id_number employer occupation   amount            transaction_type  \
# 0         NaN     NONE    RETIRED   500.00  LATE CONTRIBUTION RECEIVED
# 1         NaN     NONE    RETIRED   500.00  LATE CONTRIBUTION RECEIVED
# 2         NaN     NONE    RETIRED  5000.00  LATE CONTRIBUTION RECEIVED
# 3         NaN      NaN        NaN  5000.00  LATE CONTRIBUTION RECEIVED
# 4         NaN      NaN        NaN  1000.00  LATE CONTRIBUTION RECEIVED
# ..        ...      ...        ...      ...                         ...
# 1         NaN      NaN        NaN  3985.77                         NaN
# 2         NaN      NaN        NaN  1594.31                         NaN
# 3         NaN      NaN        NaN   478.29                         NaN
# 4         NaN      NaN        NaN   199.28                         NaN
# 5         NaN      NaN        NaN   143.48                         NaN
#
#        type transaction_date  filed_date transaction_number payment_type  \
# 0   INITIAL       02/23/2024  02/26/2024     2897128-INC515          NaN
# 1   INITIAL       02/21/2024  02/26/2024     2897128-INC504          NaN
# 2   INITIAL       02/21/2024  02/22/2024     2895281-INC507          NaN
# 3   INITIAL       02/21/2024  02/22/2024     2895281-INC506          NaN
# 4   INITIAL       02/20/2024  02/21/2024     2893914-INC499          NaN
# ..      ...              ...         ...                ...          ...
# 1       NaN              NaN         NaN                NaN          NaN
# 2       NaN              NaN         NaN                NaN          NaN
# 3       NaN              NaN         NaN                NaN          NaN
# 4       NaN              NaN         NaN                NaN          NaN
# 5       NaN              NaN         NaN                NaN          NaN
#
#    state  zip                              committee_name       date position  \
# 0    NaN  NaN  ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP 2024-02-23      NaN
# 1    NaN  NaN  ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP 2024-02-21      NaN
# 2    NaN  NaN  ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP 2024-02-21      NaN
# 3    NaN  NaN  ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP 2024-02-21      NaN
# 4    NaN  NaN  ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP 2024-02-20      NaN
# ..   ...  ...                                         ...        ...      ...
# 1    NaN  NaN                     Independent Expenditure 2024-01-30  SUPPORT
# 2    NaN  NaN                     Independent Expenditure 2024-01-26  SUPPORT
# 3    NaN  NaN                     Independent Expenditure 2024-01-31  SUPPORT
# 4    NaN  NaN                     Independent Expenditure 2024-01-21  SUPPORT
# 5    NaN  NaN                     Independent Expenditure 2024-01-24  SUPPORT
#
#         description
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ..              ...
# 1        ONLINE ADS
# 2        ONLINE ADS
# 3   DESIGN SERVICES
# 4        ONLINE ADS
# 5        ONLINE ADS
#
# [255 rows x 19 columns]

# %%
# add a column called contest that is equal to "zecher"

zecher_df['contest'] = 'zecher'

# %% [markdown]
# Begert

# %%
begert_1_late_df = pd.read_csv('./raw_files/begert_1_late.csv')

# %%
begert_2_late_df = pd.read_csv('./raw_files/begert_2_late.csv')

# %%
begert_1_all_df = pd.read_csv('./raw_files/begert_1_all.csv')

# %%
begert_2_all_df = pd.read_csv('./raw_files/begert_2_all.csv')

# %%
begert_1_late_df.columns = begert_1_late_df.columns.str.lower().str.replace(' ', '_')
begert_2_late_df.columns = begert_2_late_df.columns.str.lower().str.replace(' ', '_')
begert_1_all_df.columns = begert_1_all_df.columns.str.lower().str.replace(' ', '_')
begert_2_all_df.columns = begert_2_all_df.columns.str.lower().str.replace(' ', '_')

# %%
begert_1_late_df["committee_name"] = "BEGERT 2024; RETAIN JUDGE MICHAEL"
begert_1_all_df["committee_name"] = "BEGERT 2024; RETAIN JUDGE MICHAEL"
begert_2_late_df["committee_name"] = "BEGERT AND PATRICK THOMPSON; SAFE AND ACCOUNTABLE SAN FRANCISCO SUPPORTING THE RETENTION OF JUDGES MICHAEL ISAKU"
begert_2_all_df["committee_name"] ="BEGERT AND PATRICK THOMPSON; SAFE AND ACCOUNTABLE SAN FRANCISCO SUPPORTING THE RETENTION OF JUDGES MICHAEL ISAKU"

# %%
begert_1_late_df.head()
# Out:
#                                  name_of_contributor           city  \
# 0  SAFE AND ACCOUNTABLE SAN FRANCISCO SUPPORTING ...        OAKLAND
# 1                                       NEWTON J LAM     SAN RAFAEL
# 2  SAFE AND ACCOUNTABLE SAN FRANCISCO SUPPORTING ...        OAKLAND
# 3                                       MATTHEW GRAY  SAN FRANCISCO
# 4  CALIFORNIA ASIAN PACIFIC AMERICAN JUDGES ASSOC...        ALAMEDA
#
#     state/zip  id_number          employer occupation      amount  \
# 0  CA / 94607  1464402.0               NaN        NaN  $3,813.96
# 1  CA / 94903        NaN              NONE    RETIRED  $1,000.00
# 2  CA / 94607  1464402.0               NaN        NaN  $7,500.00
# 3  CA / 94115        NaN  PERKINS COIE LLP   ATTORNEY  $1,000.00
# 4  CA / 94501  1402811.0               NaN        NaN  $5,000.00
#
#              transaction_type     type transaction_date  filed_date  \
# 0  LATE CONTRIBUTION RECEIVED  INITIAL       02/25/2024  02/26/2024
# 1  LATE CONTRIBUTION RECEIVED  INITIAL       02/23/2024  02/23/2024
# 2  LATE CONTRIBUTION RECEIVED  INITIAL       02/18/2024  02/20/2024
# 3  LATE CONTRIBUTION RECEIVED  INITIAL       02/16/2024  02/20/2024
# 4  LATE CONTRIBUTION RECEIVED  INITIAL       02/16/2024  02/16/2024
#
#   transaction_number                     committee_name
# 0     2897168-NON705  BEGERT 2024; RETAIN JUDGE MICHAEL
# 1     2895747-INC694  BEGERT 2024; RETAIN JUDGE MICHAEL
# 2     2892878-NON661  BEGERT 2024; RETAIN JUDGE MICHAEL
# 3     2892878-INC653  BEGERT 2024; RETAIN JUDGE MICHAEL
# 4     2892063-INC652  BEGERT 2024; RETAIN JUDGE MICHAEL

# %%
begert_2_late_df.head()
# Out:
#                              name_of_contributor           city  \
# 0  SAN FRANCISCO LEAGUE OF PISSED OFF VOTERS SMO  SAN FRANCISCO
# 1                                   DEAN PRESTON  SAN FRANCISCO
# 2                                   GAIL DEKREON  SAN FRANCISCO
# 3                                     LILAH WOLF  SAN FRANCISCO
# 4                                     JOHN KEKER  SAN FRANCISCO
#
#          state/zip  id_number                                employer  \
# 0       CA / 94110  1432377.0                                     NaN
# 1       CA / 94117        NaN        CITY AND COUNTY OF SAN FRANCISCO
# 2       CA / 94124        NaN                                     NaN
# 3       CA / 94103        NaN  SAN FRANCISCO PUBLIC DEFENDER'S OFFICE
# 4  CA / 94111-1809        NaN               KEKER VAN NEST AND PETERS
#
#                occupation      amount            transaction_type     type  \
# 0                     NaN  $5,000.00   LATE CONTRIBUTION RECEIVED  INITIAL
# 1   DISTRICT 5 SUPERVISOR  $1,000.00   LATE CONTRIBUTION RECEIVED  INITIAL
# 2                 RETIRED  $1,000.00   LATE CONTRIBUTION RECEIVED  INITIAL
# 3  DEPUTY PUBLIC DEFENDER  $2,000.00   LATE CONTRIBUTION RECEIVED  INITIAL
# 4                ATTORNEY  $2,000.00   LATE CONTRIBUTION RECEIVED  INITIAL
#
#   transaction_date  filed_date transaction_number  \
# 0       01/31/2024  02/21/2024     2894188-NON298
# 1       02/18/2024  02/20/2024     2893256-INC296
# 2       02/14/2024  02/15/2024     2891868-INC286
# 3       02/06/2024  02/07/2024     2888963-INC265
# 4       02/02/2024  02/05/2024     2886104-INC252
#
#                                       committee_name
# 0  BEGERT AND PATRICK THOMPSON; SAFE AND ACCOUNTA...
# 1  BEGERT AND PATRICK THOMPSON; SAFE AND ACCOUNTA...
# 2  BEGERT AND PATRICK THOMPSON; SAFE AND ACCOUNTA...
# 3  BEGERT AND PATRICK THOMPSON; SAFE AND ACCOUNTA...
# 4  BEGERT AND PATRICK THOMPSON; SAFE AND ACCOUNTA...

# %%
begert_1_all_df.head()
# Out:
#   name_of_contributor payment_type             city state    zip  id_number  \
# 0         STEVE ROSEN     MONETARY  WEST LAKE HILLS    TX  78746        NaN
# 1     DONALD SULLIVAN     MONETARY      MILL VALLEY    CA  94941        NaN
# 2        LILLIAN SING     MONETARY    SAN FRANCISCO    CA  94122        NaN
# 3     ANTHONY MCNAMER     MONETARY         PORTLAND    OR  97214        NaN
# 4        CHRIS CANNON     MONETARY          TIBURON    CA  94920        NaN
#
#                             employer     occupation    amount  \
# 0  THE UNIVERSITY OF TEXAS AT AUSTIN       ATTORNEY  $250.00
# 1                               NONE  RETIRED JUDGE  $250.00
# 2                               NONE        RETIRED  $100.00
# 3                               NONE        RETIRED  $200.00
# 4           SELF-EMPLOYED; SAME NAME         LAWYER  $100.00
#
#   transaction_date filed_date transaction_number  \
# 0         1/1/2024  2/21/2024   2873432 - INC312
# 1         1/1/2024  2/21/2024   2873432 - INC313
# 2         1/1/2024  2/21/2024   2873432 - INC314
# 3         1/1/2024  2/21/2024   2873432 - INC316
# 4         1/1/2024  2/21/2024   2873432 - INC317
#
#                       committee_name
# 0  BEGERT 2024; RETAIN JUDGE MICHAEL
# 1  BEGERT 2024; RETAIN JUDGE MICHAEL
# 2  BEGERT 2024; RETAIN JUDGE MICHAEL
# 3  BEGERT 2024; RETAIN JUDGE MICHAEL
# 4  BEGERT 2024; RETAIN JUDGE MICHAEL

# %%
begert_2_all_df.head()
# Out:
#   name_of_contributor payment_type           city state    zip  id_number  \
# 0       MERIDEE MOORE     MONETARY  SAN FRANCISCO    CA  94118        NaN
# 1  WILLIAM OSTERHOUDT     MONETARY  SAN FRANCISCO    CA  94108        NaN
# 2      WILLIAM WILSON     MONETARY  HALF MOON BAY    CA  94019        NaN
# 3          ALLEN RUBY     MONETARY       SARATOGA    CA  95070        NaN
# 4        WARD PENFOLD     MONETARY     KENSINGTON    CA  94707        NaN
#
#                           employer              occupation      amount  \
# 0  WATERSHED ASSET MANAGEMENT, LLC  SENIOR MANAGING MEMBER    $250.00
# 1                   OSTERHOUDT LAW                  LAWYER    $250.00
# 2             HAYNES AND BOONE LLP                  LAWYER    $250.00
# 3                       ALLEN RUBY                  LAWYER  $1,000.00
# 4             LATHAM & WATKINS LLP                ATTORNEY  $1,000.00
#
#   transaction_date filed_date transaction_number  \
# 0        1/13/2024  1/25/2024   2872960 - INC100
# 1        1/13/2024  1/25/2024   2872960 - INC101
# 2        1/15/2024  1/25/2024   2872960 - INC102
# 3        1/15/2024  1/25/2024   2872960 - INC103
# 4        1/16/2024  1/25/2024   2872960 - INC104
#
#                                       committee_name
# 0  BEGERT AND PATRICK THOMPSON; SAFE AND ACCOUNTA...
# 1  BEGERT AND PATRICK THOMPSON; SAFE AND ACCOUNTA...
# 2  BEGERT AND PATRICK THOMPSON; SAFE AND ACCOUNTA...
# 3  BEGERT AND PATRICK THOMPSON; SAFE AND ACCOUNTA...
# 4  BEGERT AND PATRICK THOMPSON; SAFE AND ACCOUNTA...

# %%
# concatenate the dataframes

begert_df = pd.concat([begert_1_late_df, begert_2_late_df, begert_1_all_df, begert_2_all_df])

# %%
begert_df
# Out:
#                                    name_of_contributor           city  \
# 0    SAFE AND ACCOUNTABLE SAN FRANCISCO SUPPORTING ...        OAKLAND
# 1                                         NEWTON J LAM     SAN RAFAEL
# 2    SAFE AND ACCOUNTABLE SAN FRANCISCO SUPPORTING ...        OAKLAND
# 3                                         MATTHEW GRAY  SAN FRANCISCO
# 4    CALIFORNIA ASIAN PACIFIC AMERICAN JUDGES ASSOC...        ALAMEDA
# ..                                                 ...            ...
# 129                                      DICK GROSBOLL  SAN FRANCISCO
# 130                                        MEGAN JANIS  SAN FRANCISCO
# 131                                   DANIEL WEINSTEIN  SAN FRANCISCO
# 132                                       GAIL DEKREON  SAN FRANCISCO
# 133                                      STUART HANLON  SAN FRANCISCO
#
#       state/zip  id_number                         employer  \
# 0    CA / 94607  1464402.0                              NaN
# 1    CA / 94903        NaN                             NONE
# 2    CA / 94607  1464402.0                              NaN
# 3    CA / 94115        NaN                 PERKINS COIE LLP
# 4    CA / 94501  1402811.0                              NaN
# ..          ...        ...                              ...
# 129         NaN        NaN  NEYHART ANDERSON FLYNN GROSBOLL
# 130         NaN        NaN              ABBOTT LABORATORIES
# 131         NaN        NaN                              NaN
# 132         NaN        NaN                              NaN
# 133         NaN        NaN      LAW OFFICE OF STUART HANLON
#
#                     occupation      amount            transaction_type  \
# 0                          NaN  $3,813.96   LATE CONTRIBUTION RECEIVED
# 1                      RETIRED  $1,000.00   LATE CONTRIBUTION RECEIVED
# 2                          NaN  $7,500.00   LATE CONTRIBUTION RECEIVED
# 3                     ATTORNEY  $1,000.00   LATE CONTRIBUTION RECEIVED
# 4                          NaN  $5,000.00   LATE CONTRIBUTION RECEIVED
# ..                         ...         ...                         ...
# 129                   ATTORNEY    $500.00                          NaN
# 130         COMPLIANCE OFFICER    $250.00                          NaN
# 131                    RETIRED    $500.00                          NaN
# 132                    RETIRED  $1,000.00                          NaN
# 133  CRIMINAL DEFENSE ATTORNEY    $150.00                          NaN
#
#         type transaction_date  filed_date transaction_number  \
# 0    INITIAL       02/25/2024  02/26/2024     2897168-NON705
# 1    INITIAL       02/23/2024  02/23/2024     2895747-INC694
# 2    INITIAL       02/18/2024  02/20/2024     2892878-NON661
# 3    INITIAL       02/16/2024  02/20/2024     2892878-INC653
# 4    INITIAL       02/16/2024  02/16/2024     2892063-INC652
# ..       ...              ...         ...                ...
# 129      NaN        2/13/2024   2/22/2024   2895026 - INC274
# 130      NaN        2/12/2024   2/22/2024   2895026 - INC275
# 131      NaN        2/15/2024   2/22/2024   2895026 - INC285
# 132      NaN        2/14/2024   2/22/2024   2895026 - INC286
# 133      NaN        2/13/2024   2/22/2024   2895026 - INC287
#
#                                         committee_name payment_type state  \
# 0                    BEGERT 2024; RETAIN JUDGE MICHAEL          NaN   NaN
# 1                    BEGERT 2024; RETAIN JUDGE MICHAEL          NaN   NaN
# 2                    BEGERT 2024; RETAIN JUDGE MICHAEL          NaN   NaN
# 3                    BEGERT 2024; RETAIN JUDGE MICHAEL          NaN   NaN
# 4                    BEGERT 2024; RETAIN JUDGE MICHAEL          NaN   NaN
# ..                                                 ...          ...   ...
# 129  BEGERT AND PATRICK THOMPSON; SAFE AND ACCOUNTA...     MONETARY    CA
# 130  BEGERT AND PATRICK THOMPSON; SAFE AND ACCOUNTA...     MONETARY    CA
# 131  BEGERT AND PATRICK THOMPSON; SAFE AND ACCOUNTA...     MONETARY    CA
# 132  BEGERT AND PATRICK THOMPSON; SAFE AND ACCOUNTA...     MONETARY    CA
# 133  BEGERT AND PATRICK THOMPSON; SAFE AND ACCOUNTA...     MONETARY    CA
#
#        zip
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ..     ...
# 129  94104
# 130  94118
# 131  94111
# 132  94124
# 133  94117
#
# [619 rows x 16 columns]

# %%
begert_df['date'] = pd.to_datetime(begert_df['transaction_date'], format='%m/%d/%Y')

# %%
begert_df['amount'] = begert_df['amount'].str.replace('$', '')
# Out:
# /var/folders/_0/x7xh_2c16jq4chdcqrg28fr40000gn/T/ipykernel_1433/3088740851.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   begert_df['amount'] = begert_df['amount'].str.replace('$', '')

# %%
begert_df['amount'] = begert_df['amount'].str.replace(',', '')

# %%
begert_df['amount'] = begert_df['amount'].astype(float)

# %%
begert_df['transaction_number'] = begert_df['transaction_number'].str.replace(' - ', '-')

# %%
begert_df
# Out:
#                                    name_of_contributor           city  \
# 0    SAFE AND ACCOUNTABLE SAN FRANCISCO SUPPORTING ...        OAKLAND
# 1                                         NEWTON J LAM     SAN RAFAEL
# 2    SAFE AND ACCOUNTABLE SAN FRANCISCO SUPPORTING ...        OAKLAND
# 3                                         MATTHEW GRAY  SAN FRANCISCO
# 4    CALIFORNIA ASIAN PACIFIC AMERICAN JUDGES ASSOC...        ALAMEDA
# ..                                                 ...            ...
# 129                                      DICK GROSBOLL  SAN FRANCISCO
# 130                                        MEGAN JANIS  SAN FRANCISCO
# 131                                   DANIEL WEINSTEIN  SAN FRANCISCO
# 132                                       GAIL DEKREON  SAN FRANCISCO
# 133                                      STUART HANLON  SAN FRANCISCO
#
#       state/zip  id_number                         employer  \
# 0    CA / 94607  1464402.0                              NaN
# 1    CA / 94903        NaN                             NONE
# 2    CA / 94607  1464402.0                              NaN
# 3    CA / 94115        NaN                 PERKINS COIE LLP
# 4    CA / 94501  1402811.0                              NaN
# ..          ...        ...                              ...
# 129         NaN        NaN  NEYHART ANDERSON FLYNN GROSBOLL
# 130         NaN        NaN              ABBOTT LABORATORIES
# 131         NaN        NaN                              NaN
# 132         NaN        NaN                              NaN
# 133         NaN        NaN      LAW OFFICE OF STUART HANLON
#
#                     occupation   amount            transaction_type     type  \
# 0                          NaN  3813.96  LATE CONTRIBUTION RECEIVED  INITIAL
# 1                      RETIRED  1000.00  LATE CONTRIBUTION RECEIVED  INITIAL
# 2                          NaN  7500.00  LATE CONTRIBUTION RECEIVED  INITIAL
# 3                     ATTORNEY  1000.00  LATE CONTRIBUTION RECEIVED  INITIAL
# 4                          NaN  5000.00  LATE CONTRIBUTION RECEIVED  INITIAL
# ..                         ...      ...                         ...      ...
# 129                   ATTORNEY   500.00                         NaN      NaN
# 130         COMPLIANCE OFFICER   250.00                         NaN      NaN
# 131                    RETIRED   500.00                         NaN      NaN
# 132                    RETIRED  1000.00                         NaN      NaN
# 133  CRIMINAL DEFENSE ATTORNEY   150.00                         NaN      NaN
#
#     transaction_date  filed_date transaction_number  \
# 0         02/25/2024  02/26/2024     2897168-NON705
# 1         02/23/2024  02/23/2024     2895747-INC694
# 2         02/18/2024  02/20/2024     2892878-NON661
# 3         02/16/2024  02/20/2024     2892878-INC653
# 4         02/16/2024  02/16/2024     2892063-INC652
# ..               ...         ...                ...
# 129        2/13/2024   2/22/2024     2895026-INC274
# 130        2/12/2024   2/22/2024     2895026-INC275
# 131        2/15/2024   2/22/2024     2895026-INC285
# 132        2/14/2024   2/22/2024     2895026-INC286
# 133        2/13/2024   2/22/2024     2895026-INC287
#
#                                         committee_name payment_type state  \
# 0                    BEGERT 2024; RETAIN JUDGE MICHAEL          NaN   NaN
# 1                    BEGERT 2024; RETAIN JUDGE MICHAEL          NaN   NaN
# 2                    BEGERT 2024; RETAIN JUDGE MICHAEL          NaN   NaN
# 3                    BEGERT 2024; RETAIN JUDGE MICHAEL          NaN   NaN
# 4                    BEGERT 2024; RETAIN JUDGE MICHAEL          NaN   NaN
# ..                                                 ...          ...   ...
# 129  BEGERT AND PATRICK THOMPSON; SAFE AND ACCOUNTA...     MONETARY    CA
# 130  BEGERT AND PATRICK THOMPSON; SAFE AND ACCOUNTA...     MONETARY    CA
# 131  BEGERT AND PATRICK THOMPSON; SAFE AND ACCOUNTA...     MONETARY    CA
# 132  BEGERT AND PATRICK THOMPSON; SAFE AND ACCOUNTA...     MONETARY    CA
# 133  BEGERT AND PATRICK THOMPSON; SAFE AND ACCOUNTA...     MONETARY    CA
#
#        zip       date
# 0      NaN 2024-02-25
# 1      NaN 2024-02-23
# 2      NaN 2024-02-18
# 3      NaN 2024-02-16
# 4      NaN 2024-02-16
# ..     ...        ...
# 129  94104 2024-02-13
# 130  94118 2024-02-12
# 131  94111 2024-02-15
# 132  94124 2024-02-14
# 133  94117 2024-02-13
#
# [619 rows x 17 columns]

# %%
begert_df[begert_df.duplicated(subset=['name_of_contributor', 'amount', 'date','transaction_type'], keep=False)]
# Out:
#     name_of_contributor           city   state/zip  id_number  \
# 25   VIDHYA PRABHAKARAN  SAN FRANCISCO  CA / 94127        NaN
# 27   VIDHYA PRABHAKARAN  SAN FRANCISCO  CA / 94127        NaN
# 36   VIDHYA PRABHAKARAN  SAN FRANCISCO         NaN        NaN
# 112      MICHAEL BEGERT       PIEDMONT         NaN        NaN
# 400      MICHAEL BEGERT       PIEDMONT         NaN        NaN
# 68   VIDHYA PRABHAKARAN  SAN FRANCISCO         NaN        NaN
#
#                                    employer occupation  amount  \
# 25                DAVIS WRIGHT TREMAINE LLP   ATTORNEY  1000.0
# 27                DAVIS WRIGHT TREMAINE LLP   ATTORNEY  1000.0
# 36                DAVIS WRIGHT TREMAINE LLP   ATTORNEY  1000.0
# 112  SUPERIOR COURT OF SAN FRANCISCO COUNTY      JUDGE     0.0
# 400  SUPERIOR COURT OF SAN FRANCISCO COUNTY      JUDGE     0.0
# 68                DAVIS WRIGHT TREMAINE LLP   ATTORNEY  1000.0
#
#                transaction_type     type transaction_date  filed_date  \
# 25   LATE CONTRIBUTION RECEIVED  INITIAL       01/08/2024  01/08/2024
# 27   LATE CONTRIBUTION RECEIVED  INITIAL       01/08/2024  01/09/2024
# 36                          NaN      NaN         1/8/2024   2/21/2024
# 112                         NaN      NaN       10/18/2023   2/21/2024
# 400                         NaN      NaN       10/18/2023   2/21/2024
# 68                          NaN      NaN         1/8/2024   1/25/2024
#
#     transaction_number                                     committee_name  \
# 25      2865105-INC354                  BEGERT 2024; RETAIN JUDGE MICHAEL
# 27       2865506-INC91  BEGERT AND PATRICK THOMPSON; SAFE AND ACCOUNTA...
# 36      2873432-INC354                  BEGERT 2024; RETAIN JUDGE MICHAEL
# 112      2873432-PAY17                  BEGERT 2024; RETAIN JUDGE MICHAEL
# 400      2893895-PAY17                  BEGERT 2024; RETAIN JUDGE MICHAEL
# 68       2872960-INC91  BEGERT AND PATRICK THOMPSON; SAFE AND ACCOUNTA...
#
#     payment_type state    zip       date
# 25           NaN   NaN    NaN 2024-01-08
# 27           NaN   NaN    NaN 2024-01-08
# 36      MONETARY    CA  94127 2024-01-08
# 112         LOAN    CA  94611 2023-10-18
# 400         LOAN    CA  94611 2023-10-18
# 68      MONETARY    CA  94127 2024-01-08

# %% [markdown]
# Checked these on PDFs, they are duplicates. Vidhya only donated once.

# %%
begert_df = begert_df.drop_duplicates(subset=['date', 'amount', 'name_of_contributor'])

# %%
begert_df
# Out:
#                                    name_of_contributor           city  \
# 0    SAFE AND ACCOUNTABLE SAN FRANCISCO SUPPORTING ...        OAKLAND
# 1                                         NEWTON J LAM     SAN RAFAEL
# 2    SAFE AND ACCOUNTABLE SAN FRANCISCO SUPPORTING ...        OAKLAND
# 3                                         MATTHEW GRAY  SAN FRANCISCO
# 4    CALIFORNIA ASIAN PACIFIC AMERICAN JUDGES ASSOC...        ALAMEDA
# ..                                                 ...            ...
# 128                                      HARRIS TABACK  SAN FRANCISCO
# 129                                      DICK GROSBOLL  SAN FRANCISCO
# 130                                        MEGAN JANIS  SAN FRANCISCO
# 131                                   DANIEL WEINSTEIN  SAN FRANCISCO
# 133                                      STUART HANLON  SAN FRANCISCO
#
#       state/zip  id_number                         employer  \
# 0    CA / 94607  1464402.0                              NaN
# 1    CA / 94903        NaN                             NONE
# 2    CA / 94607  1464402.0                              NaN
# 3    CA / 94115        NaN                 PERKINS COIE LLP
# 4    CA / 94501  1402811.0                              NaN
# ..          ...        ...                              ...
# 128         NaN        NaN      LAW OFFICE OF HARRIS TABACK
# 129         NaN        NaN  NEYHART ANDERSON FLYNN GROSBOLL
# 130         NaN        NaN              ABBOTT LABORATORIES
# 131         NaN        NaN                              NaN
# 133         NaN        NaN      LAW OFFICE OF STUART HANLON
#
#                     occupation   amount            transaction_type     type  \
# 0                          NaN  3813.96  LATE CONTRIBUTION RECEIVED  INITIAL
# 1                      RETIRED  1000.00  LATE CONTRIBUTION RECEIVED  INITIAL
# 2                          NaN  7500.00  LATE CONTRIBUTION RECEIVED  INITIAL
# 3                     ATTORNEY  1000.00  LATE CONTRIBUTION RECEIVED  INITIAL
# 4                          NaN  5000.00  LATE CONTRIBUTION RECEIVED  INITIAL
# ..                         ...      ...                         ...      ...
# 128                   ATTORNEY   250.00                         NaN      NaN
# 129                   ATTORNEY   500.00                         NaN      NaN
# 130         COMPLIANCE OFFICER   250.00                         NaN      NaN
# 131                    RETIRED   500.00                         NaN      NaN
# 133  CRIMINAL DEFENSE ATTORNEY   150.00                         NaN      NaN
#
#     transaction_date  filed_date transaction_number  \
# 0         02/25/2024  02/26/2024     2897168-NON705
# 1         02/23/2024  02/23/2024     2895747-INC694
# 2         02/18/2024  02/20/2024     2892878-NON661
# 3         02/16/2024  02/20/2024     2892878-INC653
# 4         02/16/2024  02/16/2024     2892063-INC652
# ..               ...         ...                ...
# 128        2/11/2024   2/22/2024     2895026-INC269
# 129        2/13/2024   2/22/2024     2895026-INC274
# 130        2/12/2024   2/22/2024     2895026-INC275
# 131        2/15/2024   2/22/2024     2895026-INC285
# 133        2/13/2024   2/22/2024     2895026-INC287
#
#                                         committee_name payment_type state  \
# 0                    BEGERT 2024; RETAIN JUDGE MICHAEL          NaN   NaN
# 1                    BEGERT 2024; RETAIN JUDGE MICHAEL          NaN   NaN
# 2                    BEGERT 2024; RETAIN JUDGE MICHAEL          NaN   NaN
# 3                    BEGERT 2024; RETAIN JUDGE MICHAEL          NaN   NaN
# 4                    BEGERT 2024; RETAIN JUDGE MICHAEL          NaN   NaN
# ..                                                 ...          ...   ...
# 128  BEGERT AND PATRICK THOMPSON; SAFE AND ACCOUNTA...     MONETARY    CA
# 129  BEGERT AND PATRICK THOMPSON; SAFE AND ACCOUNTA...     MONETARY    CA
# 130  BEGERT AND PATRICK THOMPSON; SAFE AND ACCOUNTA...     MONETARY    CA
# 131  BEGERT AND PATRICK THOMPSON; SAFE AND ACCOUNTA...     MONETARY    CA
# 133  BEGERT AND PATRICK THOMPSON; SAFE AND ACCOUNTA...     MONETARY    CA
#
#        zip       date
# 0      NaN 2024-02-25
# 1      NaN 2024-02-23
# 2      NaN 2024-02-18
# 3      NaN 2024-02-16
# 4      NaN 2024-02-16
# ..     ...        ...
# 128  94117 2024-02-11
# 129  94104 2024-02-13
# 130  94118 2024-02-12
# 131  94111 2024-02-15
# 133  94117 2024-02-13
#
# [539 rows x 17 columns]

# %%
begert_df[begert_df.duplicated(subset=['transaction_number'], keep=False)]
# Out:
# Empty DataFrame
# Columns: [name_of_contributor, city, state/zip, id_number, employer, occupation, amount, transaction_type, type, transaction_date, filed_date, transaction_number, committee_name, payment_type, state, zip, date]
# Index: []

# %%
begert_df['contest'] = 'begert'
# Out:
# /var/folders/_0/x7xh_2c16jq4chdcqrg28fr40000gn/T/ipykernel_1433/653920462.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   begert_df['contest'] = 'begert'

# %%
begert_df
# Out:
#                                    name_of_contributor           city  \
# 0    SAFE AND ACCOUNTABLE SAN FRANCISCO SUPPORTING ...        OAKLAND
# 1                                         NEWTON J LAM     SAN RAFAEL
# 2    SAFE AND ACCOUNTABLE SAN FRANCISCO SUPPORTING ...        OAKLAND
# 3                                         MATTHEW GRAY  SAN FRANCISCO
# 4    CALIFORNIA ASIAN PACIFIC AMERICAN JUDGES ASSOC...        ALAMEDA
# ..                                                 ...            ...
# 128                                      HARRIS TABACK  SAN FRANCISCO
# 129                                      DICK GROSBOLL  SAN FRANCISCO
# 130                                        MEGAN JANIS  SAN FRANCISCO
# 131                                   DANIEL WEINSTEIN  SAN FRANCISCO
# 133                                      STUART HANLON  SAN FRANCISCO
#
#       state/zip  id_number                         employer  \
# 0    CA / 94607  1464402.0                              NaN
# 1    CA / 94903        NaN                             NONE
# 2    CA / 94607  1464402.0                              NaN
# 3    CA / 94115        NaN                 PERKINS COIE LLP
# 4    CA / 94501  1402811.0                              NaN
# ..          ...        ...                              ...
# 128         NaN        NaN      LAW OFFICE OF HARRIS TABACK
# 129         NaN        NaN  NEYHART ANDERSON FLYNN GROSBOLL
# 130         NaN        NaN              ABBOTT LABORATORIES
# 131         NaN        NaN                              NaN
# 133         NaN        NaN      LAW OFFICE OF STUART HANLON
#
#                     occupation   amount            transaction_type     type  \
# 0                          NaN  3813.96  LATE CONTRIBUTION RECEIVED  INITIAL
# 1                      RETIRED  1000.00  LATE CONTRIBUTION RECEIVED  INITIAL
# 2                          NaN  7500.00  LATE CONTRIBUTION RECEIVED  INITIAL
# 3                     ATTORNEY  1000.00  LATE CONTRIBUTION RECEIVED  INITIAL
# 4                          NaN  5000.00  LATE CONTRIBUTION RECEIVED  INITIAL
# ..                         ...      ...                         ...      ...
# 128                   ATTORNEY   250.00                         NaN      NaN
# 129                   ATTORNEY   500.00                         NaN      NaN
# 130         COMPLIANCE OFFICER   250.00                         NaN      NaN
# 131                    RETIRED   500.00                         NaN      NaN
# 133  CRIMINAL DEFENSE ATTORNEY   150.00                         NaN      NaN
#
#     transaction_date  filed_date transaction_number  \
# 0         02/25/2024  02/26/2024     2897168-NON705
# 1         02/23/2024  02/23/2024     2895747-INC694
# 2         02/18/2024  02/20/2024     2892878-NON661
# 3         02/16/2024  02/20/2024     2892878-INC653
# 4         02/16/2024  02/16/2024     2892063-INC652
# ..               ...         ...                ...
# 128        2/11/2024   2/22/2024     2895026-INC269
# 129        2/13/2024   2/22/2024     2895026-INC274
# 130        2/12/2024   2/22/2024     2895026-INC275
# 131        2/15/2024   2/22/2024     2895026-INC285
# 133        2/13/2024   2/22/2024     2895026-INC287
#
#                                         committee_name payment_type state  \
# 0                    BEGERT 2024; RETAIN JUDGE MICHAEL          NaN   NaN
# 1                    BEGERT 2024; RETAIN JUDGE MICHAEL          NaN   NaN
# 2                    BEGERT 2024; RETAIN JUDGE MICHAEL          NaN   NaN
# 3                    BEGERT 2024; RETAIN JUDGE MICHAEL          NaN   NaN
# 4                    BEGERT 2024; RETAIN JUDGE MICHAEL          NaN   NaN
# ..                                                 ...          ...   ...
# 128  BEGERT AND PATRICK THOMPSON; SAFE AND ACCOUNTA...     MONETARY    CA
# 129  BEGERT AND PATRICK THOMPSON; SAFE AND ACCOUNTA...     MONETARY    CA
# 130  BEGERT AND PATRICK THOMPSON; SAFE AND ACCOUNTA...     MONETARY    CA
# 131  BEGERT AND PATRICK THOMPSON; SAFE AND ACCOUNTA...     MONETARY    CA
# 133  BEGERT AND PATRICK THOMPSON; SAFE AND ACCOUNTA...     MONETARY    CA
#
#        zip       date contest
# 0      NaN 2024-02-25  begert
# 1      NaN 2024-02-23  begert
# 2      NaN 2024-02-18  begert
# 3      NaN 2024-02-16  begert
# 4      NaN 2024-02-16  begert
# ..     ...        ...     ...
# 128  94117 2024-02-11  begert
# 129  94104 2024-02-13  begert
# 130  94118 2024-02-12  begert
# 131  94111 2024-02-15  begert
# 133  94117 2024-02-13  begert
#
# [539 rows x 18 columns]

# %% [markdown]
# Roland

# %%
roland_late_df = pd.read_csv('./raw_files/roland_late.csv')

# %%
roland_all_df = pd.read_csv('./raw_files/roland_all.csv')

# %%
roland_late_df["committee_name"] = "ROLAND FOR SUPERIOR COURT JUDGE 2024; JEAN MYUNGJIN"
roland_all_df["committee_name"] = "ROLAND FOR SUPERIOR COURT JUDGE 2024; JEAN MYUNGJIN"

# %%
roland_late_df.columns = roland_late_df.columns.str.lower().str.replace(' ', '_')
roland_all_df.columns = roland_all_df.columns.str.lower().str.replace(' ', '_')

# %%
roland_df = pd.concat([roland_late_df, roland_all_df])

# %%
roland_df
# Out:
#                            name_of_contributor           city   state/zip  \
# 0    CHIP ZECHER FOR SUPERIOR COURT JUDGE 2024  SAN FRANCISCO  CA / 94118
# 1    CHIP ZECHER FOR SUPERIOR COURT JUDGE 2024  SAN FRANCISCO  CA / 94118
# 2                             PG&E CORPORATION        OAKLAND  CA / 94612
# 3                             AS&P CORPORATION     UNION CITY  CA / 94587
# 4                                TIMOTHY MARKS  SAN FRANCISCO  CA / 94108
# ..                                         ...            ...         ...
# 220                            CYRUS SANANDAJI  SAN FRANCISCO         NaN
# 221                                MARK CONROE  SAN FRANCISCO         NaN
# 222                             HOLLY PETERSON  SAN FRANCISCO         NaN
# 223                           ALLISON ESPESETH  SAN FRANCISCO         NaN
# 224                               TANGUY SERRA  SAN FRANCISCO         NaN
#
#      id_number                           employer  \
# 0    1463380.0                                NaN
# 1    1463380.0                                NaN
# 2          NaN                                NaN
# 3          NaN                                NaN
# 4          NaN             TUCKER AND MARKS, INC.
# ..         ...                                ...
# 220        NaN              PRESIDIO BAY VENTURES
# 221        NaN  PRESIDIO DEVELOPMENT PARTNERS LLC
# 222        NaN                               NONE
# 223        NaN            SELF-EMPLOYED/SAME NAME
# 224        NaN                          GOODFINCH
#
#                          occupation       amount            transaction_type  \
# 0                               NaN   $9,516.45   LATE CONTRIBUTION RECEIVED
# 1                               NaN  $17,500.00   LATE CONTRIBUTION RECEIVED
# 2                               NaN   $5,000.00   LATE CONTRIBUTION RECEIVED
# 3                               NaN   $1,000.00   LATE CONTRIBUTION RECEIVED
# 4                MANAGING PRINCIPAL   $1,000.00   LATE CONTRIBUTION RECEIVED
# ..                              ...          ...                         ...
# 220              MANAGING PRINCIPAL     $500.00                          NaN
# 221           REAL ESTATE DEVELOPER     $100.00                          NaN
# 222                         RETIRED     $500.00                          NaN
# 223  STRATEGIC MARKETING CONSULTANT     $100.00                          NaN
# 224                        INVESTOR     $100.00                          NaN
#
#         type transaction_date  filed_date transaction_number  \
# 0    INITIAL       02/22/2024  02/22/2024     2895403-NON445
# 1    INITIAL       02/22/2024  02/22/2024     2895403-NON444
# 2    INITIAL       02/21/2024  02/22/2024     2895403-INC443
# 3    INITIAL       02/21/2024  02/22/2024     2895403-INC442
# 4    INITIAL       02/20/2024  02/21/2024     2894178-INC413
# ..       ...              ...         ...                ...
# 220      NaN        1/12/2024   1/25/2024   2873353 - INC223
# 221      NaN        1/11/2024   1/25/2024   2873353 - INC224
# 222      NaN        1/11/2024   1/25/2024   2873353 - INC225
# 223      NaN        1/11/2024   1/25/2024   2873353 - INC226
# 224      NaN        1/11/2024   1/25/2024   2873353 - INC228
#
#                                         committee_name payment_type state  \
# 0    ROLAND FOR SUPERIOR COURT JUDGE 2024; JEAN MYU...          NaN   NaN
# 1    ROLAND FOR SUPERIOR COURT JUDGE 2024; JEAN MYU...          NaN   NaN
# 2    ROLAND FOR SUPERIOR COURT JUDGE 2024; JEAN MYU...          NaN   NaN
# 3    ROLAND FOR SUPERIOR COURT JUDGE 2024; JEAN MYU...          NaN   NaN
# 4    ROLAND FOR SUPERIOR COURT JUDGE 2024; JEAN MYU...          NaN   NaN
# ..                                                 ...          ...   ...
# 220  ROLAND FOR SUPERIOR COURT JUDGE 2024; JEAN MYU...     MONETARY    CA
# 221  ROLAND FOR SUPERIOR COURT JUDGE 2024; JEAN MYU...     MONETARY    CA
# 222  ROLAND FOR SUPERIOR COURT JUDGE 2024; JEAN MYU...     MONETARY    CA
# 223  ROLAND FOR SUPERIOR COURT JUDGE 2024; JEAN MYU...     MONETARY    CA
# 224  ROLAND FOR SUPERIOR COURT JUDGE 2024; JEAN MYU...     MONETARY    CA
#
#          zip
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ..       ...
# 220  94111.0
# 221  94123.0
# 222  94118.0
# 223  94115.0
# 224  94115.0
#
# [268 rows x 16 columns]

# %%
roland_df['date'] = pd.to_datetime(roland_df['transaction_date'], format='%m/%d/%Y')

# %%
roland_df['amount'] = roland_df['amount'].str.replace('$', '')
# Out:
# /var/folders/_0/x7xh_2c16jq4chdcqrg28fr40000gn/T/ipykernel_1433/542461781.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   roland_df['amount'] = roland_df['amount'].str.replace('$', '')

# %%
roland_df['amount'] = roland_df['amount'].str.replace(',', '')

# %%
roland_df['amount'] = roland_df['amount'].str.replace('(', '-')
# Out:
# /var/folders/_0/x7xh_2c16jq4chdcqrg28fr40000gn/T/ipykernel_1433/1733581832.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   roland_df['amount'] = roland_df['amount'].str.replace('(', '-')

# %%
roland_df['amount'] = roland_df['amount'].str.replace(')', '')
# Out:
# /var/folders/_0/x7xh_2c16jq4chdcqrg28fr40000gn/T/ipykernel_1433/1961913788.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   roland_df['amount'] = roland_df['amount'].str.replace(')', '')

# %%
roland_df['amount'] = roland_df['amount'].astype(float)

# %%
roland_df['transaction_number'] = roland_df['transaction_number'].str.replace(' - ', '-')

# %%
roland_df[roland_df.duplicated(subset=['name_of_contributor', 'amount', 'date','transaction_type'], keep=False)]
# Out:
# Empty DataFrame
# Columns: [name_of_contributor, city, state/zip, id_number, employer, occupation, amount, transaction_type, type, transaction_date, filed_date, transaction_number, committee_name, payment_type, state, zip, date]
# Index: []

# %%
roland_df[roland_df.duplicated(subset=['name_of_contributor', 'amount', 'date'], keep=False)]
# Out:
#                                name_of_contributor           city   state/zip  \
# 7        CHIP ZECHER FOR SUPERIOR COURT JUDGE 2024  SAN FRANCISCO  CA / 94118
# 8        CHIP ZECHER FOR SUPERIOR COURT JUDGE 2024  SAN FRANCISCO  CA / 94118
# 9        CHIP ZECHER FOR SUPERIOR COURT JUDGE 2024  SAN FRANCISCO  CA / 94118
# 10          GFC COURAGE COMMITTEE - SIERRA CHAPTER     SAN RAFAEL  CA / 94901
# 11   SAN FRANCISCO POLICE OFFICERS ASSOCIATION PAC  SAN FRANCISCO  CA / 94103
# ..                                             ...            ...         ...
# 125                                 DANA SPILIOTIS  SAN FRANCISCO         NaN
# 188                                  STANLEE GATTI  SAN FRANCISCO         NaN
# 189                                    KEVIN HARTZ  SAN FRANCISCO         NaN
# 190                               WILLIAM S FISHER   REDWOOD CITY         NaN
# 208                                   SIG ANDERMAN  SAN FRANCISCO         NaN
#
#      id_number                 employer                   occupation  \
# 7    1463380.0                      NaN                          NaN
# 8    1463380.0                      NaN                          NaN
# 9    1463380.0                      NaN                          NaN
# 10   1416442.0                      NaN                          NaN
# 11   1315969.0                      NaN                          NaN
# ..         ...                      ...                          ...
# 125        NaN  SELF-EMPLOYED/SAME NAME  TECHNOLOGY ADVISOR/INVESTOR
# 188        NaN  STANLEE R GATTI DESIGNS                     DESIGNER
# 189        NaN               A* CAPITAL   CO-FOUNDER/GENERAL PARTNER
# 190        NaN        MANZANITA CAPITAL                     INVESTOR
# 208        NaN                     NONE                      RETIRED
#
#        amount            transaction_type     type transaction_date  \
# 7    35000.00  LATE CONTRIBUTION RECEIVED  INITIAL       02/16/2024
# 8    31303.86  LATE CONTRIBUTION RECEIVED  INITIAL       02/16/2024
# 9    10201.80  LATE CONTRIBUTION RECEIVED  INITIAL       02/16/2024
# 10    1000.00  LATE CONTRIBUTION RECEIVED  INITIAL       02/16/2024
# 11   20000.00  LATE CONTRIBUTION RECEIVED  INITIAL       02/16/2024
# ..        ...                         ...      ...              ...
# 125   2500.00                         NaN      NaN       12/18/2023
# 188   2000.00                         NaN      NaN        1/11/2024
# 189  10000.00                         NaN      NaN        1/12/2024
# 190   1000.00                         NaN      NaN        1/19/2024
# 208   2000.00                         NaN      NaN        1/11/2024
#
#      filed_date transaction_number  \
# 7    02/18/2024     2892486-NON409
# 8    02/18/2024     2892486-NON408
# 9    02/18/2024     2892486-NON407
# 10   02/18/2024     2892486-INC377
# 11   02/18/2024     2892486-INC376
# ..          ...                ...
# 125   1/25/2024     2873352-INC162
# 188   1/25/2024     2873353-INC181
# 189   1/25/2024     2873353-INC182
# 190   1/25/2024     2873353-INC189
# 208   1/25/2024     2873353-INC208
#
#                                         committee_name payment_type state  \
# 7    ROLAND FOR SUPERIOR COURT JUDGE 2024; JEAN MYU...          NaN   NaN
# 8    ROLAND FOR SUPERIOR COURT JUDGE 2024; JEAN MYU...          NaN   NaN
# 9    ROLAND FOR SUPERIOR COURT JUDGE 2024; JEAN MYU...          NaN   NaN
# 10   ROLAND FOR SUPERIOR COURT JUDGE 2024; JEAN MYU...          NaN   NaN
# 11   ROLAND FOR SUPERIOR COURT JUDGE 2024; JEAN MYU...          NaN   NaN
# ..                                                 ...          ...   ...
# 125  ROLAND FOR SUPERIOR COURT JUDGE 2024; JEAN MYU...     MONETARY    CA
# 188  ROLAND FOR SUPERIOR COURT JUDGE 2024; JEAN MYU...     MONETARY    CA
# 189  ROLAND FOR SUPERIOR COURT JUDGE 2024; JEAN MYU...     MONETARY    CA
# 190  ROLAND FOR SUPERIOR COURT JUDGE 2024; JEAN MYU...     MONETARY    CA
# 208  ROLAND FOR SUPERIOR COURT JUDGE 2024; JEAN MYU...     MONETARY    CA
#
#          zip       date
# 7        NaN 2024-02-16
# 8        NaN 2024-02-16
# 9        NaN 2024-02-16
# 10       NaN 2024-02-16
# 11       NaN 2024-02-16
# ..       ...        ...
# 125  94115.0 2023-12-18
# 188  94103.0 2024-01-11
# 189  94133.0 2024-01-12
# 190  94065.0 2024-01-19
# 208  94111.0 2024-01-11
#
# [72 rows x 17 columns]

# %%
roland_df = roland_df.drop_duplicates(subset=['date', 'amount', 'name_of_contributor'])

# %%
roland_df
# Out:
#                            name_of_contributor           city   state/zip  \
# 0    CHIP ZECHER FOR SUPERIOR COURT JUDGE 2024  SAN FRANCISCO  CA / 94118
# 1    CHIP ZECHER FOR SUPERIOR COURT JUDGE 2024  SAN FRANCISCO  CA / 94118
# 2                             PG&E CORPORATION        OAKLAND  CA / 94612
# 3                             AS&P CORPORATION     UNION CITY  CA / 94587
# 4                                TIMOTHY MARKS  SAN FRANCISCO  CA / 94108
# ..                                         ...            ...         ...
# 220                            CYRUS SANANDAJI  SAN FRANCISCO         NaN
# 221                                MARK CONROE  SAN FRANCISCO         NaN
# 222                             HOLLY PETERSON  SAN FRANCISCO         NaN
# 223                           ALLISON ESPESETH  SAN FRANCISCO         NaN
# 224                               TANGUY SERRA  SAN FRANCISCO         NaN
#
#      id_number                           employer  \
# 0    1463380.0                                NaN
# 1    1463380.0                                NaN
# 2          NaN                                NaN
# 3          NaN                                NaN
# 4          NaN             TUCKER AND MARKS, INC.
# ..         ...                                ...
# 220        NaN              PRESIDIO BAY VENTURES
# 221        NaN  PRESIDIO DEVELOPMENT PARTNERS LLC
# 222        NaN                               NONE
# 223        NaN            SELF-EMPLOYED/SAME NAME
# 224        NaN                          GOODFINCH
#
#                          occupation    amount            transaction_type  \
# 0                               NaN   9516.45  LATE CONTRIBUTION RECEIVED
# 1                               NaN  17500.00  LATE CONTRIBUTION RECEIVED
# 2                               NaN   5000.00  LATE CONTRIBUTION RECEIVED
# 3                               NaN   1000.00  LATE CONTRIBUTION RECEIVED
# 4                MANAGING PRINCIPAL   1000.00  LATE CONTRIBUTION RECEIVED
# ..                              ...       ...                         ...
# 220              MANAGING PRINCIPAL    500.00                         NaN
# 221           REAL ESTATE DEVELOPER    100.00                         NaN
# 222                         RETIRED    500.00                         NaN
# 223  STRATEGIC MARKETING CONSULTANT    100.00                         NaN
# 224                        INVESTOR    100.00                         NaN
#
#         type transaction_date  filed_date transaction_number  \
# 0    INITIAL       02/22/2024  02/22/2024     2895403-NON445
# 1    INITIAL       02/22/2024  02/22/2024     2895403-NON444
# 2    INITIAL       02/21/2024  02/22/2024     2895403-INC443
# 3    INITIAL       02/21/2024  02/22/2024     2895403-INC442
# 4    INITIAL       02/20/2024  02/21/2024     2894178-INC413
# ..       ...              ...         ...                ...
# 220      NaN        1/12/2024   1/25/2024     2873353-INC223
# 221      NaN        1/11/2024   1/25/2024     2873353-INC224
# 222      NaN        1/11/2024   1/25/2024     2873353-INC225
# 223      NaN        1/11/2024   1/25/2024     2873353-INC226
# 224      NaN        1/11/2024   1/25/2024     2873353-INC228
#
#                                         committee_name payment_type state  \
# 0    ROLAND FOR SUPERIOR COURT JUDGE 2024; JEAN MYU...          NaN   NaN
# 1    ROLAND FOR SUPERIOR COURT JUDGE 2024; JEAN MYU...          NaN   NaN
# 2    ROLAND FOR SUPERIOR COURT JUDGE 2024; JEAN MYU...          NaN   NaN
# 3    ROLAND FOR SUPERIOR COURT JUDGE 2024; JEAN MYU...          NaN   NaN
# 4    ROLAND FOR SUPERIOR COURT JUDGE 2024; JEAN MYU...          NaN   NaN
# ..                                                 ...          ...   ...
# 220  ROLAND FOR SUPERIOR COURT JUDGE 2024; JEAN MYU...     MONETARY    CA
# 221  ROLAND FOR SUPERIOR COURT JUDGE 2024; JEAN MYU...     MONETARY    CA
# 222  ROLAND FOR SUPERIOR COURT JUDGE 2024; JEAN MYU...     MONETARY    CA
# 223  ROLAND FOR SUPERIOR COURT JUDGE 2024; JEAN MYU...     MONETARY    CA
# 224  ROLAND FOR SUPERIOR COURT JUDGE 2024; JEAN MYU...     MONETARY    CA
#
#          zip       date
# 0        NaN 2024-02-22
# 1        NaN 2024-02-22
# 2        NaN 2024-02-21
# 3        NaN 2024-02-21
# 4        NaN 2024-02-20
# ..       ...        ...
# 220  94111.0 2024-01-12
# 221  94123.0 2024-01-11
# 222  94118.0 2024-01-11
# 223  94115.0 2024-01-11
# 224  94115.0 2024-01-11
#
# [232 rows x 17 columns]

# %% [markdown]
# Add the independent expenditures:

# %%
roland_ind = pd.read_csv("./raw_files/roland_ind.csv")

# %%
roland_ind
# Out:
#          date                            name_of_contributor position  \
# 0  01/30/2024  COALITION TO GROW SAN FRANCISCO - GROW SF PAC  SUPPORT
# 1  01/30/2024  COALITION TO GROW SAN FRANCISCO - GROW SF PAC  SUPPORT
# 2  01/26/2024  COALITION TO GROW SAN FRANCISCO - GROW SF PAC  SUPPORT
# 3  01/31/2024  COALITION TO GROW SAN FRANCISCO - GROW SF PAC  SUPPORT
# 4  01/21/2024  COALITION TO GROW SAN FRANCISCO - GROW SF PAC  SUPPORT
# 5  01/24/2024  COALITION TO GROW SAN FRANCISCO - GROW SF PAC  SUPPORT
#
#       amount      description
# 0  $15713.49       ONLINE ADS
# 1   $3520.05       ONLINE ADS
# 2   $1408.02       ONLINE ADS
# 3    $422.41  DESIGN SERVICES
# 4    $176.00       ONLINE ADS
# 5    $126.72       ONLINE ADS

# %%
roland_ind['committee_name'] = 'Independent Expenditure'

# %%
roland_ind
# Out:
#          date                            name_of_contributor position  \
# 0  01/30/2024  COALITION TO GROW SAN FRANCISCO - GROW SF PAC  SUPPORT
# 1  01/30/2024  COALITION TO GROW SAN FRANCISCO - GROW SF PAC  SUPPORT
# 2  01/26/2024  COALITION TO GROW SAN FRANCISCO - GROW SF PAC  SUPPORT
# 3  01/31/2024  COALITION TO GROW SAN FRANCISCO - GROW SF PAC  SUPPORT
# 4  01/21/2024  COALITION TO GROW SAN FRANCISCO - GROW SF PAC  SUPPORT
# 5  01/24/2024  COALITION TO GROW SAN FRANCISCO - GROW SF PAC  SUPPORT
#
#       amount      description           committee_name
# 0  $15713.49       ONLINE ADS  Independent Expenditure
# 1   $3520.05       ONLINE ADS  Independent Expenditure
# 2   $1408.02       ONLINE ADS  Independent Expenditure
# 3    $422.41  DESIGN SERVICES  Independent Expenditure
# 4    $176.00       ONLINE ADS  Independent Expenditure
# 5    $126.72       ONLINE ADS  Independent Expenditure

# %%
roland_ind['amount'] = roland_ind['amount'].str.replace('$', '')

roland_ind['amount'] = roland_ind['amount'].astype(float)
# Out:
# /var/folders/_0/x7xh_2c16jq4chdcqrg28fr40000gn/T/ipykernel_1433/3750798406.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   roland_ind['amount'] = roland_ind['amount'].str.replace('$', '')

# %%
roland_ind['date'] = pd.to_datetime(roland_ind['date'], format='%m/%d/%Y')

# %%
roland_df = pd.concat([roland_df, roland_ind])

# %%
roland_df
# Out:
#                               name_of_contributor           city   state/zip  \
# 0       CHIP ZECHER FOR SUPERIOR COURT JUDGE 2024  SAN FRANCISCO  CA / 94118
# 1       CHIP ZECHER FOR SUPERIOR COURT JUDGE 2024  SAN FRANCISCO  CA / 94118
# 2                                PG&E CORPORATION        OAKLAND  CA / 94612
# 3                                AS&P CORPORATION     UNION CITY  CA / 94587
# 4                                   TIMOTHY MARKS  SAN FRANCISCO  CA / 94108
# ..                                            ...            ...         ...
# 1   COALITION TO GROW SAN FRANCISCO - GROW SF PAC            NaN         NaN
# 2   COALITION TO GROW SAN FRANCISCO - GROW SF PAC            NaN         NaN
# 3   COALITION TO GROW SAN FRANCISCO - GROW SF PAC            NaN         NaN
# 4   COALITION TO GROW SAN FRANCISCO - GROW SF PAC            NaN         NaN
# 5   COALITION TO GROW SAN FRANCISCO - GROW SF PAC            NaN         NaN
#
#     id_number                employer          occupation    amount  \
# 0   1463380.0                     NaN                 NaN   9516.45
# 1   1463380.0                     NaN                 NaN  17500.00
# 2         NaN                     NaN                 NaN   5000.00
# 3         NaN                     NaN                 NaN   1000.00
# 4         NaN  TUCKER AND MARKS, INC.  MANAGING PRINCIPAL   1000.00
# ..        ...                     ...                 ...       ...
# 1         NaN                     NaN                 NaN   3520.05
# 2         NaN                     NaN                 NaN   1408.02
# 3         NaN                     NaN                 NaN    422.41
# 4         NaN                     NaN                 NaN    176.00
# 5         NaN                     NaN                 NaN    126.72
#
#               transaction_type     type transaction_date  filed_date  \
# 0   LATE CONTRIBUTION RECEIVED  INITIAL       02/22/2024  02/22/2024
# 1   LATE CONTRIBUTION RECEIVED  INITIAL       02/22/2024  02/22/2024
# 2   LATE CONTRIBUTION RECEIVED  INITIAL       02/21/2024  02/22/2024
# 3   LATE CONTRIBUTION RECEIVED  INITIAL       02/21/2024  02/22/2024
# 4   LATE CONTRIBUTION RECEIVED  INITIAL       02/20/2024  02/21/2024
# ..                         ...      ...              ...         ...
# 1                          NaN      NaN              NaN         NaN
# 2                          NaN      NaN              NaN         NaN
# 3                          NaN      NaN              NaN         NaN
# 4                          NaN      NaN              NaN         NaN
# 5                          NaN      NaN              NaN         NaN
#
#    transaction_number                                     committee_name  \
# 0      2895403-NON445  ROLAND FOR SUPERIOR COURT JUDGE 2024; JEAN MYU...
# 1      2895403-NON444  ROLAND FOR SUPERIOR COURT JUDGE 2024; JEAN MYU...
# 2      2895403-INC443  ROLAND FOR SUPERIOR COURT JUDGE 2024; JEAN MYU...
# 3      2895403-INC442  ROLAND FOR SUPERIOR COURT JUDGE 2024; JEAN MYU...
# 4      2894178-INC413  ROLAND FOR SUPERIOR COURT JUDGE 2024; JEAN MYU...
# ..                ...                                                ...
# 1                 NaN                            Independent Expenditure
# 2                 NaN                            Independent Expenditure
# 3                 NaN                            Independent Expenditure
# 4                 NaN                            Independent Expenditure
# 5                 NaN                            Independent Expenditure
#
#    payment_type state  zip       date position      description
# 0           NaN   NaN  NaN 2024-02-22      NaN              NaN
# 1           NaN   NaN  NaN 2024-02-22      NaN              NaN
# 2           NaN   NaN  NaN 2024-02-21      NaN              NaN
# 3           NaN   NaN  NaN 2024-02-21      NaN              NaN
# 4           NaN   NaN  NaN 2024-02-20      NaN              NaN
# ..          ...   ...  ...        ...      ...              ...
# 1           NaN   NaN  NaN 2024-01-30  SUPPORT       ONLINE ADS
# 2           NaN   NaN  NaN 2024-01-26  SUPPORT       ONLINE ADS
# 3           NaN   NaN  NaN 2024-01-31  SUPPORT  DESIGN SERVICES
# 4           NaN   NaN  NaN 2024-01-21  SUPPORT       ONLINE ADS
# 5           NaN   NaN  NaN 2024-01-24  SUPPORT       ONLINE ADS
#
# [238 rows x 19 columns]

# %%
roland_df['contest'] = 'roland'

# %% [markdown]
# Thompson

# %%
# read csv 

thompson_1_late_df = pd.read_csv('./raw_files/thompson_1_late.csv')
thompson_1_all_df = pd.read_csv('./raw_files/thompson_1_all.csv')
thompson_2_late_df = pd.read_csv('./raw_files/thompson_2_late.csv')
thompson_2_all_df = pd.read_csv('./raw_files/thompson_2_all.csv')

# %%
thompson_1_late_df["committee_name"] = "THOMPSON 2024; RETAIN JUDGE PATRICK"
thompson_1_all_df["committee_name"] = "THOMPSON 2024; RETAIN JUDGE PATRICK"
thompson_2_late_df["committee_name"] = "BEGERT AND PATRICK THOMPSON; SAFE AND ACCOUNTABLE SAN FRANCISCO SUPPORTING THE RETENTION OF JUDGES MICHAEL ISAKU"
thompson_2_all_df["committee_name"] = "BEGERT AND PATRICK THOMPSON; SAFE AND ACCOUNTABLE SAN FRANCISCO SUPPORTING THE RETENTION OF JUDGES MICHAEL ISAKU"

# %%
thompson_1_all_df
# Out:
#                                    NAME OF CONTRIBUTOR  PAYMENT TYPE  \
# 0                                        RONALD SABRAW      MONETARY
# 1                                         MARK DICKSON      MONETARY
# 2                                          TREVOR READ      MONETARY
# 3                                     SALLY ROSENBLATT      MONETARY
# 4                                          JOHN CORTIS      MONETARY
# ..                                                 ...           ...
# 217                                      LISA DEWBERRY      MONETARY
# 218  SAFE AND ACCOUNTABLE SAN FRANCISCO SUPPORTING ...  NON-MONETARY
# 219  SAFE AND ACCOUNTABLE SAN FRANCISCO SUPPORTING ...  NON-MONETARY
# 220  SAFE AND ACCOUNTABLE SAN FRANCISCO SUPPORTING ...  NON-MONETARY
# 221  SAFE AND ACCOUNTABLE SAN FRANCISCO SUPPORTING ...  NON-MONETARY
#
#               CITY STATE         ZIP  ID NUMBER       EMPLOYER  \
# 0          FREMONT    CA       94539        NaN            NaN
# 1        SAN MATEO    CA  94402-3989        NaN  PHASE M LEGAL
# 2         SYRACUSE    IN       46567        NaN        AGISTIX
# 3    SAN FRANCISCO    CA       94129        NaN            NaN
# 4     WALNUT CREEK    CA       94595        NaN            NaN
# ..             ...   ...         ...        ...            ...
# 217   REDWOOD CITY    CA       94061        NaN  LISA DEWBERRY
# 218        OAKLAND    CA       94607  1464402.0            NaN
# 219        OAKLAND    CA       94607  1464402.0            NaN
# 220        OAKLAND    CA       94607  1464402.0            NaN
# 221        OAKLAND    CA       94607  1464402.0            NaN
#
#           OCCUPATION       AMOUNT TRANSACTION DATE FILED DATE  \
# 0            RETIRED    ($250.00)       12/31/2023  1/30/2024
# 1    PATENT ATTORNEY     $200.00        12/28/2023  1/30/2024
# 2          PRESIDENT     $250.00        12/29/2023  1/30/2024
# 3            RETIRED     $250.00        12/28/2023  1/30/2024
# 4       NOT EMPLOYED     $100.00        12/31/2023  1/30/2024
# ..               ...          ...              ...        ...
# 217         ATTORNEY     $100.00         2/14/2024  2/22/2024
# 218              NaN   $5,000.00         1/29/2024  2/22/2024
# 219              NaN  $23,250.00          2/2/2024  2/22/2024
# 220              NaN   $4,012.35          2/3/2024  2/22/2024
# 221              NaN  $18,743.02          2/8/2024  2/22/2024
#
#     TRANSACTION NUMBER                       committee_name
# 0     2877631 - EXP151  THOMPSON 2024; RETAIN JUDGE PATRICK
# 1     2877631 - INC111  THOMPSON 2024; RETAIN JUDGE PATRICK
# 2     2877631 - INC112  THOMPSON 2024; RETAIN JUDGE PATRICK
# 3     2877631 - INC113  THOMPSON 2024; RETAIN JUDGE PATRICK
# 4     2877631 - INC123  THOMPSON 2024; RETAIN JUDGE PATRICK
# ..                 ...                                  ...
# 217   2895024 - INC515  THOMPSON 2024; RETAIN JUDGE PATRICK
# 218   2895024 - NON294  THOMPSON 2024; RETAIN JUDGE PATRICK
# 219   2895024 - NON406  THOMPSON 2024; RETAIN JUDGE PATRICK
# 220   2895024 - NON407  THOMPSON 2024; RETAIN JUDGE PATRICK
# 221   2895024 - NON455  THOMPSON 2024; RETAIN JUDGE PATRICK
#
# [222 rows x 13 columns]

# %%
thompson_1_late_df.columns = thompson_1_late_df.columns.str.lower().str.replace(' ', '_')
thompson_1_all_df.columns = thompson_1_all_df.columns.str.lower().str.replace(' ', '_')
thompson_2_late_df.columns = thompson_2_late_df.columns.str.lower().str.replace(' ', '_')
thompson_2_all_df.columns = thompson_2_all_df.columns.str.lower().str.replace(' ', '_')

# %%
thompson_df = pd.concat([thompson_1_late_df, thompson_1_all_df, thompson_2_late_df, thompson_2_all_df])

# %%
thompson_df
# Out:
#                                    name_of_contributor           city  \
# 0    SAFE AND ACCOUNTABLE SAN FRANCISCO SUPPORTING ...        OAKLAND
# 1                                       MICHAEL GLASER  SAN FRANCISCO
# 2                                         MATTHEW GRAY  SAN FRANCISCO
# 3                                   VIDHYA PRABHAKARAN  SAN FRANCISCO
# 4    SAFE AND ACCOUNTABLE SAN FRANCISCO SUPPORTING ...        OAKLAND
# ..                                                 ...            ...
# 129                                      DICK GROSBOLL  SAN FRANCISCO
# 130                                        MEGAN JANIS  SAN FRANCISCO
# 131                                   DANIEL WEINSTEIN  SAN FRANCISCO
# 132                                       GAIL DEKREON  SAN FRANCISCO
# 133                                      STUART HANLON  SAN FRANCISCO
#
#       state/zip  id_number                         employer  \
# 0    CA / 94607  1464402.0                              NaN
# 1    CA / 94131        NaN        MORRISON AND FOERSTER LLP
# 2    CA / 94115        NaN                 PERKINS COIE LLP
# 3    CA / 94127        NaN        DAVIS WRIGHT TREMAINE LLP
# 4    CA / 94607  1464402.0                              NaN
# ..          ...        ...                              ...
# 129         NaN        NaN  NEYHART ANDERSON FLYNN GROSBOLL
# 130         NaN        NaN              ABBOTT LABORATORIES
# 131         NaN        NaN                              NaN
# 132         NaN        NaN                              NaN
# 133         NaN        NaN      LAW OFFICE OF STUART HANLON
#
#                     occupation       amount            transaction_type  \
# 0                          NaN   $1,000.00   LATE CONTRIBUTION RECEIVED
# 1                     ATTORNEY  $10,000.00   LATE CONTRIBUTION RECEIVED
# 2                     ATTORNEY   $1,000.00   LATE CONTRIBUTION RECEIVED
# 3                     ATTORNEY   $1,000.00   LATE CONTRIBUTION RECEIVED
# 4                          NaN   $7,500.00   LATE CONTRIBUTION RECEIVED
# ..                         ...          ...                         ...
# 129                   ATTORNEY     $500.00                          NaN
# 130         COMPLIANCE OFFICER     $250.00                          NaN
# 131                    RETIRED     $500.00                          NaN
# 132                    RETIRED   $1,000.00                          NaN
# 133  CRIMINAL DEFENSE ATTORNEY     $150.00                          NaN
#
#         type transaction_date  filed_date transaction_number  \
# 0    INITIAL       02/23/2024  02/26/2024     2897219-NON611
# 1    INITIAL       02/24/2024  02/26/2024     2897219-INC609
# 2    INITIAL       02/24/2024  02/26/2024     2897219-INC608
# 3    INITIAL       02/23/2024  02/26/2024     2897219-INC588
# 4    INITIAL       02/18/2024  02/20/2024     2893253-NON560
# ..       ...              ...         ...                ...
# 129      NaN        2/13/2024   2/22/2024   2895026 - INC274
# 130      NaN        2/12/2024   2/22/2024   2895026 - INC275
# 131      NaN        2/15/2024   2/22/2024   2895026 - INC285
# 132      NaN        2/14/2024   2/22/2024   2895026 - INC286
# 133      NaN        2/13/2024   2/22/2024   2895026 - INC287
#
#                                         committee_name payment_type state  \
# 0                  THOMPSON 2024; RETAIN JUDGE PATRICK          NaN   NaN
# 1                  THOMPSON 2024; RETAIN JUDGE PATRICK          NaN   NaN
# 2                  THOMPSON 2024; RETAIN JUDGE PATRICK          NaN   NaN
# 3                  THOMPSON 2024; RETAIN JUDGE PATRICK          NaN   NaN
# 4                  THOMPSON 2024; RETAIN JUDGE PATRICK          NaN   NaN
# ..                                                 ...          ...   ...
# 129  BEGERT AND PATRICK THOMPSON; SAFE AND ACCOUNTA...     MONETARY    CA
# 130  BEGERT AND PATRICK THOMPSON; SAFE AND ACCOUNTA...     MONETARY    CA
# 131  BEGERT AND PATRICK THOMPSON; SAFE AND ACCOUNTA...     MONETARY    CA
# 132  BEGERT AND PATRICK THOMPSON; SAFE AND ACCOUNTA...     MONETARY    CA
# 133  BEGERT AND PATRICK THOMPSON; SAFE AND ACCOUNTA...     MONETARY    CA
#
#        zip
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ..     ...
# 129  94104
# 130  94118
# 131  94111
# 132  94124
# 133  94117
#
# [454 rows x 16 columns]

# %%
thompson_df['amount'] = thompson_df['amount'].str.replace('$', '')
thompson_df['amount'] = thompson_df['amount'].str.replace('(', '-')
thompson_df['amount'] = thompson_df['amount'].str.replace(')', '')
thompson_df['amount'] = thompson_df['amount'].str.replace(',', '')
# Out:
# /var/folders/_0/x7xh_2c16jq4chdcqrg28fr40000gn/T/ipykernel_1433/108440448.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   thompson_df['amount'] = thompson_df['amount'].str.replace('$', '')
# /var/folders/_0/x7xh_2c16jq4chdcqrg28fr40000gn/T/ipykernel_1433/108440448.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   thompson_df['amount'] = thompson_df['amount'].str.replace('(', '-')
# /var/folders/_0/x7xh_2c16jq4chdcqrg28fr40000gn/T/ipykernel_1433/108440448.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   thompson_df['amount'] = thompson_df['amount'].str.replace(')', '')

# %%
thompson_df['amount'] = thompson_df['amount'].astype(float)

# %%
thompson_df['date'] = pd.to_datetime(thompson_df['transaction_date'], format='%m/%d/%Y')

# %%
thompson_df['transaction_number'] = thompson_df['transaction_number'].str.replace(' - ', '-')

# %%
thompson_df[thompson_df.duplicated(subset=['name_of_contributor', 'amount', 'date','transaction_type'], keep=False)]
# Out:
#    name_of_contributor     city   state/zip  id_number employer    occupation  \
# 47           RUTH PACE  ATLANTA  GA / 30309        NaN      NaN  NOT EMPLOYED
# 48           RUTH PACE  ATLANTA  GA / 30309        NaN      NaN  NOT EMPLOYED
# 37           RUTH PACE  ATLANTA         NaN        NaN      NaN  NOT EMPLOYED
# 38           RUTH PACE  ATLANTA         NaN        NaN      NaN  NOT EMPLOYED
# 72       RONALD SABRAW  FREMONT         NaN        NaN      NaN       RETIRED
# 73       RONALD SABRAW  FREMONT         NaN        NaN      NaN       RETIRED
#
#     amount            transaction_type     type transaction_date  filed_date  \
# 47  1000.0  LATE CONTRIBUTION RECEIVED  INITIAL       12/12/2023  12/22/2023
# 48  1000.0  LATE CONTRIBUTION RECEIVED  INITIAL       12/12/2023  12/22/2023
# 37  1000.0                         NaN      NaN       12/12/2023   1/30/2024
# 38  1000.0                         NaN      NaN       12/12/2023   1/30/2024
# 72   250.0                         NaN      NaN       12/23/2023   1/30/2024
# 73   250.0                         NaN      NaN       12/23/2023   1/30/2024
#
#    transaction_number                       committee_name payment_type state  \
# 47      2862266-INC26  THOMPSON 2024; RETAIN JUDGE PATRICK          NaN   NaN
# 48      2862266-INC25  THOMPSON 2024; RETAIN JUDGE PATRICK          NaN   NaN
# 37      2877631-INC25  THOMPSON 2024; RETAIN JUDGE PATRICK     MONETARY    GA
# 38      2877631-INC26  THOMPSON 2024; RETAIN JUDGE PATRICK     MONETARY    GA
# 72      2877631-INC63  THOMPSON 2024; RETAIN JUDGE PATRICK     MONETARY    CA
# 73      2877631-INC64  THOMPSON 2024; RETAIN JUDGE PATRICK     MONETARY    CA
#
#       zip       date
# 47    NaN 2023-12-12
# 48    NaN 2023-12-12
# 37  30309 2023-12-12
# 38  30309 2023-12-12
# 72  94539 2023-12-23
# 73  94539 2023-12-23

# %% [markdown]
# manually going to fix Ruth's contributions below by adding one back, she donated $2,000 total on the 12 and 13 ($1,000 installments) in December. Ronald is the one who returned $250 so this will fix itself

# %%
thompson_df = thompson_df.drop_duplicates(subset=['date', 'amount', 'name_of_contributor'])

# %%
thompson_df
# Out:
#                                    name_of_contributor           city  \
# 0    SAFE AND ACCOUNTABLE SAN FRANCISCO SUPPORTING ...        OAKLAND
# 1                                       MICHAEL GLASER  SAN FRANCISCO
# 2                                         MATTHEW GRAY  SAN FRANCISCO
# 3                                   VIDHYA PRABHAKARAN  SAN FRANCISCO
# 4    SAFE AND ACCOUNTABLE SAN FRANCISCO SUPPORTING ...        OAKLAND
# ..                                                 ...            ...
# 128                                      HARRIS TABACK  SAN FRANCISCO
# 129                                      DICK GROSBOLL  SAN FRANCISCO
# 130                                        MEGAN JANIS  SAN FRANCISCO
# 131                                   DANIEL WEINSTEIN  SAN FRANCISCO
# 133                                      STUART HANLON  SAN FRANCISCO
#
#       state/zip  id_number                         employer  \
# 0    CA / 94607  1464402.0                              NaN
# 1    CA / 94131        NaN        MORRISON AND FOERSTER LLP
# 2    CA / 94115        NaN                 PERKINS COIE LLP
# 3    CA / 94127        NaN        DAVIS WRIGHT TREMAINE LLP
# 4    CA / 94607  1464402.0                              NaN
# ..          ...        ...                              ...
# 128         NaN        NaN      LAW OFFICE OF HARRIS TABACK
# 129         NaN        NaN  NEYHART ANDERSON FLYNN GROSBOLL
# 130         NaN        NaN              ABBOTT LABORATORIES
# 131         NaN        NaN                              NaN
# 133         NaN        NaN      LAW OFFICE OF STUART HANLON
#
#                     occupation   amount            transaction_type     type  \
# 0                          NaN   1000.0  LATE CONTRIBUTION RECEIVED  INITIAL
# 1                     ATTORNEY  10000.0  LATE CONTRIBUTION RECEIVED  INITIAL
# 2                     ATTORNEY   1000.0  LATE CONTRIBUTION RECEIVED  INITIAL
# 3                     ATTORNEY   1000.0  LATE CONTRIBUTION RECEIVED  INITIAL
# 4                          NaN   7500.0  LATE CONTRIBUTION RECEIVED  INITIAL
# ..                         ...      ...                         ...      ...
# 128                   ATTORNEY    250.0                         NaN      NaN
# 129                   ATTORNEY    500.0                         NaN      NaN
# 130         COMPLIANCE OFFICER    250.0                         NaN      NaN
# 131                    RETIRED    500.0                         NaN      NaN
# 133  CRIMINAL DEFENSE ATTORNEY    150.0                         NaN      NaN
#
#     transaction_date  filed_date transaction_number  \
# 0         02/23/2024  02/26/2024     2897219-NON611
# 1         02/24/2024  02/26/2024     2897219-INC609
# 2         02/24/2024  02/26/2024     2897219-INC608
# 3         02/23/2024  02/26/2024     2897219-INC588
# 4         02/18/2024  02/20/2024     2893253-NON560
# ..               ...         ...                ...
# 128        2/11/2024   2/22/2024     2895026-INC269
# 129        2/13/2024   2/22/2024     2895026-INC274
# 130        2/12/2024   2/22/2024     2895026-INC275
# 131        2/15/2024   2/22/2024     2895026-INC285
# 133        2/13/2024   2/22/2024     2895026-INC287
#
#                                         committee_name payment_type state  \
# 0                  THOMPSON 2024; RETAIN JUDGE PATRICK          NaN   NaN
# 1                  THOMPSON 2024; RETAIN JUDGE PATRICK          NaN   NaN
# 2                  THOMPSON 2024; RETAIN JUDGE PATRICK          NaN   NaN
# 3                  THOMPSON 2024; RETAIN JUDGE PATRICK          NaN   NaN
# 4                  THOMPSON 2024; RETAIN JUDGE PATRICK          NaN   NaN
# ..                                                 ...          ...   ...
# 128  BEGERT AND PATRICK THOMPSON; SAFE AND ACCOUNTA...     MONETARY    CA
# 129  BEGERT AND PATRICK THOMPSON; SAFE AND ACCOUNTA...     MONETARY    CA
# 130  BEGERT AND PATRICK THOMPSON; SAFE AND ACCOUNTA...     MONETARY    CA
# 131  BEGERT AND PATRICK THOMPSON; SAFE AND ACCOUNTA...     MONETARY    CA
# 133  BEGERT AND PATRICK THOMPSON; SAFE AND ACCOUNTA...     MONETARY    CA
#
#        zip       date
# 0      NaN 2024-02-23
# 1      NaN 2024-02-24
# 2      NaN 2024-02-24
# 3      NaN 2024-02-23
# 4      NaN 2024-02-18
# ..     ...        ...
# 128  94117 2024-02-11
# 129  94104 2024-02-13
# 130  94118 2024-02-12
# 131  94111 2024-02-15
# 133  94117 2024-02-13
#
# [364 rows x 17 columns]

# %%
# show the rows where the name is ruth pace 

thompson_df[thompson_df['name_of_contributor'] == 'RUTH PACE']

# duplicate this row

thompson_df = pd.concat([thompson_df, thompson_df[thompson_df['name_of_contributor'] == 'RUTH PACE']])

# %% [markdown]
# note: that needs to be fixed later to have the correct transaction number

# %%
thompson_df['contest'] = 'thompson'

# %% [markdown]
# ### Adding everything together

# %%
df = pd.concat([zecher_df, begert_df, roland_df, thompson_df])

# %%
df
# Out:
#       name_of_contributor           city   state/zip  id_number  \
# 0      JEANNIE SANGIACOMO           ROSS  CA / 94957        NaN
# 1      JEANNIE SANGIACOMO           ROSS  CA / 94957        NaN
# 2             WALTER WOOD      LOS ALTOS  CA / 94022        NaN
# 3        PG&E CORPORATION        OAKLAND  CA / 94612        NaN
# 4    TUCKER AND MARKS INC  SAN FRANCISCO  CA / 94108        NaN
# ..                    ...            ...         ...        ...
# 129         DICK GROSBOLL  SAN FRANCISCO         NaN        NaN
# 130           MEGAN JANIS  SAN FRANCISCO         NaN        NaN
# 131      DANIEL WEINSTEIN  SAN FRANCISCO         NaN        NaN
# 133         STUART HANLON  SAN FRANCISCO         NaN        NaN
# 47              RUTH PACE        ATLANTA  GA / 30309        NaN
#
#                             employer                 occupation  amount  \
# 0                               NONE                    RETIRED   500.0
# 1                               NONE                    RETIRED   500.0
# 2                               NONE                    RETIRED  5000.0
# 3                                NaN                        NaN  5000.0
# 4                                NaN                        NaN  1000.0
# ..                               ...                        ...     ...
# 129  NEYHART ANDERSON FLYNN GROSBOLL                   ATTORNEY   500.0
# 130              ABBOTT LABORATORIES         COMPLIANCE OFFICER   250.0
# 131                              NaN                    RETIRED   500.0
# 133      LAW OFFICE OF STUART HANLON  CRIMINAL DEFENSE ATTORNEY   150.0
# 47                               NaN               NOT EMPLOYED  1000.0
#
#                transaction_type     type transaction_date  filed_date  \
# 0    LATE CONTRIBUTION RECEIVED  INITIAL       02/23/2024  02/26/2024
# 1    LATE CONTRIBUTION RECEIVED  INITIAL       02/21/2024  02/26/2024
# 2    LATE CONTRIBUTION RECEIVED  INITIAL       02/21/2024  02/22/2024
# 3    LATE CONTRIBUTION RECEIVED  INITIAL       02/21/2024  02/22/2024
# 4    LATE CONTRIBUTION RECEIVED  INITIAL       02/20/2024  02/21/2024
# ..                          ...      ...              ...         ...
# 129                         NaN      NaN        2/13/2024   2/22/2024
# 130                         NaN      NaN        2/12/2024   2/22/2024
# 131                         NaN      NaN        2/15/2024   2/22/2024
# 133                         NaN      NaN        2/13/2024   2/22/2024
# 47   LATE CONTRIBUTION RECEIVED  INITIAL       12/12/2023  12/22/2023
#
#     transaction_number payment_type state    zip  \
# 0       2897128-INC515          NaN   NaN    NaN
# 1       2897128-INC504          NaN   NaN    NaN
# 2       2895281-INC507          NaN   NaN    NaN
# 3       2895281-INC506          NaN   NaN    NaN
# 4       2893914-INC499          NaN   NaN    NaN
# ..                 ...          ...   ...    ...
# 129     2895026-INC274     MONETARY    CA  94104
# 130     2895026-INC275     MONETARY    CA  94118
# 131     2895026-INC285     MONETARY    CA  94111
# 133     2895026-INC287     MONETARY    CA  94117
# 47       2862266-INC26          NaN   NaN    NaN
#
#                                         committee_name       date position  \
# 0           ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP 2024-02-23      NaN
# 1           ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP 2024-02-21      NaN
# 2           ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP 2024-02-21      NaN
# 3           ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP 2024-02-21      NaN
# 4           ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP 2024-02-20      NaN
# ..                                                 ...        ...      ...
# 129  BEGERT AND PATRICK THOMPSON; SAFE AND ACCOUNTA... 2024-02-13      NaN
# 130  BEGERT AND PATRICK THOMPSON; SAFE AND ACCOUNTA... 2024-02-12      NaN
# 131  BEGERT AND PATRICK THOMPSON; SAFE AND ACCOUNTA... 2024-02-15      NaN
# 133  BEGERT AND PATRICK THOMPSON; SAFE AND ACCOUNTA... 2024-02-13      NaN
# 47                 THOMPSON 2024; RETAIN JUDGE PATRICK 2023-12-12      NaN
#
#     description   contest
# 0           NaN    zecher
# 1           NaN    zecher
# 2           NaN    zecher
# 3           NaN    zecher
# 4           NaN    zecher
# ..          ...       ...
# 129         NaN  thompson
# 130         NaN  thompson
# 131         NaN  thompson
# 133         NaN  thompson
# 47          NaN  thompson
#
# [1397 rows x 20 columns]

# %%
df['name_of_contributor'] = df['name_of_contributor'].str.title()

# %%
df.payment_type.value_counts()
# Out:
# MONETARY        1097
# LOAN               5
# NON-MONETARY       2
# Name: payment_type, dtype: int64

# %%
df = df[df.payment_type != 'Loan']

df = df[df.payment_type != 'NON-MONETARY']

# %%
df
# Out:
#       name_of_contributor           city   state/zip  id_number  \
# 0      Jeannie Sangiacomo           ROSS  CA / 94957        NaN
# 1      Jeannie Sangiacomo           ROSS  CA / 94957        NaN
# 2             Walter Wood      LOS ALTOS  CA / 94022        NaN
# 3        Pg&E Corporation        OAKLAND  CA / 94612        NaN
# 4    Tucker And Marks Inc  SAN FRANCISCO  CA / 94108        NaN
# ..                    ...            ...         ...        ...
# 129         Dick Grosboll  SAN FRANCISCO         NaN        NaN
# 130           Megan Janis  SAN FRANCISCO         NaN        NaN
# 131      Daniel Weinstein  SAN FRANCISCO         NaN        NaN
# 133         Stuart Hanlon  SAN FRANCISCO         NaN        NaN
# 47              Ruth Pace        ATLANTA  GA / 30309        NaN
#
#                             employer                 occupation  amount  \
# 0                               NONE                    RETIRED   500.0
# 1                               NONE                    RETIRED   500.0
# 2                               NONE                    RETIRED  5000.0
# 3                                NaN                        NaN  5000.0
# 4                                NaN                        NaN  1000.0
# ..                               ...                        ...     ...
# 129  NEYHART ANDERSON FLYNN GROSBOLL                   ATTORNEY   500.0
# 130              ABBOTT LABORATORIES         COMPLIANCE OFFICER   250.0
# 131                              NaN                    RETIRED   500.0
# 133      LAW OFFICE OF STUART HANLON  CRIMINAL DEFENSE ATTORNEY   150.0
# 47                               NaN               NOT EMPLOYED  1000.0
#
#                transaction_type     type transaction_date  filed_date  \
# 0    LATE CONTRIBUTION RECEIVED  INITIAL       02/23/2024  02/26/2024
# 1    LATE CONTRIBUTION RECEIVED  INITIAL       02/21/2024  02/26/2024
# 2    LATE CONTRIBUTION RECEIVED  INITIAL       02/21/2024  02/22/2024
# 3    LATE CONTRIBUTION RECEIVED  INITIAL       02/21/2024  02/22/2024
# 4    LATE CONTRIBUTION RECEIVED  INITIAL       02/20/2024  02/21/2024
# ..                          ...      ...              ...         ...
# 129                         NaN      NaN        2/13/2024   2/22/2024
# 130                         NaN      NaN        2/12/2024   2/22/2024
# 131                         NaN      NaN        2/15/2024   2/22/2024
# 133                         NaN      NaN        2/13/2024   2/22/2024
# 47   LATE CONTRIBUTION RECEIVED  INITIAL       12/12/2023  12/22/2023
#
#     transaction_number payment_type state    zip  \
# 0       2897128-INC515          NaN   NaN    NaN
# 1       2897128-INC504          NaN   NaN    NaN
# 2       2895281-INC507          NaN   NaN    NaN
# 3       2895281-INC506          NaN   NaN    NaN
# 4       2893914-INC499          NaN   NaN    NaN
# ..                 ...          ...   ...    ...
# 129     2895026-INC274     MONETARY    CA  94104
# 130     2895026-INC275     MONETARY    CA  94118
# 131     2895026-INC285     MONETARY    CA  94111
# 133     2895026-INC287     MONETARY    CA  94117
# 47       2862266-INC26          NaN   NaN    NaN
#
#                                         committee_name       date position  \
# 0           ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP 2024-02-23      NaN
# 1           ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP 2024-02-21      NaN
# 2           ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP 2024-02-21      NaN
# 3           ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP 2024-02-21      NaN
# 4           ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP 2024-02-20      NaN
# ..                                                 ...        ...      ...
# 129  BEGERT AND PATRICK THOMPSON; SAFE AND ACCOUNTA... 2024-02-13      NaN
# 130  BEGERT AND PATRICK THOMPSON; SAFE AND ACCOUNTA... 2024-02-12      NaN
# 131  BEGERT AND PATRICK THOMPSON; SAFE AND ACCOUNTA... 2024-02-15      NaN
# 133  BEGERT AND PATRICK THOMPSON; SAFE AND ACCOUNTA... 2024-02-13      NaN
# 47                 THOMPSON 2024; RETAIN JUDGE PATRICK 2023-12-12      NaN
#
#     description   contest
# 0           NaN    zecher
# 1           NaN    zecher
# 2           NaN    zecher
# 3           NaN    zecher
# 4           NaN    zecher
# ..          ...       ...
# 129         NaN  thompson
# 130         NaN  thompson
# 131         NaN  thompson
# 133         NaN  thompson
# 47          NaN  thompson
#
# [1395 rows x 20 columns]

# %%
df.groupby('committee_name').amount.sum()
# Out:
# committee_name
# BEGERT 2024; RETAIN JUDGE MICHAEL                                                                                   346492.07
# BEGERT AND PATRICK THOMPSON; SAFE AND ACCOUNTABLE SAN FRANCISCO SUPPORTING THE RETENTION OF JUDGES MICHAEL ISAKU    284954.40
# Independent Expenditure                                                                                              45560.32
# ROLAND FOR SUPERIOR COURT JUDGE 2024; JEAN MYUNGJIN                                                                 384889.60
# THOMPSON 2024; RETAIN JUDGE PATRICK                                                                                 203275.52
# ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP                                                                          680490.33
# Name: amount, dtype: float64

# %%
df.columns
# Out:
# Index(['name_of_contributor', 'city', 'state/zip', 'id_number', 'employer',
#        'occupation', 'amount', 'transaction_type', 'type', 'transaction_date',
#        'filed_date', 'transaction_number', 'payment_type', 'state', 'zip',
#        'committee_name', 'date', 'position', 'description', 'contest'],
#       dtype='object')

# %%
df['seat'] = df['contest']

# %%
df["seat"].replace({"zecher": "Seat 1", "begert": "Seat 1", "roland": "Seat 13", "thom"}, inplace=True)
# Out:
#       name_of_contributor           city   state/zip  id_number  \
# 0      Jeannie Sangiacomo           ROSS  CA / 94957        NaN
# 1      Jeannie Sangiacomo           ROSS  CA / 94957        NaN
# 2             Walter Wood      LOS ALTOS  CA / 94022        NaN
# 3        Pg&E Corporation        OAKLAND  CA / 94612        NaN
# 4    Tucker And Marks Inc  SAN FRANCISCO  CA / 94108        NaN
# ..                    ...            ...         ...        ...
# 129         Dick Grosboll  SAN FRANCISCO         NaN        NaN
# 130           Megan Janis  SAN FRANCISCO         NaN        NaN
# 131      Daniel Weinstein  SAN FRANCISCO         NaN        NaN
# 133         Stuart Hanlon  SAN FRANCISCO         NaN        NaN
# 47              Ruth Pace        ATLANTA  GA / 30309        NaN
#
#                             employer                 occupation  amount  \
# 0                               NONE                    RETIRED   500.0
# 1                               NONE                    RETIRED   500.0
# 2                               NONE                    RETIRED  5000.0
# 3                                NaN                        NaN  5000.0
# 4                                NaN                        NaN  1000.0
# ..                               ...                        ...     ...
# 129  NEYHART ANDERSON FLYNN GROSBOLL                   ATTORNEY   500.0
# 130              ABBOTT LABORATORIES         COMPLIANCE OFFICER   250.0
# 131                              NaN                    RETIRED   500.0
# 133      LAW OFFICE OF STUART HANLON  CRIMINAL DEFENSE ATTORNEY   150.0
# 47                               NaN               NOT EMPLOYED  1000.0
#
#                transaction_type     type transaction_date  ...  \
# 0    LATE CONTRIBUTION RECEIVED  INITIAL       02/23/2024  ...
# 1    LATE CONTRIBUTION RECEIVED  INITIAL       02/21/2024  ...
# 2    LATE CONTRIBUTION RECEIVED  INITIAL       02/21/2024  ...
# 3    LATE CONTRIBUTION RECEIVED  INITIAL       02/21/2024  ...
# 4    LATE CONTRIBUTION RECEIVED  INITIAL       02/20/2024  ...
# ..                          ...      ...              ...  ...
# 129                         NaN      NaN        2/13/2024  ...
# 130                         NaN      NaN        2/12/2024  ...
# 131                         NaN      NaN        2/15/2024  ...
# 133                         NaN      NaN        2/13/2024  ...
# 47   LATE CONTRIBUTION RECEIVED  INITIAL       12/12/2023  ...
#
#     transaction_number payment_type state    zip  \
# 0       2897128-INC515          NaN   NaN    NaN
# 1       2897128-INC504          NaN   NaN    NaN
# 2       2895281-INC507          NaN   NaN    NaN
# 3       2895281-INC506          NaN   NaN    NaN
# 4       2893914-INC499          NaN   NaN    NaN
# ..                 ...          ...   ...    ...
# 129     2895026-INC274     MONETARY    CA  94104
# 130     2895026-INC275     MONETARY    CA  94118
# 131     2895026-INC285     MONETARY    CA  94111
# 133     2895026-INC287     MONETARY    CA  94117
# 47       2862266-INC26          NaN   NaN    NaN
#
#                                         committee_name       date position  \
# 0           ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP 2024-02-23      NaN
# 1           ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP 2024-02-21      NaN
# 2           ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP 2024-02-21      NaN
# 3           ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP 2024-02-21      NaN
# 4           ZECHER FOR SUPERIOR COURT JUDGE 2024; CHIP 2024-02-20      NaN
# ..                                                 ...        ...      ...
# 129  BEGERT AND PATRICK THOMPSON; SAFE AND ACCOUNTA... 2024-02-13      NaN
# 130  BEGERT AND PATRICK THOMPSON; SAFE AND ACCOUNTA... 2024-02-12      NaN
# 131  BEGERT AND PATRICK THOMPSON; SAFE AND ACCOUNTA... 2024-02-15      NaN
# 133  BEGERT AND PATRICK THOMPSON; SAFE AND ACCOUNTA... 2024-02-13      NaN
# 47                 THOMPSON 2024; RETAIN JUDGE PATRICK 2023-12-12      NaN
#
#     description   contest      seat
# 0           NaN    zecher    zecher
# 1           NaN    zecher    zecher
# 2           NaN    zecher    zecher
# 3           NaN    zecher    zecher
# 4           NaN    zecher    zecher
# ..          ...       ...       ...
# 129         NaN  thompson  thompson
# 130         NaN  thompson  thompson
# 131         NaN  thompson  thompson
# 133         NaN  thompson  thompson
# 47          NaN  thompson  thompson
#
# [1395 rows x 21 columns]

# %%
# rename name_of_contributor to name

df = df.rename(columns={'name_of_contributor': 'name', })

# %%
df = df[['name', 'amount', 'committee_name', 'position', 'contest', 'slate', 'race']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [3368], line 1
# ----> 1 df = df[['name', 'amount', 'committee_name', 'position', 'contest', 'slate', 'race']]
#
# File ~/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages/pandas/core/frame.py:3810, in DataFrame.__getitem__(self, key)
#    3808     if is_iterator(key):
#    3809         key = list(key)
# -> 3810     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3812 # take() does not accept boolean indexers
#    3813 if getattr(indexer, "dtype", None) == bool:
#
# File ~/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages/pandas/core/indexes/base.py:6111, in Index._get_indexer_strict(self, key, axis_name)
#    6108 else:
#    6109     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6111 self._raise_if_missing(keyarr, indexer, axis_name)
#    6113 keyarr = self.take(indexer)
#    6114 if isinstance(key, Index):
#    6115     # GH 42790 - Preserve name from an Index
#
# File ~/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages/pandas/core/indexes/base.py:6174, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6171     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6173 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6174 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['name', 'slate', 'race'] not in index"
