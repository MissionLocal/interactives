# %%
import pandas as pd
import os

# %%
# read csv 

df = pd.read_csv('./raw_files/data_20240227.csv')

# %%
df
# Out:
#      Election Date    Contest Type                              Contest  \
# 0         3/5/2024       CANDIDATE  DEMOCRATIC COUNTY CENTRAL - 19TH AD
# 1         3/5/2024       CANDIDATE  DEMOCRATIC COUNTY CENTRAL - 19TH AD
# 2         3/5/2024       CANDIDATE  DEMOCRATIC COUNTY CENTRAL - 19TH AD
# 3         3/5/2024       CANDIDATE  DEMOCRATIC COUNTY CENTRAL - 19TH AD
# 4         3/5/2024       CANDIDATE  DEMOCRATIC COUNTY CENTRAL - 19TH AD
# ...            ...             ...                                  ...
# 3802      3/5/2024  BALLOT MEASURE                            MEASURE E
# 3803      3/5/2024  BALLOT MEASURE                    MULTIPLE MEASURES
# 3804      3/5/2024  BALLOT MEASURE                    MULTIPLE MEASURES
# 3805      3/5/2024  BALLOT MEASURE                    MULTIPLE MEASURES
# 3806      3/5/2024       CANDIDATE  DEMOCRATIC COUNTY CENTRAL - 19TH AD
#
#                            Candidate or Measure Position  \
# 0                             CATHERINE STEFANI  SUPPORT
# 1                             CATHERINE STEFANI  SUPPORT
# 2                             CATHERINE STEFANI  SUPPORT
# 3                             CATHERINE STEFANI  SUPPORT
# 4                             CATHERINE STEFANI  SUPPORT
# ...                                         ...      ...
# 3802  POLICE DEPARTMENT POLICIES AND PROCEDURES  SUPPORT
# 3803                           MEASURES E AND F  SUPPORT
# 3804                           MEASURES E AND F  SUPPORT
# 3805                           MEASURES E AND F  SUPPORT
# 3806                                CONNIE CHAN  SUPPORT
#
#                                          Committee Name  \
# 0     CATHERINE STEFANI FOR DEMOCRATIC COUNTY CENTRA...
# 1     CATHERINE STEFANI FOR DEMOCRATIC COUNTY CENTRA...
# 2     CATHERINE STEFANI FOR DEMOCRATIC COUNTY CENTRA...
# 3     CATHERINE STEFANI FOR DEMOCRATIC COUNTY CENTRA...
# 4     CATHERINE STEFANI FOR DEMOCRATIC COUNTY CENTRA...
# ...                                                 ...
# 3802  YES ON E, COMMITTEE FOR A SAFER SAN FRANCISCO ...
# 3803  THE FIGHT FOR SAN FRANCISCO'S FUTURE, SUPPORTI...
# 3804  THE FIGHT FOR SAN FRANCISCO'S FUTURE, SUPPORTI...
# 3805  THE FIGHT FOR SAN FRANCISCO'S FUTURE, SUPPORTI...
# 3806  CONNIE CHAN FOR DEMOCRATIC COUNTY CENTRAL COMM...
#
#                 Transaction Type                 Employer         Occupation  \
# 0         Monetary Contributions                     NONE            RETIRED
# 1         Monetary Contributions  THE RAISER ORGANIZATION     PHILANTHROPIST
# 2         Monetary Contributions         THIGPEN LEGAL PC           ATTORNEY
# 3         Monetary Contributions                     NONE            RETIRED
# 4         Monetary Contributions                   SQUARE  SOFTWARE ENGINEER
# ...                          ...                      ...                ...
# 3802  Non-Monetary Contributions              N/A: ENTITY        N/A: ENTITY
# 3803      Monetary Contributions              N/A: ENTITY        N/A: ENTITY
# 3804      Monetary Contributions              N/A: ENTITY        N/A: ENTITY
# 3805      Monetary Contributions              N/A: ENTITY        N/A: ENTITY
# 3806      Monetary Contributions              N/A: ENTITY        N/A: ENTITY
#
#      Tx Form  Entitycode Tx Entitycode     Amount  \
# 0          A  Individual           IND    $100.00
# 1          A  Individual           IND    $403.00
# 2          A  Individual           IND    $250.00
# 3          A  Individual           IND    $100.00
# 4          A  Individual           IND    $500.00
# ...      ...         ...           ...        ...
# 3802       C      Entity           OTH  $6,155.00
# 3803       A      Entity           OTH  $8,000.00
# 3804       A      Entity           OTH  $8,000.00
# 3805       A      Entity           OTH  $8,000.00
# 3806       A      Entity           SCC  $1,000.00
#
#                                 Filing Nid  \
# 0     2c47bcec-df97-4c1f-92f8-b3f8f928286c
# 1     2c47bcec-df97-4c1f-92f8-b3f8f928286c
# 2     2c47bcec-df97-4c1f-92f8-b3f8f928286c
# 3     2c47bcec-df97-4c1f-92f8-b3f8f928286c
# 4     2c47bcec-df97-4c1f-92f8-b3f8f928286c
# ...                                    ...
# 3802  7458e4db-bded-46b4-bd00-3b119be62c54
# 3803  eeec9dd5-e0b9-406e-9918-d3594aa18bab
# 3804  eeec9dd5-e0b9-406e-9918-d3594aa18bab
# 3805  eeec9dd5-e0b9-406e-9918-d3594aa18bab
# 3806  2197accc-5f7c-4062-8cb8-ebbeda505ceb
#
#                                                    Name     Tx Date  \
# 0                                       KATH TSAKALAKIS   3/24/2023
# 1                                   HELEN HILTON RAISER   3/24/2023
# 2                                      JORDANNA THIGPEN   3/24/2023
# 3                                       MARION BLUMBERG   3/24/2023
# 4                                              BRIAN IP   3/24/2023
# ...                                                 ...         ...
# 3802                                  TOGETHERSF ACTION   1/16/2024
# 3803                GOLD CLUB - SF, LLC(JOSEPH CAROUBA)  10/30/2023
# 3804  SAW ENTERTAINMENT LTD., DBA HUSTLER CLUB(JOSEP...  10/30/2023
# 3805              SFBSC MANAGEMENT, LLC(JOSEPH CAROUBA)  10/30/2023
# 3806                  TEAMSTERS UNION LOCAL NO. 665 PAC  12/23/2023
#
#                               Tx Description   Tx Zip
# 0                                        NaN  94132.0
# 1                                        NaN  94109.0
# 2                                        NaN  90064.0
# 3                                        NaN  94123.0
# 4                                        NaN  94118.0
# ...                                      ...      ...
# 3802  Estd cost of VG updated from $3,347.30  94110.0
# 3803                                     NaN  94105.0
# 3804                                     NaN  94133.0
# 3805                                     NaN  94133.0
# 3806                                     NaN  94108.0
#
# [3807 rows x 18 columns]

# %%
df.columns
# Out:
# Index(['Election Date', 'Contest Type', 'Contest', 'Candidate or Measure',
#        'Position', 'Committee Name', 'Transaction Type', 'Employer',
#        'Occupation', 'Tx Form', 'Entitycode', 'Tx Entitycode', 'Amount',
#        'Filing Nid', 'Name', 'Tx Date', 'Tx Description', 'Tx Zip'],
#       dtype='object')

# %%
df.columns = df.columns.str.replace(' ', '_').str.lower()

# %%
df.head(1)
# Out:
#   election_date contest_type                              contest  \
# 0      3/5/2024    CANDIDATE  DEMOCRATIC COUNTY CENTRAL - 19TH AD
#
#   candidate_or_measure position  \
# 0    CATHERINE STEFANI  SUPPORT
#
#                                       committee_name        transaction_type  \
# 0  CATHERINE STEFANI FOR DEMOCRATIC COUNTY CENTRA...  Monetary Contributions
#
#   employer occupation tx_form  entitycode tx_entitycode   amount  \
# 0     NONE    RETIRED       A  Individual           IND  $100.00
#
#                              filing_nid             name    tx_date  \
# 0  2c47bcec-df97-4c1f-92f8-b3f8f928286c  KATH TSAKALAKIS  3/24/2023
#
#   tx_description   tx_zip
# 0            NaN  94132.0

# %%
df.rename(columns={'contest': 'race', 'candidate_or_measure': 'contest'}, inplace=True)

# %%
df.head(1)
# Out:
#   election_date contest_type                                 race  \
# 0      3/5/2024    CANDIDATE  DEMOCRATIC COUNTY CENTRAL - 19TH AD
#
#              contest position  \
# 0  CATHERINE STEFANI  SUPPORT
#
#                                       committee_name        transaction_type  \
# 0  CATHERINE STEFANI FOR DEMOCRATIC COUNTY CENTRA...  Monetary Contributions
#
#   employer occupation tx_form  entitycode tx_entitycode   amount  \
# 0     NONE    RETIRED       A  Individual           IND  $100.00
#
#                              filing_nid             name    tx_date  \
# 0  2c47bcec-df97-4c1f-92f8-b3f8f928286c  KATH TSAKALAKIS  3/24/2023
#
#   tx_description   tx_zip
# 0            NaN  94132.0

# %%
conditions = {
    'AFFORDABLE HOUSING BOND': 'MEASURE A',
    'POLICE OFFICER STAFFING LEVELS CONDITIONED ON FUTURE FUNDING': 'MEASURE B',
    'REAL ESTATE TRANSFER TAX EXEMPTION AND OFFICE SPACE ALLOCATION': 'MEASURE C',
    'POLICE DEPARTMENT POLICIES AND PROCEDURES': 'MEASURE E',
    'ILLEGAL SUBSTANCE DEPENDENCE SCREENING AND TREATMENT FOR RECIPIENTS OF PUBLIC ASSISTANCE': 'MEASURE F',
    'OFFERING ALGEBRA 1 TO EIGHTH GRADERS': 'MEASURE G'
}

# %%
df['contest'] = df['contest'].replace(conditions)

# %%
# find out the number of unique values in contest

df['contest'].nunique()
# Out:
# 57

# %%
races = {"DEMOCRATIC COUNTY CENTRAL - 17TH AD":'DCCC',
         "DEMOCRATIC COUNTY CENTRAL - 19TH AD":'DCCC',
         "REPUBLICAN COUNTY CENTRAL - 17TH AND 19TH AD":'RCCC',
         "MEASURE A":'Measure',
         "MEASURE G":'Measure',
         "MEASURE E":'Measure',
         "MEASURE B":'Measure',
         "MEASURE F":'Measure',
         "MEASURE C":'Measure'}

# %%
df['race'] = df['race'].replace(races)

# %%
df.race.value_counts()
# Out:
# DCCC                 3309
# Measure               344
# RCCC                  143
# MULTIPLE MEASURES      11
# Name: race, dtype: int64

# %%
df['amount'] = df['amount'].str.replace('[$,()]', '', regex=True)

df['amount'] = df['amount'].astype(float)

# %%
df.dtypes
# Out:
# election_date        object
# contest_type         object
# race                 object
# contest              object
# position             object
# committee_name       object
# transaction_type     object
# employer             object
# occupation           object
# tx_form              object
# entitycode           object
# tx_entitycode        object
# amount              float64
# filing_nid           object
# name                 object
# tx_date              object
# tx_description       object
# tx_zip              float64
# dtype: object

# %%
df.head(5)
# Out:
#   election_date contest_type  race            contest position  \
# 0      3/5/2024    CANDIDATE  DCCC  CATHERINE STEFANI  SUPPORT
# 1      3/5/2024    CANDIDATE  DCCC  CATHERINE STEFANI  SUPPORT
# 2      3/5/2024    CANDIDATE  DCCC  CATHERINE STEFANI  SUPPORT
# 3      3/5/2024    CANDIDATE  DCCC  CATHERINE STEFANI  SUPPORT
# 4      3/5/2024    CANDIDATE  DCCC  CATHERINE STEFANI  SUPPORT
#
#                                       committee_name        transaction_type  \
# 0  CATHERINE STEFANI FOR DEMOCRATIC COUNTY CENTRA...  Monetary Contributions
# 1  CATHERINE STEFANI FOR DEMOCRATIC COUNTY CENTRA...  Monetary Contributions
# 2  CATHERINE STEFANI FOR DEMOCRATIC COUNTY CENTRA...  Monetary Contributions
# 3  CATHERINE STEFANI FOR DEMOCRATIC COUNTY CENTRA...  Monetary Contributions
# 4  CATHERINE STEFANI FOR DEMOCRATIC COUNTY CENTRA...  Monetary Contributions
#
#                   employer         occupation tx_form  entitycode  \
# 0                     NONE            RETIRED       A  Individual
# 1  THE RAISER ORGANIZATION     PHILANTHROPIST       A  Individual
# 2         THIGPEN LEGAL PC           ATTORNEY       A  Individual
# 3                     NONE            RETIRED       A  Individual
# 4                   SQUARE  SOFTWARE ENGINEER       A  Individual
#
#   tx_entitycode  amount                            filing_nid  \
# 0           IND   100.0  2c47bcec-df97-4c1f-92f8-b3f8f928286c
# 1           IND   403.0  2c47bcec-df97-4c1f-92f8-b3f8f928286c
# 2           IND   250.0  2c47bcec-df97-4c1f-92f8-b3f8f928286c
# 3           IND   100.0  2c47bcec-df97-4c1f-92f8-b3f8f928286c
# 4           IND   500.0  2c47bcec-df97-4c1f-92f8-b3f8f928286c
#
#                   name    tx_date tx_description   tx_zip
# 0      KATH TSAKALAKIS  3/24/2023            NaN  94132.0
# 1  HELEN HILTON RAISER  3/24/2023            NaN  94109.0
# 2     JORDANNA THIGPEN  3/24/2023            NaN  90064.0
# 3      MARION BLUMBERG  3/24/2023            NaN  94123.0
# 4             BRIAN IP  3/24/2023            NaN  94118.0

# %%
df['name'] = df['name'].str.title()
df['committee_name'] = df['committee_name'].str.title()
df['position'] = df['position'].str.title()
df['contest_type'] = df['contest_type'].str.title()
df['employer'] = df['employer'].str.title()
df['contest'] = df['contest'].str.title()

# %%
acronyms = {   
    "Sf":"SF",
    "Lp":"LP",
    "Aclu":"ACLU",
    "Sfpd":"SFPD",
    "Llc":"LLC",
    "Dccc":"DCCC", 
    "Pac":"PAC", 
    "Gfc": "GFC",
    "Of":"of",
    "Kmm":"KMM",
    "()":"",
    "LLC()": "LLC",
    "Media()": "Media"
}

# %%
# I want to replace strings in a column based on a dictionary

df['committee_name'] = df['committee_name'].replace(acronyms, regex=True)

# %%
df['name'] = df['name'].replace("Emmet Shear","Emmett Shear")
df['name'] = df['name'].replace("Christian Larsen","Chris Larsen")

# %%
# show me any rows where the committee name is equal to NO ON B, STOP THE COP TAX

df[df['committee_name'] == 'No On B, Stop The Cop Tax']
# Out:
#     election_date    contest_type     race    contest position  \
# 710      3/5/2024  Ballot Measure  Measure  Measure B   Oppose
# 711      3/5/2024  Ballot Measure  Measure  Measure B   Oppose
# 712      3/5/2024  Ballot Measure  Measure  Measure B   Oppose
# 731  No On B, Stop The Cop Tax  Monetary Contributions (Committee)
# 732  No On B, Stop The Cop Tax  Monetary Contributions (Committee)
# 733  No On B, Stop The Cop Tax  Monetary Contributions (Committee)
# 734  No On B, Stop The Cop Tax  Monetary Contributions (Committee)
# 735  No On B, Stop The Cop Tax          Non-Monetary Contributions
# 741  No On B, Stop The Cop Tax              Monetary Contributions
# 742  No On B, Stop The Cop Tax              Monetary Contributions
# 743  No On B, Stop The Cop Tax              Monetary Contributions
# 744  No On B, Stop The Cop Tax              Monetary Contributions
# 745  No On B, Stop The Cop Tax              Monetary Contributions
# 746  No On B, Stop The Cop Tax              Monetary Contributions
# 747  No On B, Stop The Cop Tax              Monetary Contributions
# 748  No On B, Stop The Cop Tax              Monetary Contributions
# 749  No On B, Stop The Cop Tax              Monetary Contributions
# 750  No On B, Stop The Cop Tax              Monetary Contributions
# 751  No On B, Stop The Cop Tax                      24-Hour Report
# 758  No On B, Stop The Cop Tax              Monetary Contributions
# 759  No On B, Stop The Cop Tax              Monetary Contributions
# 760  No On B, Stop The Cop Tax              Monetary Contributions
# 761  No On B, Stop The Cop Tax              Monetary Contributions
# 762  No On B, Stop The Cop Tax              Monetary Contributions
# 763  No On B, Stop The Cop Tax              Monetary Contributions
#
#                              employer                         occupation  \
# 710                       N/A: Entity                        N/A: ENTITY
# 711                       N/A: Entity                        N/A: ENTITY
# 712                       N/A: Entity                        N/A: ENTITY
# 713                       N/A: Entity                        N/A: ENTITY
# 714                       N/A: Entity                        N/A: ENTITY
# 715                       N/A: Entity                        N/A: ENTITY
# 716                       N/A: Entity                        N/A: ENTITY
# 717                       N/A: Entity                        N/A: ENTITY
# 718                       N/A: Entity                        N/A: ENTITY
# 719                       N/A: Entity                        N/A: ENTITY
# 720                       N/A: Entity                        N/A: ENTITY
# 721                       N/A: Entity                        N/A: ENTITY
# 726              San Francisco Toyota           EXECUTIVE VICE PRESIDENT
# 729                       N/A: Entity                        N/A: ENTITY
# 731                       N/A: Entity                        N/A: ENTITY
# 732                       N/A: Entity                        N/A: ENTITY
# 733                       N/A: Entity                        N/A: ENTITY
# 734                       N/A: Entity                        N/A: ENTITY
# 735                       N/A: Entity                        N/A: ENTITY
# 741                      Y Combinator                           INVESTOR
# 742  City And County Of San Francisco                         SUPERVISOR
# 743                  Sequoia Heritage                            ADVISOR
# 744                     Ground Matrix                           DIRECTOR
# 745                          Sv Angel                     ANGEL INVESTOR
# 746                            Ripple                           CHAIRMAN
# 747                            Ripple                           CHAIRMAN
# 748                              None                            RETIRED
# 749                            Ripple                           CHAIRMAN
# 750       Trinity Management Services                          PRINCIPAL
# 751                      Y Combinator  PRESIDENT/CHIEF EXECUTIVE OFFICER
# 758                       N/A: Entity                        N/A: ENTITY
# 759                       N/A: Entity                        N/A: ENTITY
# 760                       N/A: Entity                        N/A: ENTITY
# 761                       N/A: Entity                        N/A: ENTITY
# 762                       N/A: Entity                        N/A: ENTITY
# 763                       N/A: Entity                        N/A: ENTITY
#
#     tx_form  entitycode tx_entitycode    amount  \
# 710       A   Committee           COM   25000.0
# 726                                       NaN  94949.0
# 729                                       NaN  90064.0
# 731                                       NaN  94102.0
# 732                                       NaN  94108.0
# 733                                       NaN  94103.0
# 734                                       NaN  94118.0
# 735  NON-MONETARY CONTRIBUTION OF SLATE MAIL.  94103.0
# 741                                       NaN  94114.0
# 742                                       NaN  94103.0
# 743                                       NaN  94103.0
# 744                                       NaN  94108.0
# 745                                       NaN  94108.0
# 746                                       NaN  94118.0
# 747                                       NaN  94118.0
# 748                                       NaN  94115.0
# 749                                       NaN  94118.0
# 750                                       NaN  94127.0
# 751                                       NaN  94110.0
# 758                                       NaN  94104.0
# 759                                       NaN  94103.0
# 760                                       NaN  94103.0
# 761                                       NaN  94122.0
# 762                                       NaN  94104.0
# 763                                       NaN  94133.0

# %%
df.loc[df['committee_name'] == 'No On B, Stop The Cop Tax', 'position'] = 'Oppose'

# %%
df[df['committee_name'] == 'No On B, Stop The Cop Tax']
# Out:
#     election_date    contest_type     race    contest position  \
# 710      3/5/2024  Ballot Measure  Measure  Measure B   Oppose
# 711      3/5/2024  Ballot Measure  Measure  Measure B   Oppose
# 712      3/5/2024  Ballot Measure  Measure  Measure B   Oppose
# 713      3/5/2024  Ballot Measure  Measure  Measure B   Oppose
# 714      3/5/2024  Ballot Measure  Measure  Measure B   Oppose
# 715      3/5/2024  Ballot Measure  Measure  Measure B   Oppose
# 716      3/5/2024  Ballot Measure  Measure  Measure B   Oppose
# 717      3/5/2024  Ballot Measure  Measure  Measure B   Oppose
# 718      3/5/2024  Ballot Measure  Measure  Measure B   Oppose
# 719      3/5/2024  Ballot Measure  Measure  Measure B   Oppose
# 720      3/5/2024  Ballot Measure  Measure  Measure B   Oppose
# 721      3/5/2024  Ballot Measure  Measure  Measure B   Oppose
# 726      3/5/2024  Ballot Measure  Measure  Measure B   Oppose
# 729      3/5/2024  Ballot Measure  Measure  Measure B   Oppose
# 731      3/5/2024  Ballot Measure  Measure  Measure B   Oppose
# 732      3/5/2024  Ballot Measure  Measure  Measure B   Oppose
# 733      3/5/2024  Ballot Measure  Measure  Measure B   Oppose
# 734      3/5/2024  Ballot Measure  Measure  Measure B   Oppose
# 735      3/5/2024  Ballot Measure  Measure  Measure B   Oppose
# 741      3/5/2024  Ballot Measure  Measure  Measure B   Oppose
# 742      3/5/2024  Ballot Measure  Measure  Measure B   Oppose
# 743      3/5/2024  Ballot Measure  Measure  Measure B   Oppose
# 744      3/5/2024  Ballot Measure  Measure  Measure B   Oppose
# 745      3/5/2024  Ballot Measure  Measure  Measure B   Oppose
# 746      3/5/2024  Ballot Measure  Measure  Measure B   Oppose
# 747      3/5/2024  Ballot Measure  Measure  Measure B   Oppose
# 748      3/5/2024  Ballot Measure  Measure  Measure B   Oppose
# 749      3/5/2024  Ballot Measure  Measure  Measure B   Oppose
# 750      3/5/2024  Ballot Measure  Measure  Measure B   Oppose
# 751      3/5/2024  Ballot Measure  Measure  Measure B   Oppose
# 758      3/5/2024  Ballot Measure  Measure  Measure B   Oppose
# 759      3/5/2024  Ballot Measure  Measure  Measure B   Oppose
# 760      3/5/2024  Ballot Measure  Measure  Measure B   Oppose
# 761      3/5/2024  Ballot Measure  Measure  Measure B   Oppose
# 762      3/5/2024  Ballot Measure  Measure  Measure B   Oppose
# 763      3/5/2024  Ballot Measure  Measure  Measure B   Oppose
#
#                 committee_name                    transaction_type  \
# 710  No On B, Stop The Cop Tax  Monetary Contributions (Committee)
# 711  No On B, Stop The Cop Tax  Monetary Contributions (Committee)
# 712  No On B, Stop The Cop Tax  Monetary Contributions (Committee)
# 713  No On B, Stop The Cop Tax  Monetary Contributions (Committee)
# 714  No On B, Stop The Cop Tax          Non-Monetary Contributions
# 715  No On B, Stop The Cop Tax          Non-Monetary Contributions
# 716  No On B, Stop The Cop Tax          Non-Monetary Contributions
# 717  No On B, Stop The Cop Tax          Non-Monetary Contributions
# 718  No On B, Stop The Cop Tax          Non-Monetary Contributions
# 719  No On B, Stop The Cop Tax          Non-Monetary Contributions
# 720  No On B, Stop The Cop Tax                      24-Hour Report
# 721  No On B, Stop The Cop Tax                      24-Hour Report
# 726  No On B, Stop The Cop Tax              Monetary Contributions
# 729  No On B, Stop The Cop Tax              Monetary Contributions
# 731  No On B, Stop The Cop Tax  Monetary Contributions (Committee)
# 732  No On B, Stop The Cop Tax  Monetary Contributions (Committee)
# 733  No On B, Stop The Cop Tax  Monetary Contributions (Committee)
# 734  No On B, Stop The Cop Tax  Monetary Contributions (Committee)
# 735  No On B, Stop The Cop Tax          Non-Monetary Contributions
# 741  No On B, Stop The Cop Tax              Monetary Contributions
# 742  No On B, Stop The Cop Tax              Monetary Contributions
# 743  No On B, Stop The Cop Tax              Monetary Contributions
# 744  No On B, Stop The Cop Tax              Monetary Contributions
# 745  No On B, Stop The Cop Tax              Monetary Contributions
# 746  No On B, Stop The Cop Tax              Monetary Contributions
# 747  No On B, Stop The Cop Tax              Monetary Contributions
# 748  No On B, Stop The Cop Tax              Monetary Contributions
# 749  No On B, Stop The Cop Tax              Monetary Contributions
# 750  No On B, Stop The Cop Tax              Monetary Contributions
# 751  No On B, Stop The Cop Tax                      24-Hour Report
# 758  No On B, Stop The Cop Tax              Monetary Contributions
# 759  No On B, Stop The Cop Tax              Monetary Contributions
# 760  No On B, Stop The Cop Tax              Monetary Contributions
# 761  No On B, Stop The Cop Tax              Monetary Contributions
# 762  No On B, Stop The Cop Tax              Monetary Contributions
# 763  No On B, Stop The Cop Tax              Monetary Contributions
#
#                              employer                         occupation  \
# 710                       N/A: Entity                        N/A: ENTITY
# 711                       N/A: Entity                        N/A: ENTITY
# 712                       N/A: Entity                        N/A: ENTITY
# 713                       N/A: Entity                        N/A: ENTITY
# 714                       N/A: Entity                        N/A: ENTITY
# 715                       N/A: Entity                        N/A: ENTITY
# 716                       N/A: Entity                        N/A: ENTITY
# 717                       N/A: Entity                        N/A: ENTITY
# 718                       N/A: Entity                        N/A: ENTITY
# 719                       N/A: Entity                        N/A: ENTITY
# 720                       N/A: Entity                        N/A: ENTITY
# 721                       N/A: Entity                        N/A: ENTITY
# 726              San Francisco Toyota           EXECUTIVE VICE PRESIDENT
# 729                       N/A: Entity                        N/A: ENTITY
# 731                       N/A: Entity                        N/A: ENTITY
# 732                       N/A: Entity                        N/A: ENTITY
# 733                       N/A: Entity                        N/A: ENTITY
# 734                       N/A: Entity                        N/A: ENTITY
# 735                       N/A: Entity                        N/A: ENTITY
# 741                      Y Combinator                           INVESTOR
# 742  City And County Of San Francisco                         SUPERVISOR
# 743                  Sequoia Heritage                            ADVISOR
# 744                     Ground Matrix                           DIRECTOR
# 745                          Sv Angel                     ANGEL INVESTOR
# 746                            Ripple                           CHAIRMAN
# 747                            Ripple                           CHAIRMAN
# 748                              None                            RETIRED
# 749                            Ripple                           CHAIRMAN
# 750       Trinity Management Services                          PRINCIPAL
# 751                      Y Combinator  PRESIDENT/CHIEF EXECUTIVE OFFICER
# 758                       N/A: Entity                        N/A: ENTITY
# 759                       N/A: Entity                        N/A: ENTITY
# 760                       N/A: Entity                        N/A: ENTITY
# 761                       N/A: Entity                        N/A: ENTITY
# 762                       N/A: Entity                        N/A: ENTITY
# 763                       N/A: Entity                        N/A: ENTITY
#
#     tx_form  entitycode tx_entitycode    amount  \
# 710       A   Committee           COM   25000.0
# 711       A   Committee           COM   10000.0
# 712       A   Committee           COM    9860.0
# 713       A   Committee           COM   17500.0
# 714       C   Committee           COM  100000.0
# 715       C   Committee           COM  260000.0
# 716       C   Committee           COM   40000.0
# 717       C   Committee           COM   20000.0
# 718       C   Committee           COM  200000.0
# 719       C   Committee           COM   40000.0
# 720  F497P1   Committee           COM  140000.0
# 721  F497P1   Committee           COM    8400.0
# 726       A  Individual           IND    5000.0
# 729       A      Entity           OTH   15000.0
# 731       A   Committee           COM   10000.0
# 732       A   Committee           COM   25000.0
# 733       A   Committee           COM   10000.0
# 734       A   Committee           COM    2000.0
# 735       C   Committee           COM    5000.0
# 741       A  Individual           IND    2000.0
# 742       A  Individual           IND     500.0
# 743       A  Individual           IND   50000.0
# 744       A  Individual           IND     500.0
# 745       A  Individual           IND   25000.0
# 746       A  Individual           IND   50000.0
# 747       A  Individual           IND  150000.0
# 748       A  Individual           IND   25000.0
# 749       A  Individual           IND   50000.0
# 750       A  Individual           IND     500.0
# 751  F497P1  Individual           IND   10000.0
# 758       A      Entity           OTH   10000.0
# 759       A      Entity           OTH    5000.0
# 760       A      Entity           OTH    5000.0
# 761       A      Entity           OTH   10000.0
# 762       A      Entity           OTH    2500.0
# 763       A      Entity           OTH    5000.0
#
#                                filing_nid  \
# 710  ec471c7a-ce11-4026-8995-8f59534e5ef2
# 711  39cf9ac7-e3c1-4681-b9e2-912ad9720ab2
# 712  39cf9ac7-e3c1-4681-b9e2-912ad9720ab2
# 713  ec471c7a-ce11-4026-8995-8f59534e5ef2
# 714  ec471c7a-ce11-4026-8995-8f59534e5ef2
# 715  ec471c7a-ce11-4026-8995-8f59534e5ef2
# 716  ec471c7a-ce11-4026-8995-8f59534e5ef2
# 717  ec471c7a-ce11-4026-8995-8f59534e5ef2
# 718  ec471c7a-ce11-4026-8995-8f59534e5ef2
# 719  ec471c7a-ce11-4026-8995-8f59534e5ef2
# 720  f62423d4-c8fc-4e93-b65a-b42a26c147eb
# 750                                Maryanne Sangiacomo   2/16/2024
# 751                                          Garry Tan   2/21/2024
# 758        Tmg Partners R.E., Llc(Michael Covarrubias)   1/23/2024
# 759    Anderson Enterprises Inc. Dba Royal Motor Sales   1/27/2024
# 760                        Trinity Management Services   1/31/2024
# 761         San Francisco Coalition For Better Housing    2/5/2024
# 762                         Reuben Junius And Rose Llp    2/6/2024
# 763               Sfbsc Management Llc(Joseph Carouba)   2/13/2024
#
#                                tx_description   tx_zip
# 710                                       NaN  95814.0
# 711                                       NaN  94901.0
# 712                                       NaN  94901.0
# 713                                       NaN  94901.0
# 714  NON-MONETARY CONTRIBUTION OF SLATE MAIL.  94901.0
# 715  NON-MONETARY CONTRIBUTION OF SLATE MAIL.  94901.0
# 716  NON-MONETARY CONTRIBUTION OF SLATE MAIL.  94901.0
# 717  NON-MONETARY CONTRIBUTION OF SLATE MAIL.  94901.0
# 718  NON-MONETARY CONTRIBUTION OF SLATE MAIL.  94901.0
# 719  NON-MONETARY CONTRIBUTION OF SLATE MAIL.  94901.0
# 720                                       NaN  94901.0
# 721                                       NaN  94901.0
# 726                                       NaN  94949.0
# 729                                       NaN  90064.0
# 731                                       NaN  94102.0
# 732                                       NaN  94108.0
# 733                                       NaN  94103.0
# 734                                       NaN  94118.0
# 735  NON-MONETARY CONTRIBUTION OF SLATE MAIL.  94103.0
# 741                                       NaN  94114.0
# 742                                       NaN  94103.0
# 743                                       NaN  94103.0
# 744                                       NaN  94108.0
# 745                                       NaN  94108.0
# 746                                       NaN  94118.0
# 747                                       NaN  94118.0
# 748                                       NaN  94115.0
# 749                                       NaN  94118.0
# 750                                       NaN  94127.0
# 751                                       NaN  94110.0
# 758                                       NaN  94104.0
# 759                                       NaN  94103.0
# 760                                       NaN  94103.0
# 761                                       NaN  94122.0
# 762                                       NaN  94104.0
# 763                                       NaN  94133.0

# %%
df['name'] = df['name'].replace("American Civil Liberties Union","ACLU")

# %%
df['name'] = df['name'].replace(acronyms, regex=True)

# %%
slates_df = pd.read_csv('candidates_edited.csv')

# %%
slates_df.describe()
# Out:
#                  contest        slate
# count                 48           48
# unique                48            2
# top     Adolfo Velasquez  progressive
# freq                   1           24

# %%
# make a list of the candidares from df['contest'].nunique()    

candidates_list = df['contest'].unique()

# %%
len(candidates_list)
# Out:
# 57

# %% [markdown]
# THIS is where I need to check the number of candidates in the data matches slates_df
#
# The latest change I made was updating "Michael Chen" to "Mike Chen" and adding Gordon Mar, progressive to slates_df

# %%
# join the two dataframes

df = df.merge(slates_df, how='left', left_on='contest', right_on='contest')

# %%
df
# Out:
#      election_date    contest_type               race            contest  \
# 0         3/5/2024       Candidate               DCCC  Catherine Stefani
# 1         3/5/2024       Candidate               DCCC  Catherine Stefani
# 2         3/5/2024       Candidate               DCCC  Catherine Stefani
# 3         3/5/2024       Candidate               DCCC  Catherine Stefani
# 4         3/5/2024       Candidate               DCCC  Catherine Stefani
# ...            ...             ...                ...                ...
# 3802      3/5/2024  Ballot Measure            Measure          Measure E
# 3803      3/5/2024  Ballot Measure  MULTIPLE MEASURES   Measures E And F
# 3804      3/5/2024  Ballot Measure  MULTIPLE MEASURES   Measures E And F
# 3805      3/5/2024  Ballot Measure  MULTIPLE MEASURES   Measures E And F
# 3806      3/5/2024       Candidate               DCCC        Connie Chan
#
#      position                                     committee_name  \
# 0     Support  Catherine Stefani For Democratic County Centra...
# 1     Support  Catherine Stefani For Democratic County Centra...
# 2     Support  Catherine Stefani For Democratic County Centra...
# 3     Support  Catherine Stefani For Democratic County Centra...
# 4     Support  Catherine Stefani For Democratic County Centra...
# ...       ...                                                ...
# 3802  Support  Yes On E, Committee For A Safer San Francisco ...
# 3803  Support  The Fight For San Francisco'S Future, Supporti...
# 3804  Support  The Fight For San Francisco'S Future, Supporti...
# 3805  Support  The Fight For San Francisco'S Future, Supporti...
# 3806  Support  Connie Chan For Democratic County Central Comm...
#
#                 transaction_type                 employer         occupation  \
# 0         Monetary Contributions                     None            RETIRED
# 1         Monetary Contributions  The Raiser Organization     PHILANTHROPIST
# 2         Monetary Contributions         Thigpen Legal Pc           ATTORNEY
# 3         Monetary Contributions                     None            RETIRED
# 4         Monetary Contributions                   Square  SOFTWARE ENGINEER
# ...                          ...                      ...                ...
# 3802  Non-Monetary Contributions              N/A: Entity        N/A: ENTITY
# 3803      Monetary Contributions              N/A: Entity        N/A: ENTITY
# 3804      Monetary Contributions              N/A: Entity        N/A: ENTITY
# 3805      Monetary Contributions              N/A: Entity        N/A: ENTITY
# 3806      Monetary Contributions              N/A: Entity        N/A: ENTITY
#
#      tx_form  entitycode tx_entitycode  amount  \
# 0          A  Individual           IND   100.0
# 1          A  Individual           IND   403.0
# 2          A  Individual           IND   250.0
# 3          A  Individual           IND   100.0
# 4          A  Individual           IND   500.0
# ...      ...         ...           ...     ...
# 3802       C      Entity           OTH  6155.0
# 3803       A      Entity           OTH  8000.0
# 3804       A      Entity           OTH  8000.0
# 3805       A      Entity           OTH  8000.0
# 3806       A      Entity           SCC  1000.0
#
#                                 filing_nid  \
# 0     2c47bcec-df97-4c1f-92f8-b3f8f928286c
# 1     2c47bcec-df97-4c1f-92f8-b3f8f928286c
# 2     2c47bcec-df97-4c1f-92f8-b3f8f928286c
# 3     2c47bcec-df97-4c1f-92f8-b3f8f928286c
# 4     2c47bcec-df97-4c1f-92f8-b3f8f928286c
# ...                                    ...
# 3802  7458e4db-bded-46b4-bd00-3b119be62c54
# 3803  eeec9dd5-e0b9-406e-9918-d3594aa18bab
# 3804  eeec9dd5-e0b9-406e-9918-d3594aa18bab
# 3805  eeec9dd5-e0b9-406e-9918-d3594aa18bab
# 3806  2197accc-5f7c-4062-8cb8-ebbeda505ceb
#
#                                                    name     tx_date  \
# 0                                       Kath Tsakalakis   3/24/2023
# 1                                   Helen Hilton Raiser   3/24/2023
# 2                                      Jordanna Thigpen   3/24/2023
# 3                                       Marion Blumberg   3/24/2023
# 4                                              Brian Ip   3/24/2023
# ...                                                 ...         ...
# 3802                                  Togethersf Action   1/16/2024
# 3803                Gold Club - SF, LLC(Joseph Carouba)  10/30/2023
# 3804  Saw Entertainment Ltd., Dba Hustler Club(Josep...  10/30/2023
# 3805              SFbsc Management, LLC(Joseph Carouba)  10/30/2023
# 3806                  Teamsters Union Local No. 665 PAC  12/23/2023
#
#                               tx_description   tx_zip        slate
# 0                                        NaN  94132.0     moderate
# 1                                        NaN  94109.0     moderate
# 2                                        NaN  90064.0     moderate
# 3                                        NaN  94123.0     moderate
# 4                                        NaN  94118.0     moderate
# ...                                      ...      ...          ...
# 3802  Estd cost of VG updated from $3,347.30  94110.0          NaN
# 3803                                     NaN  94105.0          NaN
# 3804                                     NaN  94133.0          NaN
# 3805                                     NaN  94133.0          NaN
# 3806                                     NaN  94108.0  progressive
#
# [3807 rows x 19 columns]

# %%
df.position.value_counts()
# Out:
# Support    3746
# Oppose       61
# Name: position, dtype: int64

# %%
# show me rows based on a condition

measures = df[df['race'] == 'Measure']

# %%
measures.groupby('position').sum()
# Out:
# /var/folders/_0/x7xh_2c16jq4chdcqrg28fr40000gn/T/ipykernel_1434/2472117559.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   measures.groupby('position').sum()
#              amount      tx_zip
# position
# Oppose    1642372.0   5567993.0
# Support   4319033.0  25294093.0

# %%
# group by position AND measure and calculate the sum of the amount

measures.groupby(['contest', 'position']).sum()
# Out:
# /var/folders/_0/x7xh_2c16jq4chdcqrg28fr40000gn/T/ipykernel_1434/855163696.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   measures.groupby(['contest', 'position']).sum()
#                        amount     tx_zip
# contest   position
# Measure A Support    786989.0  6776866.0
# Measure B Oppose    1343760.0  3395183.0
#           Support    607500.0   376930.0
# Measure C Oppose      63600.0   848707.0
#           Support    369348.0  2269904.0
# Measure E Oppose     210100.0   474463.0
#           Support   1729510.0  9457498.0
# Measure F Oppose      24912.0   849640.0
#           Support    650905.0  2069823.0
# Measure G Support    174781.0  4343072.0

# %%
measures.groupby('contest').sum()
# Out:
# /var/folders/_0/x7xh_2c16jq4chdcqrg28fr40000gn/T/ipykernel_1434/345912410.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   measures.groupby('contest').sum()
#               amount     tx_zip
# contest
# Measure A   786989.0  6776866.0
# Measure B  1951260.0  3772113.0
# Measure C   432948.0  3118611.0
# Measure E  1939610.0  9931961.0
# Measure F   675817.0  2919463.0
# Measure G   174781.0  4343072.0

# %%
# find the sum per position
measures.groupby('position').sum()
# Out:
# /var/folders/_0/x7xh_2c16jq4chdcqrg28fr40000gn/T/ipykernel_1434/1749022360.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   measures.groupby('position').sum()
#              amount      tx_zip
# position
# Oppose    1642372.0   5567993.0
# Support   4319033.0  25294093.0

# %% [markdown]
# Make sure here we have a df with the same number of rows as in the original data

# %%
df = df[['name', 'amount', 'committee_name', 'position', 'contest', 'slate', 'race']]

# %%
# if the name and contest are the same, group by name and contest and sum the amount, keep all the other columns

df = df.groupby(['name', 'contest']).agg({'amount':'sum', 'committee_name':'first', 'position':'first', 'slate':'first', 'race':'first'}).reset_index()

# %%
df
# Out:
#                                name                   contest   amount  \
# 0        1266 Ninth LLC(Dan Safier)                 Measure A    375.0
# 1       3333 California(Dan Safier)                 Measure A  13900.0
# 2       3700 California(Dan Safier)                 Measure A  11900.0
# 3     A San Francisco For All of Us                 Measure F   7500.0
# 4                         A. Sparks            Michael Nguyen    100.0
# ...                             ...                       ...      ...
# 2665                 Zalaikha Lodin            Sydney Simpson    150.0
# 2666                   Zhengren Yan  Multiple Candidates Rccc    100.0
# 2667                     Zhihan Zou               Natalie Gee    100.0
# 2668                     Zoe Kelman              Joshua Ochoa    250.0
# 2669                  Zoe Scheinman               Lyn Werbach    100.0
#
#                                          committee_name position        slate  \
# 0                             Affordable Housing For SF  Support         None
# 1                             Affordable Housing For SF  Support         None
# 2                             Affordable Housing For SF  Support         None
# 3     Yes On F, For Treatment, Compassion And Accoun...  Support         None
# 4     Michael Nguyen For Democratic County Central C...  Support  progressive
# ...                                                 ...      ...          ...
# 2665  Sydney Simpson For Democratic County Central C...  Support  progressive
# 2666  Briones Society PAC Supporting Our San Francis...  Support         None
# 2667  Natalie Gee For Democratic County Central Comm...  Support  progressive
# 2668             Joshua Rudy Ochoa For DCCC Member 2024  Support  progressive
# 2669  Lyn Werbach For Democratic County Central Comm...  Support     moderate
#
#          race
# 0     Measure
# 1     Measure
# 2     Measure
# 3     Measure
# 4        DCCC
# ...       ...
# 2665     DCCC
# 2666     RCCC
# 2667     DCCC
# 2668     DCCC
# 2669     DCCC
#
# [2670 rows x 7 columns]

# %%
judges_df = pd.read_csv('./judges.csv')

# %%
judges_df
# Out:
#                  name  contest  \
# 0              A Chun   Seat 1
# 1      A. Marisa Chun   Seat 1
# 2      A. Marisa Chun  Seat 13
# 3        Aaron Peskin   Seat 1
# 4        Aaron Peskin   Seat 1
# ...               ...      ...
# 1276          Yen Hui  Seat 13
# 1277          Yj Choi  Seat 13
# 1278  Zachary Alinder   Seat 1
# 1279    Zachary Stobo   Seat 1
# 1280    Zachary Stobo  Seat 13
#
#                                          committee_name  amount position  \
# 0                     Begert 2024; Retain Judge Michael   500.0    right
# 1     Begert And Patrick Thompson; Safe And Accounta...   250.0    right
# 2     Begert And Patrick Thompson; Safe And Accounta...   250.0    right
# 3                     Begert 2024; Retain Judge Michael   100.0    right
# 4     Begert And Patrick Thompson; Safe And Accounta...  1000.0    right
# ...                                                 ...     ...      ...
# 1276  Roland For Superior Court Judge 2024; Jean Myu...   100.0     left
# 1277  Roland For Superior Court Judge 2024; Jean Myu...   100.0     left
# 1278                  Begert 2024; Retain Judge Michael   250.0    right
# 1279         Zecher For Superior Court Judge 2024; Chip   500.0     left
# 1280  Roland For Superior Court Judge 2024; Jean Myu...   500.0     left
#
#      slate   race
# 0     None  judge
# 1     None  judge
# 2     None  judge
# 3     None  judge
# 4     None  judge
# ...    ...    ...
# 1276  None  judge
# 1277  None  judge
# 1278  None  judge
# 1279  None  judge
# 1280  None  judge
#
# [1281 rows x 7 columns]

# %%
df = pd.concat([df, judges_df])

# %%
df
# Out:
#                                name         contest   amount  \
# 0        1266 Ninth LLC(Dan Safier)       Measure A    375.0
# 1       3333 California(Dan Safier)       Measure A  13900.0
# 2       3700 California(Dan Safier)       Measure A  11900.0
# 3     A San Francisco For All of Us       Measure F   7500.0
# 4                         A. Sparks  Michael Nguyen    100.0
# ...                             ...             ...      ...
# 1276                        Yen Hui         Seat 13    100.0
# 1277                        Yj Choi         Seat 13    100.0
# 1278                Zachary Alinder          Seat 1    250.0
# 1279                  Zachary Stobo          Seat 1    500.0
# 1280                  Zachary Stobo         Seat 13    500.0
#
#                                          committee_name position        slate  \
# 0                             Affordable Housing For SF  Support         None
# 1                             Affordable Housing For SF  Support         None
# 2                             Affordable Housing For SF  Support         None
# 3     Yes On F, For Treatment, Compassion And Accoun...  Support         None
# 4     Michael Nguyen For Democratic County Central C...  Support  progressive
# ...                                                 ...      ...          ...
# 1276  Roland For Superior Court Judge 2024; Jean Myu...     left         None
# 1277  Roland For Superior Court Judge 2024; Jean Myu...     left         None
# 1278                  Begert 2024; Retain Judge Michael    right         None
# 1279         Zecher For Superior Court Judge 2024; Chip     left         None
# 1280  Roland For Superior Court Judge 2024; Jean Myu...     left         None
#
#          race
# 0     Measure
# 1     Measure
# 2     Measure
# 3     Measure
# 4        DCCC
# ...       ...
# 1276    judge
# 1277    judge
# 1278    judge
# 1279    judge
# 1280    judge
#
# [3951 rows x 7 columns]

# %%
# show rows that are NaN

df[df['amount'].isna()]
# Out:
# Empty DataFrame
# Columns: [name, contest, amount, committee_name, position, slate, race]
# Index: []

# %%
# show rows in amount column that are null

df[df['amount'] == 0]
# Out:
#                        name      contest  amount  \
# 2548  Unitemized Schedule I  Luis Zamora     0.0
# 2549  Unitemized Schedule I    Measure E     0.0
# 73       Anthony Schoenberg      Seat 13     0.0
# 222         Colin Alexander      Seat 13     0.0
# 290          David Mitchell      Seat 13     0.0
# 622          Julius De Guia      Seat 13     0.0
# 817            Matt Donahue      Seat 13     0.0
# 1050          Ronald Sabraw      Seat 13     0.0
#
#                                          committee_name position     slate  \
# 2548  Luis Zamora [Democratic County Central Committ...  Support  moderate
# 2549  Yes On E, Committee For A Safer San Francisco ...  Support      None
# 73                  Thompson 2024; Retain Judge Patrick    right      None
# 222   Roland For Superior Court Judge 2024; Jean Myu...     left      None
# 290   Roland For Superior Court Judge 2024; Jean Myu...     left      None
# 622   Roland For Superior Court Judge 2024; Jean Myu...     left      None
# 817   Roland For Superior Court Judge 2024; Jean Myu...     left      None
# 1050                Thompson 2024; Retain Judge Patrick    right      None
#
#          race
# 2548     DCCC
# 2549  Measure
# 73      judge
# 222     judge
# 290     judge
# 622     judge
# 817     judge
# 1050    judge

# %%
# remove the rows where the amount is 0

df = df[df['amount'] != 0]

# %%
# save as csv

df.to_csv('/Users/kellywaldron/Desktop/interactives/docs/2024-march-ballots-desktop/data.csv', index=False)
df.to_csv('/Users/kellywaldron/Desktop/interactives/docs/2024-march-ballots-mobile/data.csv', index=False)
df.to_csv('/Users/kellywaldron/Desktop/interactives/docs/2024-march-dccc-desktop/data.csv', index=False)
df.to_csv('/Users/kellywaldron/Desktop/interactives/docs/2024-march-dccc-mobile/data.csv', index=False)
df.to_csv('/Users/kellywaldron/Desktop/interactives/docs/2024-march-judge-candidates-mobile/data.csv', index=False)
df.to_csv('/Users/kellywaldron/Desktop/interactives/docs/2024-march-judge-candidates-desktop/data.csv', index=False)
