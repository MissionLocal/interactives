# %%
import pandas as pd
import os

# %%
# read csv 

df = pd.read_csv('./raw_files/data_20240228.csv')

# %%
df
# Out:
#      Election Date    Contest Type                              Contest  \
# 0         3/5/2024       CANDIDATE  DEMOCRATIC COUNTY CENTRAL - 19TH AD
# 1         3/5/2024       CANDIDATE  DEMOCRATIC COUNTY CENTRAL - 19TH AD
# 2         3/5/2024       CANDIDATE  DEMOCRATIC COUNTY CENTRAL - 19TH AD
# 3         3/5/2024       CANDIDATE  DEMOCRATIC COUNTY CENTRAL - 19TH AD
# 4         3/5/2024       CANDIDATE  DEMOCRATIC COUNTY CENTRAL - 19TH AD
# ...            ...             ...                                  ...
# 3802      3/5/2024  BALLOT MEASURE                            MEASURE E
# 3803      3/5/2024  BALLOT MEASURE                    MULTIPLE MEASURES
# 3804      3/5/2024  BALLOT MEASURE                    MULTIPLE MEASURES
# 3805      3/5/2024  BALLOT MEASURE                    MULTIPLE MEASURES
# 3806      3/5/2024       CANDIDATE  DEMOCRATIC COUNTY CENTRAL - 19TH AD
#
#                            Candidate or Measure Position  \
# 0                             CATHERINE STEFANI  SUPPORT
# 1                             CATHERINE STEFANI  SUPPORT
# 2                             CATHERINE STEFANI  SUPPORT
# 3                             CATHERINE STEFANI  SUPPORT
# 4                             CATHERINE STEFANI  SUPPORT
# ...                                         ...      ...
# 3802  POLICE DEPARTMENT POLICIES AND PROCEDURES  SUPPORT
# 3803                           MEASURES E AND F  SUPPORT
# 3804                           MEASURES E AND F  SUPPORT
# 3805                           MEASURES E AND F  SUPPORT
# 3806                                CONNIE CHAN  SUPPORT
#
#                                          Committee Name  \
# 0     CATHERINE STEFANI FOR DEMOCRATIC COUNTY CENTRA...
# 1     CATHERINE STEFANI FOR DEMOCRATIC COUNTY CENTRA...
# 2     CATHERINE STEFANI FOR DEMOCRATIC COUNTY CENTRA...
# 3     CATHERINE STEFANI FOR DEMOCRATIC COUNTY CENTRA...
# 4     CATHERINE STEFANI FOR DEMOCRATIC COUNTY CENTRA...
# ...                                                 ...
# 3802  YES ON E, COMMITTEE FOR A SAFER SAN FRANCISCO ...
# 3803  THE FIGHT FOR SAN FRANCISCO'S FUTURE, SUPPORTI...
# 3804  THE FIGHT FOR SAN FRANCISCO'S FUTURE, SUPPORTI...
# 3805  THE FIGHT FOR SAN FRANCISCO'S FUTURE, SUPPORTI...
# 3806  CONNIE CHAN FOR DEMOCRATIC COUNTY CENTRAL COMM...
#
#                 Transaction Type                 Employer         Occupation  \
# 0         Monetary Contributions                     NONE            RETIRED
# 1         Monetary Contributions  THE RAISER ORGANIZATION     PHILANTHROPIST
# 2         Monetary Contributions         THIGPEN LEGAL PC           ATTORNEY
# 3         Monetary Contributions                     NONE            RETIRED
# 4         Monetary Contributions                   SQUARE  SOFTWARE ENGINEER
# ...                          ...                      ...                ...
# 3802  Non-Monetary Contributions              N/A: ENTITY        N/A: ENTITY
# 3803      Monetary Contributions              N/A: ENTITY        N/A: ENTITY
# 3804      Monetary Contributions              N/A: ENTITY        N/A: ENTITY
# 3805      Monetary Contributions              N/A: ENTITY        N/A: ENTITY
# 3806      Monetary Contributions              N/A: ENTITY        N/A: ENTITY
#
#      Tx Form  Entitycode Tx Entitycode     Amount  \
# 0          A  Individual           IND    $100.00
# 1          A  Individual           IND    $403.00
# 2          A  Individual           IND    $250.00
# 3          A  Individual           IND    $100.00
# 4          A  Individual           IND    $500.00
# ...      ...         ...           ...        ...
# 3802       C      Entity           OTH  $6,155.00
# 3803       A      Entity           OTH  $8,000.00
# 3804       A      Entity           OTH  $8,000.00
# 3805       A      Entity           OTH  $8,000.00
# 3806       A      Entity           SCC  $1,000.00
#
#                                                    Name  \
# 0                                       KATH TSAKALAKIS
# 1                                   HELEN HILTON RAISER
# 2                                      JORDANNA THIGPEN
# 3                                       MARION BLUMBERG
# 4                                              BRIAN IP
# ...                                                 ...
# 3802                                  TOGETHERSF ACTION
# 3803                GOLD CLUB - SF, LLC(JOSEPH CAROUBA)
# 3804  SAW ENTERTAINMENT LTD., DBA HUSTLER CLUB(JOSEP...
# 3805              SFBSC MANAGEMENT, LLC(JOSEPH CAROUBA)
# 3806                  TEAMSTERS UNION LOCAL NO. 665 PAC
#
#                                 Filing Nid Contest Nid                In City  \
# 0     2c47bcec-df97-4c1f-92f8-b3f8f928286c   206723576          San Francisco
# 1     2c47bcec-df97-4c1f-92f8-b3f8f928286c   206723576          San Francisco
# 2     2c47bcec-df97-4c1f-92f8-b3f8f928286c   206723576  Outside San Francisco
# 3     2c47bcec-df97-4c1f-92f8-b3f8f928286c   206723576          San Francisco
# 4     2c47bcec-df97-4c1f-92f8-b3f8f928286c   206723576          San Francisco
# ...                                    ...         ...                    ...
# 3802  7458e4db-bded-46b4-bd00-3b119be62c54   208885882          San Francisco
# 3803  eeec9dd5-e0b9-406e-9918-d3594aa18bab   MULTI_E_F          San Francisco
# 3804  eeec9dd5-e0b9-406e-9918-d3594aa18bab   MULTI_E_F          San Francisco
# 3805  eeec9dd5-e0b9-406e-9918-d3594aa18bab   MULTI_E_F          San Francisco
# 3806  2197accc-5f7c-4062-8cb8-ebbeda505ceb   206723576          San Francisco
#
#          Tx Date                          Tx Description   Tx Zip
# 0      3/24/2023                                     NaN  94132.0
# 1      3/24/2023                                     NaN  94109.0
# 2      3/24/2023                                     NaN  90064.0
# 3      3/24/2023                                     NaN  94123.0
# 4      3/24/2023                                     NaN  94118.0
# ...          ...                                     ...      ...
# 3802   1/16/2024  Estd cost of VG updated from $3,347.30  94110.0
# 3803  10/30/2023                                     NaN  94105.0
# 3804  10/30/2023                                     NaN  94133.0
# 3805  10/30/2023                                     NaN  94133.0
# 3806  12/23/2023                                     NaN  94108.0
#
# [3807 rows x 20 columns]

# %%
df.columns
# Out:
# Index(['Election Date', 'Contest Type', 'Contest', 'Candidate or Measure',
#        'Position', 'Committee Name', 'Transaction Type', 'Employer',
#        'Occupation', 'Tx Form', 'Entitycode', 'Tx Entitycode', 'Amount',
#        'Name', 'Filing Nid', 'Contest Nid', 'In City', 'Tx Date',
#        'Tx Description', 'Tx Zip'],
#       dtype='object')

# %%
df.columns = df.columns.str.replace(' ', '_').str.lower()

# %%
df.head(1)
# Out:
#   election_date contest_type                              contest  \
# 0      3/5/2024    CANDIDATE  DEMOCRATIC COUNTY CENTRAL - 19TH AD
#
#   candidate_or_measure position  \
# 0    CATHERINE STEFANI  SUPPORT
#
#                                       committee_name        transaction_type  \
# 0  CATHERINE STEFANI FOR DEMOCRATIC COUNTY CENTRA...  Monetary Contributions
#
#   employer occupation tx_form  entitycode tx_entitycode   amount  \
# 0     NONE    RETIRED       A  Individual           IND  $100.00
#
#               name                            filing_nid contest_nid  \
# 0  KATH TSAKALAKIS  2c47bcec-df97-4c1f-92f8-b3f8f928286c   206723576
#
#          in_city    tx_date tx_description   tx_zip
# 0  San Francisco  3/24/2023            NaN  94132.0

# %%
df.rename(columns={'contest': 'race', 'candidate_or_measure': 'contest'}, inplace=True)

# %%
df.head(1)
# Out:
#   election_date contest_type                                 race  \
# 0      3/5/2024    CANDIDATE  DEMOCRATIC COUNTY CENTRAL - 19TH AD
#
#              contest position  \
# 0  CATHERINE STEFANI  SUPPORT
#
#                                       committee_name        transaction_type  \
# 0  CATHERINE STEFANI FOR DEMOCRATIC COUNTY CENTRA...  Monetary Contributions
#
#   employer occupation tx_form  entitycode tx_entitycode   amount  \
# 0     NONE    RETIRED       A  Individual           IND  $100.00
#
#               name                            filing_nid contest_nid  \
# 0  KATH TSAKALAKIS  2c47bcec-df97-4c1f-92f8-b3f8f928286c   206723576
#
#          in_city    tx_date tx_description   tx_zip
# 0  San Francisco  3/24/2023            NaN  94132.0

# %%
conditions = {
    'AFFORDABLE HOUSING BOND': 'Proposition A',
    'POLICE OFFICER STAFFING LEVELS CONDITIONED ON FUTURE FUNDING': 'Proposition B',
    'REAL ESTATE TRANSFER TAX EXEMPTION AND OFFICE SPACE ALLOCATION': 'Proposition C',
    'POLICE DEPARTMENT POLICIES AND PROCEDURES': 'Proposition E',
    'ILLEGAL SUBSTANCE DEPENDENCE SCREENING AND TREATMENT FOR RECIPIENTS OF PUBLIC ASSISTANCE': 'Proposition F',
    'OFFERING ALGEBRA 1 TO EIGHTH GRADERS': 'Proposition G'
}

# %%
df['contest'] = df['contest'].replace(conditions)

# %%
# find out the number of unique values in contest

df['contest'].nunique()
# Out:
# 57

# %%
df
# Out:
#      election_date    contest_type                                 race  \
# 0         3/5/2024       CANDIDATE  DEMOCRATIC COUNTY CENTRAL - 19TH AD
# 1         3/5/2024       CANDIDATE  DEMOCRATIC COUNTY CENTRAL - 19TH AD
# 2         3/5/2024       CANDIDATE  DEMOCRATIC COUNTY CENTRAL - 19TH AD
# 3         3/5/2024       CANDIDATE  DEMOCRATIC COUNTY CENTRAL - 19TH AD
# 4         3/5/2024       CANDIDATE  DEMOCRATIC COUNTY CENTRAL - 19TH AD
# ...            ...             ...                                  ...
# 3802      3/5/2024  BALLOT MEASURE                            MEASURE E
# 3803      3/5/2024  BALLOT MEASURE                    MULTIPLE MEASURES
# 3804      3/5/2024  BALLOT MEASURE                    MULTIPLE MEASURES
# 3805      3/5/2024  BALLOT MEASURE                    MULTIPLE MEASURES
# 3806      3/5/2024       CANDIDATE  DEMOCRATIC COUNTY CENTRAL - 19TH AD
#
#                 contest position  \
# 0     CATHERINE STEFANI  SUPPORT
# 1     CATHERINE STEFANI  SUPPORT
# 2     CATHERINE STEFANI  SUPPORT
# 3     CATHERINE STEFANI  SUPPORT
# 4     CATHERINE STEFANI  SUPPORT
# ...                 ...      ...
# 3802      Proposition E  SUPPORT
# 3803   MEASURES E AND F  SUPPORT
# 3804   MEASURES E AND F  SUPPORT
# 3805   MEASURES E AND F  SUPPORT
# 3806        CONNIE CHAN  SUPPORT
#
#                                          committee_name  \
# 0     CATHERINE STEFANI FOR DEMOCRATIC COUNTY CENTRA...
# 1     CATHERINE STEFANI FOR DEMOCRATIC COUNTY CENTRA...
# 2     CATHERINE STEFANI FOR DEMOCRATIC COUNTY CENTRA...
# 3     CATHERINE STEFANI FOR DEMOCRATIC COUNTY CENTRA...
# 4     CATHERINE STEFANI FOR DEMOCRATIC COUNTY CENTRA...
# ...                                                 ...
# 3802  YES ON E, COMMITTEE FOR A SAFER SAN FRANCISCO ...
# 3803  THE FIGHT FOR SAN FRANCISCO'S FUTURE, SUPPORTI...
# 3804  THE FIGHT FOR SAN FRANCISCO'S FUTURE, SUPPORTI...
# 3805  THE FIGHT FOR SAN FRANCISCO'S FUTURE, SUPPORTI...
# 3806  CONNIE CHAN FOR DEMOCRATIC COUNTY CENTRAL COMM...
#
#                 transaction_type                 employer         occupation  \
# 0         Monetary Contributions                     NONE            RETIRED
# 1         Monetary Contributions  THE RAISER ORGANIZATION     PHILANTHROPIST
# 2         Monetary Contributions         THIGPEN LEGAL PC           ATTORNEY
# 3         Monetary Contributions                     NONE            RETIRED
# 4         Monetary Contributions                   SQUARE  SOFTWARE ENGINEER
# ...                          ...                      ...                ...
# 3802  Non-Monetary Contributions              N/A: ENTITY        N/A: ENTITY
# 3803      Monetary Contributions              N/A: ENTITY        N/A: ENTITY
# 3804      Monetary Contributions              N/A: ENTITY        N/A: ENTITY
# 3805      Monetary Contributions              N/A: ENTITY        N/A: ENTITY
# 3806      Monetary Contributions              N/A: ENTITY        N/A: ENTITY
#
#      tx_form  entitycode tx_entitycode     amount  \
# 0          A  Individual           IND    $100.00
# 1          A  Individual           IND    $403.00
# 2          A  Individual           IND    $250.00
# 3          A  Individual           IND    $100.00
# 4          A  Individual           IND    $500.00
# ...      ...         ...           ...        ...
# 3802       C      Entity           OTH  $6,155.00
# 3803       A      Entity           OTH  $8,000.00
# 3804       A      Entity           OTH  $8,000.00
# 3805       A      Entity           OTH  $8,000.00
# 3806       A      Entity           SCC  $1,000.00
#
#                                                    name  \
# 0                                       KATH TSAKALAKIS
# 1                                   HELEN HILTON RAISER
# 2                                      JORDANNA THIGPEN
# 3                                       MARION BLUMBERG
# 4                                              BRIAN IP
# ...                                                 ...
# 3802                                  TOGETHERSF ACTION
# 3803                GOLD CLUB - SF, LLC(JOSEPH CAROUBA)
# 3804  SAW ENTERTAINMENT LTD., DBA HUSTLER CLUB(JOSEP...
# 3805              SFBSC MANAGEMENT, LLC(JOSEPH CAROUBA)
# 3806                  TEAMSTERS UNION LOCAL NO. 665 PAC
#
#                                 filing_nid contest_nid                in_city  \
# 0     2c47bcec-df97-4c1f-92f8-b3f8f928286c   206723576          San Francisco
# 1     2c47bcec-df97-4c1f-92f8-b3f8f928286c   206723576          San Francisco
# 2     2c47bcec-df97-4c1f-92f8-b3f8f928286c   206723576  Outside San Francisco
# 3     2c47bcec-df97-4c1f-92f8-b3f8f928286c   206723576          San Francisco
# 4     2c47bcec-df97-4c1f-92f8-b3f8f928286c   206723576          San Francisco
# ...                                    ...         ...                    ...
# 3802  7458e4db-bded-46b4-bd00-3b119be62c54   208885882          San Francisco
# 3803  eeec9dd5-e0b9-406e-9918-d3594aa18bab   MULTI_E_F          San Francisco
# 3804  eeec9dd5-e0b9-406e-9918-d3594aa18bab   MULTI_E_F          San Francisco
# 3805  eeec9dd5-e0b9-406e-9918-d3594aa18bab   MULTI_E_F          San Francisco
# 3806  2197accc-5f7c-4062-8cb8-ebbeda505ceb   206723576          San Francisco
#
#          tx_date                          tx_description   tx_zip
# 0      3/24/2023                                     NaN  94132.0
# 1      3/24/2023                                     NaN  94109.0
# 2      3/24/2023                                     NaN  90064.0
# 3      3/24/2023                                     NaN  94123.0
# 4      3/24/2023                                     NaN  94118.0
# ...          ...                                     ...      ...
# 3802   1/16/2024  Estd cost of VG updated from $3,347.30  94110.0
# 3803  10/30/2023                                     NaN  94105.0
# 3804  10/30/2023                                     NaN  94133.0
# 3805  10/30/2023                                     NaN  94133.0
# 3806  12/23/2023                                     NaN  94108.0
#
# [3807 rows x 20 columns]

# %%
# show me the unique values in the races column

df['race'].value_counts()
# Out:
# DEMOCRATIC COUNTY CENTRAL - 17TH AD             2156
# DEMOCRATIC COUNTY CENTRAL - 19TH AD             1153
# REPUBLICAN COUNTY CENTRAL - 17TH AND 19TH AD     143
# MEASURE E                                        110
# MEASURE A                                         76
# MEASURE G                                         50
# MEASURE B                                         40
# MEASURE F                                         34
# MEASURE C                                         34
# MULTIPLE MEASURES                                 11
# Name: race, dtype: int64

# %%
races = {"DEMOCRATIC COUNTY CENTRAL - 17TH AD":'DCCC',
         "DEMOCRATIC COUNTY CENTRAL - 19TH AD":'DCCC',
         "REPUBLICAN COUNTY CENTRAL - 17TH AND 19TH AD":'RCCC',
         "MEASURE A":'Measure',
         "MEASURE G":'Measure',
         "MEASURE E":'Measure',
         "MEASURE B":'Measure',
         "MEASURE F":'Measure',
         "MEASURE C":'Measure'}

# %%
df['race'] = df['race'].replace(races)

# %%
df.race.value_counts()
# Out:
# DCCC                 3309
# Measure               344
# RCCC                  143
# MULTIPLE MEASURES      11
# Name: race, dtype: int64

# %%
df[df['race'] == 'MULTIPLE MEASURES']
# Out:
#      election_date    contest_type               race           contest  \
# 1984      3/5/2024  BALLOT MEASURE  MULTIPLE MEASURES  MEASURES E AND F
# 1996      3/5/2024  BALLOT MEASURE  MULTIPLE MEASURES  MEASURES E AND F
# 3647      3/5/2024  BALLOT MEASURE  MULTIPLE MEASURES  MEASURES E AND F
# 3648      3/5/2024  BALLOT MEASURE  MULTIPLE MEASURES  MEASURES E AND F
# 3649      3/5/2024  BALLOT MEASURE  MULTIPLE MEASURES  MEASURES E AND F
# 3650      3/5/2024  BALLOT MEASURE  MULTIPLE MEASURES  MEASURES E AND F
# 3651      3/5/2024  BALLOT MEASURE  MULTIPLE MEASURES  MEASURES E AND F
# 3652      3/5/2024  BALLOT MEASURE  MULTIPLE MEASURES  MEASURES E AND F
# 3803      3/5/2024  BALLOT MEASURE  MULTIPLE MEASURES  MEASURES E AND F
# 3804      3/5/2024  BALLOT MEASURE  MULTIPLE MEASURES  MEASURES E AND F
# 3805      3/5/2024  BALLOT MEASURE  MULTIPLE MEASURES  MEASURES E AND F
#
#      position                                     committee_name  \
# 1984  SUPPORT  THE FIGHT FOR SAN FRANCISCO'S FUTURE, SUPPORTI...
# 1996  SUPPORT  THE FIGHT FOR SAN FRANCISCO'S FUTURE, SUPPORTI...
# 3647  SUPPORT  THE FIGHT FOR SAN FRANCISCO'S FUTURE, SUPPORTI...
# 3648  SUPPORT  THE FIGHT FOR SAN FRANCISCO'S FUTURE, SUPPORTI...
# 3649  SUPPORT  THE FIGHT FOR SAN FRANCISCO'S FUTURE, SUPPORTI...
# 3650  SUPPORT  THE FIGHT FOR SAN FRANCISCO'S FUTURE, SUPPORTI...
# 3651  SUPPORT  THE FIGHT FOR SAN FRANCISCO'S FUTURE, SUPPORTI...
# 3652  SUPPORT  THE FIGHT FOR SAN FRANCISCO'S FUTURE, SUPPORTI...
# 3803  SUPPORT  THE FIGHT FOR SAN FRANCISCO'S FUTURE, SUPPORTI...
# 3804  SUPPORT  THE FIGHT FOR SAN FRANCISCO'S FUTURE, SUPPORTI...
# 3805  SUPPORT  THE FIGHT FOR SAN FRANCISCO'S FUTURE, SUPPORTI...
#
#             transaction_type                         employer  \
# 1984  Monetary Contributions                      N/A: ENTITY
# 1996  Monetary Contributions                      N/A: ENTITY
# 3647  Monetary Contributions                           RIPPLE
# 3648  Monetary Contributions                             NONE
# 3649  Monetary Contributions  SUSIE TOMPKINS BUELL FOUNDATION
# 3650  Monetary Contributions                     GOSSAMER BIO
# 3651  Monetary Contributions                     Y COMBINATOR
# 3652  Monetary Contributions             PRESIDIO TRUST BOARD
# 3803  Monetary Contributions                      N/A: ENTITY
# 3804  Monetary Contributions                      N/A: ENTITY
# 3805  Monetary Contributions                      N/A: ENTITY
#
#                    occupation tx_form  entitycode tx_entitycode       amount  \
# 1984              N/A: ENTITY       A      Entity           OTH   $10,000.00
# 1996              N/A: ENTITY       A      Entity           SCC   $50,000.00
# 3647       EXECUTIVE CHAIRMAN       A  Individual           IND  $250,000.00
# 3648                  RETIRED       A  Individual           IND   $10,000.00
# 3649                PRESIDENT       A  Individual           IND   $10,000.00
# 3650  CHIEF FINANCIAL OFFICER       A  Individual           IND    $5,000.00
# 3651                  PARTNER       A  Individual           IND   $10,000.00
# 3652               VICE CHAIR       A  Individual           IND    $9,900.00
# 3803              N/A: ENTITY       A      Entity           OTH    $8,000.00
# 3804              N/A: ENTITY       A      Entity           OTH    $8,000.00
# 3805              N/A: ENTITY       A      Entity           OTH    $8,000.00
#
#                                                    name  \
# 1984     RELATED CALIFORNIA RESIDENTIAL LLC(BILL WITTE)
# 1996  NORTHERN CALIFORNIA CARPENTERS REGIONAL COUNCI...
# 3647                                       CHRIS LARSEN
# 3648                                         MARK BUELL
# 3649                                        SUSIE BUELL
# 3650                                    BRYAN M GIRAUDO
# 3651                                       EMMETT SHEAR
# 3652                                       NICOLA MINER
# 3803                GOLD CLUB - SF, LLC(JOSEPH CAROUBA)
# 3804  SAW ENTERTAINMENT LTD., DBA HUSTLER CLUB(JOSEP...
# 3805              SFBSC MANAGEMENT, LLC(JOSEPH CAROUBA)
#
#                                 filing_nid contest_nid                in_city  \
# 1984  eeec9dd5-e0b9-406e-9918-d3594aa18bab   MULTI_E_F  Outside San Francisco
# 1996  eeec9dd5-e0b9-406e-9918-d3594aa18bab   MULTI_E_F  Outside San Francisco
# 3647  eeec9dd5-e0b9-406e-9918-d3594aa18bab   MULTI_E_F          San Francisco
# 3648  eeec9dd5-e0b9-406e-9918-d3594aa18bab   MULTI_E_F          San Francisco
# 3649  eeec9dd5-e0b9-406e-9918-d3594aa18bab   MULTI_E_F          San Francisco
# 3650  7edb78e1-20c2-4189-8b7d-305fbff22dab   MULTI_E_F          San Francisco
# 3651  7e90e5c2-7598-4d97-a0a1-e427905657c6   MULTI_E_F          San Francisco
# 3652  7e90e5c2-7598-4d97-a0a1-e427905657c6   MULTI_E_F          San Francisco
# 3803  eeec9dd5-e0b9-406e-9918-d3594aa18bab   MULTI_E_F          San Francisco
# 3804  eeec9dd5-e0b9-406e-9918-d3594aa18bab   MULTI_E_F          San Francisco
# 3805  eeec9dd5-e0b9-406e-9918-d3594aa18bab   MULTI_E_F          San Francisco
#
#          tx_date tx_description   tx_zip
# 1984  12/18/2023            NaN  92612.0
# 1996   11/6/2023            NaN  94621.0
# 3647  10/27/2023            NaN  94109.0
# 3648  12/11/2023            NaN  94115.0
# 3649  12/27/2023            NaN  94115.0
# 3650    1/9/2024            NaN  94123.0
# 3651   1/23/2024            NaN  94115.0
# 3652    2/3/2024            NaN  94115.0
# 3803  10/30/2023            NaN  94105.0
# 3804  10/30/2023            NaN  94133.0
# 3805  10/30/2023            NaN  94133.0

# %%
multiples_df = df[df['race'] == 'MULTIPLE MEASURES']

# %%
multiples_df['contest'] = 'Proposition E'
multiples_df['race'] = 'Measure'
# Out:
# /var/folders/_0/x7xh_2c16jq4chdcqrg28fr40000gn/T/ipykernel_19163/422729447.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   multiples_df['contest'] = 'Proposition E'
# /var/folders/_0/x7xh_2c16jq4chdcqrg28fr40000gn/T/ipykernel_19163/422729447.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   multiples_df['race'] = 'Measure'

# %%
multiples_copy_df = multiples_df.copy()

# %%
multiples_copy_df['contest'] = 'Proposition F'
multiples_copy_df['race'] = 'Measure'

# %%
df = df[df['race'] != 'MULTIPLE MEASURES']

# %%
df = pd.concat([df, multiples_df, multiples_copy_df])

# %%
df['amount'] = df['amount'].str.replace('[$,()]', '', regex=True)

df['amount'] = df['amount'].astype(float)

# %%
df.dtypes
# Out:
# election_date        object
# contest_type         object
# race                 object
# contest              object
# position             object
# committee_name       object
# transaction_type     object
# employer             object
# occupation           object
# tx_form              object
# entitycode           object
# tx_entitycode        object
# amount              float64
# name                 object
# filing_nid           object
# contest_nid          object
# in_city              object
# tx_date              object
# tx_description       object
# tx_zip              float64
# dtype: object

# %%
df.head(5)
# Out:
#   election_date contest_type  race            contest position  \
# 0      3/5/2024    CANDIDATE  DCCC  CATHERINE STEFANI  SUPPORT
# 1      3/5/2024    CANDIDATE  DCCC  CATHERINE STEFANI  SUPPORT
# 2      3/5/2024    CANDIDATE  DCCC  CATHERINE STEFANI  SUPPORT
# 3      3/5/2024    CANDIDATE  DCCC  CATHERINE STEFANI  SUPPORT
# 4      3/5/2024    CANDIDATE  DCCC  CATHERINE STEFANI  SUPPORT
#
#                                       committee_name        transaction_type  \
# 0  CATHERINE STEFANI FOR DEMOCRATIC COUNTY CENTRA...  Monetary Contributions
# 1  CATHERINE STEFANI FOR DEMOCRATIC COUNTY CENTRA...  Monetary Contributions
# 2  CATHERINE STEFANI FOR DEMOCRATIC COUNTY CENTRA...  Monetary Contributions
# 3  CATHERINE STEFANI FOR DEMOCRATIC COUNTY CENTRA...  Monetary Contributions
# 4  CATHERINE STEFANI FOR DEMOCRATIC COUNTY CENTRA...  Monetary Contributions
#
#                   employer         occupation tx_form  entitycode  \
# 0                     NONE            RETIRED       A  Individual
# 1  THE RAISER ORGANIZATION     PHILANTHROPIST       A  Individual
# 2         THIGPEN LEGAL PC           ATTORNEY       A  Individual
# 3                     NONE            RETIRED       A  Individual
# 4                   SQUARE  SOFTWARE ENGINEER       A  Individual
#
#   tx_entitycode  amount                 name  \
# 0           IND   100.0      KATH TSAKALAKIS
# 1           IND   403.0  HELEN HILTON RAISER
# 2           IND   250.0     JORDANNA THIGPEN
# 3           IND   100.0      MARION BLUMBERG
# 4           IND   500.0             BRIAN IP
#
#                              filing_nid contest_nid                in_city  \
# 0  2c47bcec-df97-4c1f-92f8-b3f8f928286c   206723576          San Francisco
# 1  2c47bcec-df97-4c1f-92f8-b3f8f928286c   206723576          San Francisco
# 2  2c47bcec-df97-4c1f-92f8-b3f8f928286c   206723576  Outside San Francisco
# 3  2c47bcec-df97-4c1f-92f8-b3f8f928286c   206723576          San Francisco
# 4  2c47bcec-df97-4c1f-92f8-b3f8f928286c   206723576          San Francisco
#
#      tx_date tx_description   tx_zip
# 0  3/24/2023            NaN  94132.0
# 1  3/24/2023            NaN  94109.0
# 2  3/24/2023            NaN  90064.0
# 3  3/24/2023            NaN  94123.0
# 4  3/24/2023            NaN  94118.0

# %%
df['name'] = df['name'].str.title()
df['committee_name'] = df['committee_name'].str.title()
df['position'] = df['position'].str.title()
df['contest_type'] = df['contest_type'].str.title()
df['employer'] = df['employer'].str.title()
df['contest'] = df['contest'].str.title()

# %%
acronyms = {   
    "Sf":"SF",
    "Lp":"LP",
    "Aclu":"ACLU",
    "Sfpd":"SFPD",
    "Llc":"LLC",
    "Dccc":"DCCC", 
    "Pac":"PAC", 
    "Gfc": "GFC",
    "Of":"of",
    "Kmm":"KMM",
    "()":"",
    "LLC()": "LLC",
    "Media()": "Media"
}

# %%
# I want to replace strings in a column based on a dictionary

df['committee_name'] = df['committee_name'].replace(acronyms, regex=True)

# %%
df['name'] = df['name'].replace("Emmet Shear","Emmett Shear")
df['name'] = df['name'].replace("Christian Larsen","Chris Larsen")

# %%
df.loc[df['committee_name'] == 'No On B, Stop The Cop Tax', 'position'] = 'Oppose'

# %%
df['name'] = df['name'].replace("American Civil Liberties Union","ACLU")

# %%
df['name'] = df['name'].replace(acronyms, regex=True)

# %%
slates_df = pd.read_csv('candidates_edited.csv')

# %%
slates_df.describe()
# Out:
#                  contest        slate
# count                 48           48
# unique                48            2
# top     Adolfo Velasquez  progressive
# freq                   1           24

# %%
# make a list of the candidares from df['contest'].nunique()    

candidates_list = df['contest'].unique()

# %%
len(candidates_list)
# Out:
# 56

# %% [markdown]
# THIS is where I need to check the number of candidates in the data matches slates_df
#
# The latest change I made was updating "Michael Chen" to "Mike Chen" and adding Gordon Mar, progressive to slates_df

# %%
# join the two dataframes

df = df.merge(slates_df, how='left', left_on='contest', right_on='contest')

# %%
df
# Out:
#      election_date    contest_type     race            contest position  \
# 0         3/5/2024       Candidate     DCCC  Catherine Stefani  Support
# 1         3/5/2024       Candidate     DCCC  Catherine Stefani  Support
# 2         3/5/2024       Candidate     DCCC  Catherine Stefani  Support
# 3         3/5/2024       Candidate     DCCC  Catherine Stefani  Support
# 4         3/5/2024       Candidate     DCCC  Catherine Stefani  Support
# ...            ...             ...      ...                ...      ...
# 3813      3/5/2024  Ballot Measure  Measure      Proposition F  Support
# 3814      3/5/2024  Ballot Measure  Measure      Proposition F  Support
# 3815      3/5/2024  Ballot Measure  Measure      Proposition F  Support
# 3816      3/5/2024  Ballot Measure  Measure      Proposition F  Support
# 3817      3/5/2024  Ballot Measure  Measure      Proposition F  Support
#
#                                          committee_name  \
# 0     Catherine Stefani For Democratic County Centra...
# 1     Catherine Stefani For Democratic County Centra...
# 2     Catherine Stefani For Democratic County Centra...
# 3     Catherine Stefani For Democratic County Centra...
# 4     Catherine Stefani For Democratic County Centra...
# ...                                                 ...
# 3813  The Fight For San Francisco'S Future, Supporti...
# 3814  The Fight For San Francisco'S Future, Supporti...
# 3815  The Fight For San Francisco'S Future, Supporti...
# 3816  The Fight For San Francisco'S Future, Supporti...
# 3817  The Fight For San Francisco'S Future, Supporti...
#
#             transaction_type                 employer         occupation  \
# 0     Monetary Contributions                     None            RETIRED
# 1     Monetary Contributions  The Raiser Organization     PHILANTHROPIST
# 2     Monetary Contributions         Thigpen Legal Pc           ATTORNEY
# 3     Monetary Contributions                     None            RETIRED
# 4     Monetary Contributions                   Square  SOFTWARE ENGINEER
# ...                      ...                      ...                ...
# 3813  Monetary Contributions             Y Combinator            PARTNER
# 3814  Monetary Contributions     Presidio Trust Board         VICE CHAIR
# 3815  Monetary Contributions              N/A: Entity        N/A: ENTITY
# 3816  Monetary Contributions              N/A: Entity        N/A: ENTITY
# 3817  Monetary Contributions              N/A: Entity        N/A: ENTITY
#
#      tx_form  ... tx_entitycode   amount  \
# 0          A  ...           IND    100.0
# 1          A  ...           IND    403.0
# 2          A  ...           IND    250.0
# 3          A  ...           IND    100.0
# 4          A  ...           IND    500.0
# ...      ...  ...           ...      ...
# 3813       A  ...           IND  10000.0
# 3814       A  ...           IND   9900.0
# 3815       A  ...           OTH   8000.0
# 3816       A  ...           OTH   8000.0
# 3817       A  ...           OTH   8000.0
#
#                                                    name  \
# 0                                       Kath Tsakalakis
# 1                                   Helen Hilton Raiser
# 2                                      Jordanna Thigpen
# 3                                       Marion Blumberg
# 4                                              Brian Ip
# ...                                                 ...
# 3813                                       Emmett Shear
# 3814                                       Nicola Miner
# 3815                Gold Club - SF, LLC(Joseph Carouba)
# 3816  Saw Entertainment Ltd., Dba Hustler Club(Josep...
# 3817              SFbsc Management, LLC(Joseph Carouba)
#
#                                 filing_nid contest_nid                in_city  \
# 0     2c47bcec-df97-4c1f-92f8-b3f8f928286c   206723576          San Francisco
# 1     2c47bcec-df97-4c1f-92f8-b3f8f928286c   206723576          San Francisco
# 2     2c47bcec-df97-4c1f-92f8-b3f8f928286c   206723576  Outside San Francisco
# 3     2c47bcec-df97-4c1f-92f8-b3f8f928286c   206723576          San Francisco
# 4     2c47bcec-df97-4c1f-92f8-b3f8f928286c   206723576          San Francisco
# ...                                    ...         ...                    ...
# 3813  7e90e5c2-7598-4d97-a0a1-e427905657c6   MULTI_E_F          San Francisco
# 3814  7e90e5c2-7598-4d97-a0a1-e427905657c6   MULTI_E_F          San Francisco
# 3815  eeec9dd5-e0b9-406e-9918-d3594aa18bab   MULTI_E_F          San Francisco
# 3816  eeec9dd5-e0b9-406e-9918-d3594aa18bab   MULTI_E_F          San Francisco
# 3817  eeec9dd5-e0b9-406e-9918-d3594aa18bab   MULTI_E_F          San Francisco
#
#          tx_date tx_description   tx_zip     slate
# 0      3/24/2023            NaN  94132.0  moderate
# 1      3/24/2023            NaN  94109.0  moderate
# 2      3/24/2023            NaN  90064.0  moderate
# 3      3/24/2023            NaN  94123.0  moderate
# 4      3/24/2023            NaN  94118.0  moderate
# ...          ...            ...      ...       ...
# 3813   1/23/2024            NaN  94115.0       NaN
# 3814    2/3/2024            NaN  94115.0       NaN
# 3815  10/30/2023            NaN  94105.0       NaN
# 3816  10/30/2023            NaN  94133.0       NaN
# 3817  10/30/2023            NaN  94133.0       NaN
#
# [3818 rows x 21 columns]

# %%
df.position.value_counts()
# Out:
# Support    3757
# Oppose       61
# Name: position, dtype: int64

# %%
# show me rows based on a condition

measures = df[df['race'] == 'Measure']

# %%
measures.groupby('position').sum()
# Out:
# /var/folders/_0/x7xh_2c16jq4chdcqrg28fr40000gn/T/ipykernel_19163/2472117559.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   measures.groupby('position').sum()
#              amount      tx_zip
# position
# Oppose    1642372.0   5567993.0
# Support   5076833.0  27362685.0

# %%
# group by position AND measure and calculate the sum of the amount

measures.groupby(['contest', 'position']).sum()
# Out:
# /var/folders/_0/x7xh_2c16jq4chdcqrg28fr40000gn/T/ipykernel_19163/855163696.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   measures.groupby(['contest', 'position']).sum()
#                            amount      tx_zip
# contest       position
# Proposition A Support    786989.0   6776866.0
# Proposition B Oppose    1343760.0   3395183.0
#               Support    607500.0    376930.0
# Proposition C Oppose      63600.0    848707.0
#               Support    369348.0   2269904.0
# Proposition E Oppose     210100.0    474463.0
#               Support   2108410.0  10491794.0
# Proposition F Oppose      24912.0    849640.0
#               Support   1029805.0   3104119.0
# Proposition G Support    174781.0   4343072.0

# %%
measures.groupby('contest').sum()
# Out:
# /var/folders/_0/x7xh_2c16jq4chdcqrg28fr40000gn/T/ipykernel_19163/345912410.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   measures.groupby('contest').sum()
#                   amount      tx_zip
# contest
# Proposition A   786989.0   6776866.0
# Proposition B  1951260.0   3772113.0
# Proposition C   432948.0   3118611.0
# Proposition E  2318510.0  10966257.0
# Proposition F  1054717.0   3953759.0
# Proposition G   174781.0   4343072.0

# %%
# find the sum per position
measures.groupby('position').sum()
# Out:
# /var/folders/_0/x7xh_2c16jq4chdcqrg28fr40000gn/T/ipykernel_19163/1773860654.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   measures.groupby('position').sum()
#              amount      tx_zip
# position
# Oppose    1642372.0   5567993.0
# Support   5076833.0  27362685.0

# %% [markdown]
# Make sure here we have a df with the same number of rows as in the original data

# %%
df = df[['name', 'amount', 'committee_name', 'position', 'contest', 'slate', 'race']]

# %%
# if the name and contest are the same, group by name and contest and sum the amount, keep all the other columns

df = df.groupby(['name', 'contest']).agg({'amount':'sum','committee_name': lambda x: list(x), 'position':'first', 'slate':'first', 'race':'first'}).reset_index()

# %%
df
# Out:
#                                name                   contest   amount  \
# 0        1266 Ninth LLC(Dan Safier)             Proposition A    375.0
# 1       3333 California(Dan Safier)             Proposition A  13900.0
# 2       3700 California(Dan Safier)             Proposition A  11900.0
# 3     A San Francisco For All of Us             Proposition F   7500.0
# 4                         A. Sparks            Michael Nguyen    100.0
# ...                             ...                       ...      ...
# 2673                 Zalaikha Lodin            Sydney Simpson    150.0
# 2674                   Zhengren Yan  Multiple Candidates Rccc    100.0
# 2675                     Zhihan Zou               Natalie Gee    100.0
# 2676                     Zoe Kelman              Joshua Ochoa    250.0
# 2677                  Zoe Scheinman               Lyn Werbach    100.0
#
#                                          committee_name position        slate  \
# 0                           [Affordable Housing For SF]  Support         None
# 1                           [Affordable Housing For SF]  Support         None
# 2                           [Affordable Housing For SF]  Support         None
# 3     [Yes On F, For Treatment, Compassion And Accou...  Support         None
# 4     [Michael Nguyen For Democratic County Central ...  Support  progressive
# ...                                                 ...      ...          ...
# 2673  [Sydney Simpson For Democratic County Central ...  Support  progressive
# 2674  [Briones Society PAC Supporting Our San Franci...  Support         None
# 2675  [Natalie Gee For Democratic County Central Com...  Support  progressive
# 2676           [Joshua Rudy Ochoa For DCCC Member 2024]  Support  progressive
# 2677  [Lyn Werbach For Democratic County Central Com...  Support     moderate
#
#          race
# 0     Measure
# 1     Measure
# 2     Measure
# 3     Measure
# 4        DCCC
# ...       ...
# 2673     DCCC
# 2674     RCCC
# 2675     DCCC
# 2676     DCCC
# 2677     DCCC
#
# [2678 rows x 7 columns]

# %%
df['committee_name'] = df['committee_name'].apply(lambda x: ', '.join(x))

# %%
df['committee_name'] = df['committee_name'].apply(lambda x: ', '.join(set(x.split(', '))))

# %%
df['committee_name'] = df['committee_name'].str.replace("The Fight For San Francisco'S", "The Fight For San Francisco's")

# %%
df
# Out:
#                                name                   contest   amount  \
# 0        1266 Ninth LLC(Dan Safier)             Proposition A    375.0
# 1       3333 California(Dan Safier)             Proposition A  13900.0
# 2       3700 California(Dan Safier)             Proposition A  11900.0
# 3     A San Francisco For All of Us             Proposition F   7500.0
# 4                         A. Sparks            Michael Nguyen    100.0
# ...                             ...                       ...      ...
# 2673                 Zalaikha Lodin            Sydney Simpson    150.0
# 2674                   Zhengren Yan  Multiple Candidates Rccc    100.0
# 2675                     Zhihan Zou               Natalie Gee    100.0
# 2676                     Zoe Kelman              Joshua Ochoa    250.0
# 2677                  Zoe Scheinman               Lyn Werbach    100.0
#
#                                          committee_name position        slate  \
# 0                             Affordable Housing For SF  Support         None
# 1                             Affordable Housing For SF  Support         None
# 2                             Affordable Housing For SF  Support         None
# 3     Compassion And Accountability, Yes On F, For T...  Support         None
# 4     Michael Nguyen For Democratic County Central C...  Support  progressive
# ...                                                 ...      ...          ...
# 2673  Sydney Simpson For Democratic County Central C...  Support  progressive
# 2674  Briones Society PAC Supporting Our San Francis...  Support         None
# 2675  Natalie Gee For Democratic County Central Comm...  Support  progressive
# 2676             Joshua Rudy Ochoa For DCCC Member 2024  Support  progressive
# 2677  Lyn Werbach For Democratic County Central Comm...  Support     moderate
#
#          race
# 0     Measure
# 1     Measure
# 2     Measure
# 3     Measure
# 4        DCCC
# ...       ...
# 2673     DCCC
# 2674     RCCC
# 2675     DCCC
# 2676     DCCC
# 2677     DCCC
#
# [2678 rows x 7 columns]

# %%
judges_df = pd.read_csv('./judges.csv')

# %%
judges_df
# Out:
#                  name  contest  \
# 0              A Chun   Seat 1
# 1      A. Marisa Chun   Seat 1
# 2      A. Marisa Chun  Seat 13
# 3        Aaron Peskin   Seat 1
# 4        Aaron Peskin   Seat 1
# ...               ...      ...
# 1276          Yen Hui  Seat 13
# 1277          Yj Choi  Seat 13
# 1278  Zachary Alinder   Seat 1
# 1279    Zachary Stobo   Seat 1
# 1280    Zachary Stobo  Seat 13
#
#                                          committee_name  amount position  \
# 0                     Begert 2024; Retain Judge Michael   500.0    right
# 1     Begert And Patrick Thompson; Safe And Accounta...   250.0    right
# 2     Begert And Patrick Thompson; Safe And Accounta...   250.0    right
# 3                     Begert 2024; Retain Judge Michael   100.0    right
# 4     Begert And Patrick Thompson; Safe And Accounta...  1000.0    right
# ...                                                 ...     ...      ...
# 1276  Roland For Superior Court Judge 2024; Jean Myu...   100.0     left
# 1277  Roland For Superior Court Judge 2024; Jean Myu...   100.0     left
# 1278                  Begert 2024; Retain Judge Michael   250.0    right
# 1279         Zecher For Superior Court Judge 2024; Chip   500.0     left
# 1280  Roland For Superior Court Judge 2024; Jean Myu...   500.0     left
#
#      slate   race             judge
# 0     None  judge    Michael Begert
# 1     None  judge    Michael Begert
# 2     None  judge  Patrick Thompson
# 3     None  judge    Michael Begert
# 4     None  judge    Michael Begert
# ...    ...    ...               ...
# 1276  None  judge       Jean Roland
# 1277  None  judge       Jean Roland
# 1278  None  judge    Michael Begert
# 1279  None  judge     Albert Zecher
# 1280  None  judge       Jean Roland
#
# [1281 rows x 8 columns]

# %%
df = pd.concat([df, judges_df])

# %%
df
# Out:
#                                name         contest   amount  \
# 0        1266 Ninth LLC(Dan Safier)   Proposition A    375.0
# 1       3333 California(Dan Safier)   Proposition A  13900.0
# 2       3700 California(Dan Safier)   Proposition A  11900.0
# 3     A San Francisco For All of Us   Proposition F   7500.0
# 4                         A. Sparks  Michael Nguyen    100.0
# ...                             ...             ...      ...
# 1276                        Yen Hui         Seat 13    100.0
# 1277                        Yj Choi         Seat 13    100.0
# 1278                Zachary Alinder          Seat 1    250.0
# 1279                  Zachary Stobo          Seat 1    500.0
# 1280                  Zachary Stobo         Seat 13    500.0
#
#                                          committee_name position        slate  \
# 0                             Affordable Housing For SF  Support         None
# 1                             Affordable Housing For SF  Support         None
# 2                             Affordable Housing For SF  Support         None
# 3     Compassion And Accountability, Yes On F, For T...  Support         None
# 4     Michael Nguyen For Democratic County Central C...  Support  progressive
# ...                                                 ...      ...          ...
# 1276  Roland For Superior Court Judge 2024; Jean Myu...     left         None
# 1277  Roland For Superior Court Judge 2024; Jean Myu...     left         None
# 1278                  Begert 2024; Retain Judge Michael    right         None
# 1279         Zecher For Superior Court Judge 2024; Chip     left         None
# 1280  Roland For Superior Court Judge 2024; Jean Myu...     left         None
#
#          race           judge
# 0     Measure             NaN
# 1     Measure             NaN
# 2     Measure             NaN
# 3     Measure             NaN
# 4        DCCC             NaN
# ...       ...             ...
# 1276    judge     Jean Roland
# 1277    judge     Jean Roland
# 1278    judge  Michael Begert
# 1279    judge   Albert Zecher
# 1280    judge     Jean Roland
#
# [3959 rows x 8 columns]

# %%
# show rows that are NaN

df[df['amount'].isna()]
# Out:
# Empty DataFrame
# Columns: [name, contest, amount, committee_name, position, slate, race, judge]
# Index: []

# %%
# show rows in amount column that are null

df[df['amount'] == 0]
# Out:
#                        name        contest  amount  \
# 2556  Unitemized Schedule I    Luis Zamora     0.0
# 2558  Unitemized Schedule I  Proposition E     0.0
# 73       Anthony Schoenberg        Seat 13     0.0
# 222         Colin Alexander        Seat 13     0.0
# 290          David Mitchell        Seat 13     0.0
# 622          Julius De Guia        Seat 13     0.0
# 817            Matt Donahue        Seat 13     0.0
# 1050          Ronald Sabraw        Seat 13     0.0
#
#                                          committee_name position     slate  \
# 2556  Luis Zamora [Democratic County Central Committ...  Support  moderate
# 2558  Yes On E, Committee For A Safer San Francisco ...  Support      None
# 73                  Thompson 2024; Retain Judge Patrick    right      None
# 222   Roland For Superior Court Judge 2024; Jean Myu...     left      None
# 290   Roland For Superior Court Judge 2024; Jean Myu...     left      None
# 622   Roland For Superior Court Judge 2024; Jean Myu...     left      None
# 817   Roland For Superior Court Judge 2024; Jean Myu...     left      None
# 1050                Thompson 2024; Retain Judge Patrick    right      None
#
#          race             judge
# 2556     DCCC               NaN
# 2558  Measure               NaN
# 73      judge  Patrick Thompson
# 222     judge       Jean Roland
# 290     judge       Jean Roland
# 622     judge       Jean Roland
# 817     judge       Jean Roland
# 1050    judge  Patrick Thompson

# %%
# remove the rows where the amount is 0

df = df[df['amount'] != 0]

# %%
# fond the total amount by race     

df.groupby('race').amount.sum()
# Out:
# race
# DCCC       2300419.00
# Measure    6719205.00
# RCCC         99500.00
# judge      1945662.24
# Name: amount, dtype: float64

# %%
df.amount.sum()
# Out:
# 11064786.24

# %%
df.groupby('race').contest.nunique()
# Out:
# race
# DCCC       49
# Measure     6
# RCCC        1
# judge       2
# Name: contest, dtype: int64

# %%
# save as csv

df.to_csv('/Users/kellywaldron/Desktop/interactives/docs/2024-march-ballots-desktop/data.csv', index=False)
df.to_csv('/Users/kellywaldron/Desktop/interactives/docs/2024-march-ballots-mobile/data.csv', index=False)
df.to_csv('/Users/kellywaldron/Desktop/interactives/docs/2024-march-dccc-desktop/data.csv', index=False)
df.to_csv('/Users/kellywaldron/Desktop/interactives/docs/2024-march-dccc-mobile/data.csv', index=False)
df.to_csv('/Users/kellywaldron/Desktop/interactives/docs/2024-march-judge-candidates-mobile/data.csv', index=False)
df.to_csv('/Users/kellywaldron/Desktop/interactives/docs/2024-march-judge-candidates-desktop/data.csv', index=False)
